# %%
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor


from trading_envs import PortfolioValueTradingEnv, PortfolioValueTradingEnvUpdated
from logger import TrainingLoggerCallback
from data_and_plots import (
    generate_sine_wave,
    training_plot,
    results_plot_continuous,
    plot_shares_changes_fixed_size,
    plot,
)
from helper import predict_data_env
import torch
import random

# %%
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)

# ziarno dla NumPy
np.random.seed(42)

# ziarno dla standardowego generatora liczb losowych Pythona
random.seed(42)

# %%
prices = generate_sine_wave(seed=42)
plot(prices)

# %%
# Tworzenie instacji środowiska
env_agent = PortfolioValueTradingEnv(prices)
env_agent = Monitor(env_agent)

# Sprawdzenie zgodności środowiska z stable_baselines3
check_env(env_agent)

logger_callback = TrainingLoggerCallback()
# Tworzenie modelu PPO
model_agent = PPO(
    "MlpPolicy",
    env_agent,
    # policy_kwargs=dict(
    #     net_arch=[
    #         128,
    #         128,
    #     ]
    # ),
    #   learning_rate=0.00005,        # domyślnie 3e-4
    n_steps=400,  # liczba kroków zanim agent zrobi aktualizację
    batch_size=100,  # batch size do uczenia
    # n_epochs=10,                 # ile razy przebiega po danych przy każdej aktualizacji
    gamma=0.3,  # współczynnik dyskontujący nagrody
    # gae_lambda=0.95,             # współczynnik GAE
    # clip_range=0.2,              # zakres klipu PPO (stabilizacja treningu)
    # ent_coef=0.9,                # zachęta do eksploracji
    verbose=1,
)

# Trening modelu
model_agent.learn(total_timesteps=30_000, callback=logger_callback)


training_plot(logger_callback=logger_callback)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 400       |
# |    ep_rew_mean     | -3.61e+03 |
# | time/              |           |
# |    fps             | 737       |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 400       |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -3.1e+03    |
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 800         |
# | train/                  |             |
# |    approx_kl            | 0.020528335 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.000378   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 860         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0367     |
# |    std                  | 0.994       |
# |    value_loss           | 1.19e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -2.82e+03  |
# | time/                   |            |
# |    fps                  | 638        |
# |    iterations           | 3          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 1200       |
# | train/                  |            |
# |    approx_kl            | 0.02097138 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.00196    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 292        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0355    |
# |    std                  | 0.985      |
# |    value_loss           | 781        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.34e+03   |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1600        |
# | train/                  |             |
# |    approx_kl            | 0.014485877 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.00173     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 231         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0335     |
# |    std                  | 0.974       |
# |    value_loss           | 714         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.99e+03   |
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2000        |
# | train/                  |             |
# |    approx_kl            | 0.006117599 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.00244    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 243         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.965       |
# |    value_loss           | 304         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.67e+03    |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2400         |
# | train/                  |              |
# |    approx_kl            | 0.0047098105 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00347      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.6         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0218      |
# |    std                  | 0.957        |
# |    value_loss           | 261          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.47e+03   |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2800        |
# | train/                  |             |
# |    approx_kl            | 0.016457435 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0359      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 59.4        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.948       |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.3e+03    |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.009694273 |
# |    clip_fraction        | 0.0742      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.061       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.021      |
# |    std                  | 0.943       |
# |    value_loss           | 221         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.13e+03   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.024618082 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0945      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95.6        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0328     |
# |    std                  | 0.936       |
# |    value_loss           | 257         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -841        |
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 10          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.018442992 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 180         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.928       |
# |    value_loss           | 239         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -554         |
# | time/                   |              |
# |    fps                  | 630          |
# |    iterations           | 11           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4400         |
# | train/                  |              |
# |    approx_kl            | 0.0065422487 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 319          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00348     |
# |    std                  | 0.924        |
# |    value_loss           | 826          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -198        |
# | time/                   |             |
# |    fps                  | 632         |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4800        |
# | train/                  |             |
# |    approx_kl            | 0.018831681 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 273         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.922       |
# |    value_loss           | 625         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 42.1        |
# | time/                   |             |
# |    fps                  | 631         |
# |    iterations           | 13          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5200        |
# | train/                  |             |
# |    approx_kl            | 0.005524756 |
# |    clip_fraction        | 0.0382      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00601    |
# |    std                  | 0.92        |
# |    value_loss           | 1.82e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 438         |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 14          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5600        |
# | train/                  |             |
# |    approx_kl            | 0.012230158 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 753         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.917       |
# |    value_loss           | 1.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 684         |
# | time/                   |             |
# |    fps                  | 636         |
# |    iterations           | 15          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.009413354 |
# |    clip_fraction        | 0.0665      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0917      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.5e+03     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0044      |
# |    std                  | 0.916       |
# |    value_loss           | 3.94e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 1.16e+03    |
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 16          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.009130832 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 567         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00349    |
# |    std                  | 0.915       |
# |    value_loss           | 2.26e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 1.43e+03     |
# | time/                   |              |
# |    fps                  | 638          |
# |    iterations           | 17           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6800         |
# | train/                  |              |
# |    approx_kl            | 0.0056973095 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0811       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.04e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.000772     |
# |    std                  | 0.914        |
# |    value_loss           | 7.39e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 1.7e+03     |
# | time/                   |             |
# |    fps                  | 636         |
# |    iterations           | 18          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 7200        |
# | train/                  |             |
# |    approx_kl            | 0.011106713 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.44e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0087     |
# |    std                  | 0.913       |
# |    value_loss           | 3.81e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | 1.75e+03   |
# | time/                   |            |
# |    fps                  | 636        |
# |    iterations           | 19         |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 7600       |
# | train/                  |            |
# |    approx_kl            | 0.00447015 |
# |    clip_fraction        | 0.012      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.11       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.3e+03    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.000423   |
# |    std                  | 0.913      |
# |    value_loss           | 4.88e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.01e+03    |
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 20          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.014514033 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 969         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.911       |
# |    value_loss           | 2.28e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 2.38e+03     |
# | time/                   |              |
# |    fps                  | 637          |
# |    iterations           | 21           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 8400         |
# | train/                  |              |
# |    approx_kl            | 0.0024218902 |
# |    clip_fraction        | 0.00525      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.32e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00429     |
# |    std                  | 0.91         |
# |    value_loss           | 5.01e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.65e+03    |
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 22          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8800        |
# | train/                  |             |
# |    approx_kl            | 0.000879437 |
# |    clip_fraction        | 0.00475     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0806      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.96e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.000629    |
# |    std                  | 0.91        |
# |    value_loss           | 9.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.76e+03    |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 23          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 9200        |
# | train/                  |             |
# |    approx_kl            | 0.004946807 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0935      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.09e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00167    |
# |    std                  | 0.909       |
# |    value_loss           | 6.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 3.06e+03    |
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 24          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 9600        |
# | train/                  |             |
# |    approx_kl            | 0.002917613 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.41e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00213    |
# |    std                  | 0.908       |
# |    value_loss           | 5.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 3.31e+03    |
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 25          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.001184227 |
# |    clip_fraction        | 0.00725     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0881      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.82e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000826   |
# |    std                  | 0.908       |
# |    value_loss           | 1.08e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 3.56e+03     |
# | time/                   |              |
# |    fps                  | 632          |
# |    iterations           | 26           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 10400        |
# | train/                  |              |
# |    approx_kl            | 0.0025801684 |
# |    clip_fraction        | 0.00525      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.0942       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.55e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00197     |
# |    std                  | 0.907        |
# |    value_loss           | 9.34e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 3.85e+03    |
# | time/                   |             |
# |    fps                  | 631         |
# |    iterations           | 27          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10800       |
# | train/                  |             |
# |    approx_kl            | 0.002218604 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.086       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.8e+03     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00532    |
# |    std                  | 0.907       |
# |    value_loss           | 1.19e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 3.99e+03     |
# | time/                   |              |
# |    fps                  | 629          |
# |    iterations           | 28           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 11200        |
# | train/                  |              |
# |    approx_kl            | 0.0019051649 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.0857       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.46e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00203     |
# |    std                  | 0.907        |
# |    value_loss           | 1.48e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 4.24e+03    |
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 29          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 11600       |
# | train/                  |             |
# |    approx_kl            | 0.004478247 |
# |    clip_fraction        | 0.0135      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.48e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00307    |
# |    std                  | 0.907       |
# |    value_loss           | 7.18e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 4.59e+03     |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 30           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0010447082 |
# |    clip_fraction        | 0.003        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.0868       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.58e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00158     |
# |    std                  | 0.906        |
# |    value_loss           | 1.34e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 4.81e+03    |
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 31          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 12400       |
# | train/                  |             |
# |    approx_kl            | 0.003280871 |
# |    clip_fraction        | 0.0065      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0657      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+04    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00324    |
# |    std                  | 0.907       |
# |    value_loss           | 2.13e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 5.06e+03    |
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 32          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.005658426 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0776      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.6e+03     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00299    |
# |    std                  | 0.907       |
# |    value_loss           | 1.41e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 5.24e+03    |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 33          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 13200       |
# | train/                  |             |
# |    approx_kl            | 0.005877563 |
# |    clip_fraction        | 0.0132      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.08        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.27e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.000532    |
# |    std                  | 0.906       |
# |    value_loss           | 1.68e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 5.4e+03     |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 34          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 13600       |
# | train/                  |             |
# |    approx_kl            | 0.027918682 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.0947      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.31e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00452     |
# |    std                  | 0.906       |
# |    value_loss           | 1.27e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 5.56e+03     |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 35           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 14000        |
# | train/                  |              |
# |    approx_kl            | 0.0043487074 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.35e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00271     |
# |    std                  | 0.906        |
# |    value_loss           | 1.16e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 5.66e+03    |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 36          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14400       |
# | train/                  |             |
# |    approx_kl            | 0.024144229 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.54e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00627     |
# |    std                  | 0.905       |
# |    value_loss           | 1.16e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 5.71e+03    |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 37          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14800       |
# | train/                  |             |
# |    approx_kl            | 0.014086241 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.93e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00245    |
# |    std                  | 0.905       |
# |    value_loss           | 7.72e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 5.85e+03    |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 38          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 15200       |
# | train/                  |             |
# |    approx_kl            | 0.009894526 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.59e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 4.21e-05    |
# |    std                  | 0.904       |
# |    value_loss           | 6.42e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 5.93e+03     |
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 39           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 15600        |
# | train/                  |              |
# |    approx_kl            | 0.0044849515 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.107        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.94e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 8.28e-05     |
# |    std                  | 0.904        |
# |    value_loss           | 1.16e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 5.84e+03     |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 40           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 16000        |
# | train/                  |              |
# |    approx_kl            | 0.0049329777 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.125        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.68e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00333     |
# |    std                  | 0.904        |
# |    value_loss           | 9.09e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 5.95e+03    |
# | time/                   |             |
# |    fps                  | 614         |
# |    iterations           | 41          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16400       |
# | train/                  |             |
# |    approx_kl            | 0.019367483 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 860         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.903       |
# |    value_loss           | 2.53e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.14e+03    |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 42          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 16800       |
# | train/                  |             |
# |    approx_kl            | 0.030329376 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.29e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0217      |
# |    std                  | 0.903       |
# |    value_loss           | 1.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.1e+03     |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 43          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 17200       |
# | train/                  |             |
# |    approx_kl            | 0.005896326 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28e+04    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00103    |
# |    std                  | 0.903       |
# |    value_loss           | 1.8e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.06e+03     |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 44           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 17600        |
# | train/                  |              |
# |    approx_kl            | 0.0046355887 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.39e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00585     |
# |    std                  | 0.902        |
# |    value_loss           | 3e+03        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.1e+03     |
# | time/                   |             |
# |    fps                  | 614         |
# |    iterations           | 45          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.105532125 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49e+03    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0376      |
# |    std                  | 0.902       |
# |    value_loss           | 3.86e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.13e+03    |
# | time/                   |             |
# |    fps                  | 614         |
# |    iterations           | 46          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18400       |
# | train/                  |             |
# |    approx_kl            | 0.013210668 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.09e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0085     |
# |    std                  | 0.902       |
# |    value_loss           | 6.45e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.14e+03     |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 47           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 18800        |
# | train/                  |              |
# |    approx_kl            | 0.0012251278 |
# |    clip_fraction        | 0.003        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.23e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0027      |
# |    std                  | 0.902        |
# |    value_loss           | 6.2e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.27e+03     |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 48           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 19200        |
# | train/                  |              |
# |    approx_kl            | 0.0019123742 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.185        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+03     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00353     |
# |    std                  | 0.901        |
# |    value_loss           | 6.23e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.32e+03     |
# | time/                   |              |
# |    fps                  | 615          |
# |    iterations           | 49           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 19600        |
# | train/                  |              |
# |    approx_kl            | 0.0012744897 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.97e+03     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00121     |
# |    std                  | 0.901        |
# |    value_loss           | 1.31e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.44e+03    |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 50          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.003776106 |
# |    clip_fraction        | 0.00425     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.154       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.1e+03     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00566    |
# |    std                  | 0.901       |
# |    value_loss           | 8.01e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.43e+03     |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 51           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 20400        |
# | train/                  |              |
# |    approx_kl            | 0.0013077855 |
# |    clip_fraction        | 0.0387       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.28e+03     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.00639      |
# |    std                  | 0.901        |
# |    value_loss           | 1.31e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | 6.44e+03   |
# | time/                   |            |
# |    fps                  | 613        |
# |    iterations           | 52         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 20800      |
# | train/                  |            |
# |    approx_kl            | 0.07251789 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.203      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.4e+03    |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.00362    |
# |    std                  | 0.901      |
# |    value_loss           | 3.43e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.51e+03     |
# ...
# |    value_loss           | 8.44e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.73e+03     |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 59           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 23600        |
# | train/                  |              |
# |    approx_kl            | 0.0006166631 |
# |    clip_fraction        | 0.00325      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.21e+03     |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00101     |
# |    std                  | 0.898        |
# |    value_loss           | 7.93e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.83e+03    |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 60          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 24000       |
# | train/                  |             |
# |    approx_kl            | 0.005327521 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.11e+03    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00288    |
# |    std                  | 0.898       |
# |    value_loss           | 9.19e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.88e+03     |
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 61           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 24400        |
# | train/                  |              |
# |    approx_kl            | 0.0007330717 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.28e+03     |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00179     |
# |    std                  | 0.897        |
# |    value_loss           | 1.67e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.96e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 62          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 24800       |
# | train/                  |             |
# |    approx_kl            | 0.009620626 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+04     |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00631    |
# |    std                  | 0.897       |
# |    value_loss           | 1.11e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.97e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 63          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 25200       |
# | train/                  |             |
# |    approx_kl            | 0.003106005 |
# |    clip_fraction        | 0.0102      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.97e+03    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00267    |
# |    std                  | 0.896       |
# |    value_loss           | 1.3e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.04e+03     |
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 64           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0024327205 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.09e+03     |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.00127     |
# |    std                  | 0.896        |
# |    value_loss           | 7.03e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.12e+03     |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 65           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 26000        |
# | train/                  |              |
# |    approx_kl            | 0.0024914374 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.89e+03     |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00186     |
# |    std                  | 0.896        |
# |    value_loss           | 1.15e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.18e+03     |
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 66           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 26400        |
# | train/                  |              |
# |    approx_kl            | 0.0031555467 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.45e+03     |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.00489     |
# |    std                  | 0.896        |
# |    value_loss           | 1.41e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.2e+03      |
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 67           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 26800        |
# | train/                  |              |
# |    approx_kl            | 0.0058341958 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.141        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.91e+03     |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00425     |
# |    std                  | 0.894        |
# |    value_loss           | 1.29e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.28e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 68          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 27200       |
# | train/                  |             |
# |    approx_kl            | 0.007984456 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.72e+03    |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00285    |
# |    std                  | 0.894       |
# |    value_loss           | 8.46e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 400           |
# |    ep_rew_mean          | 7.35e+03      |
# | time/                   |               |
# |    fps                  | 611           |
# |    iterations           | 69            |
# |    time_elapsed         | 45            |
# |    total_timesteps      | 27600         |
# | train/                  |               |
# |    approx_kl            | 0.00084800064 |
# |    clip_fraction        | 0.004         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0.143         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.25e+03      |
# |    n_updates            | 680           |
# |    policy_gradient_loss | -0.00127      |
# |    std                  | 0.894         |
# |    value_loss           | 1.41e+04      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.4e+03     |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 70          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 28000       |
# | train/                  |             |
# |    approx_kl            | 0.011455419 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.43e+03    |
# |    n_updates            | 690         |
# |    policy_gradient_loss | 0.00267     |
# |    std                  | 0.893       |
# |    value_loss           | 1.27e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.5e+03     |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 71          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 28400       |
# | train/                  |             |
# |    approx_kl            | 0.020031393 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.143       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.5e+03     |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.00351    |
# |    std                  | 0.894       |
# |    value_loss           | 1.25e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.54e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 72          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 28800       |
# | train/                  |             |
# |    approx_kl            | 0.012030952 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.39e+03    |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.00388    |
# |    std                  | 0.894       |
# |    value_loss           | 1.8e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.51e+03     |
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 73           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 29200        |
# | train/                  |              |
# |    approx_kl            | 0.0045688017 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0.136        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.86e+03     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00655     |
# |    std                  | 0.894        |
# |    value_loss           | 1.33e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.45e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 74          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 29600       |
# | train/                  |             |
# |    approx_kl            | 0.013314258 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.00631    |
# |    std                  | 0.895       |
# |    value_loss           | 4.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.55e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 75          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.012448616 |
# |    clip_fraction        | 0.006       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 854         |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.00537    |
# |    std                  | 0.895       |
# |    value_loss           | 2.26e+03    |
# -----------------------------------------

# %%
env_predict, lista = predict_data_env(
    env=PortfolioValueTradingEnv, data=prices, agent=model_agent
)
# Out:
# Krok: 1|Cena: 5.17|Gotówka: 4.88|Akcje: 19|Wartość portfela: 103.08|Nagroda: 0.38|
# Krok: 2|Cena: 5.39|Gotówka: 4.88|Akcje: 19|Wartość portfela: 107.33|Nagroda: 3.08|
# Krok: 3|Cena: 5.58|Gotówka: 4.88|Akcje: 19|Wartość portfela: 110.95|Nagroda: 4.25|
# Krok: 4|Cena: 5.71|Gotówka: 4.88|Akcje: 19|Wartość portfela: 113.35|Nagroda: 3.62|
# Krok: 5|Cena: 5.90|Gotówka: 4.88|Akcje: 19|Wartość portfela: 117.05|Nagroda: 2.40|
# Krok: 6|Cena: 6.11|Gotówka: 4.88|Akcje: 19|Wartość portfela: 120.97|Nagroda: 3.69|
# Krok: 7|Cena: 6.27|Gotówka: 4.88|Akcje: 19|Wartość portfela: 124.09|Nagroda: 3.92|
# Krok: 8|Cena: 6.45|Gotówka: 4.88|Akcje: 19|Wartość portfela: 127.40|Nagroda: 3.12|
# Krok: 9|Cena: 6.59|Gotówka: 4.88|Akcje: 19|Wartość portfela: 130.17|Nagroda: 3.31|
# Krok: 10|Cena: 6.78|Gotówka: 4.88|Akcje: 19|Wartość portfela: 133.79|Nagroda: 2.77|
# Krok: 11|Cena: 6.93|Gotówka: 4.88|Akcje: 19|Wartość portfela: 136.59|Nagroda: 3.62|
# Krok: 12|Cena: 7.06|Gotówka: 4.88|Akcje: 19|Wartość portfela: 139.01|Nagroda: 2.79|
# Krok: 13|Cena: 7.21|Gotówka: 4.88|Akcje: 19|Wartość portfela: 141.94|Nagroda: 2.42|
# Krok: 14|Cena: 7.33|Gotówka: 4.88|Akcje: 19|Wartość portfela: 144.06|Nagroda: 2.94|
# Krok: 15|Cena: 7.41|Gotówka: 4.88|Akcje: 19|Wartość portfela: 145.75|Nagroda: 2.12|
# Krok: 16|Cena: 7.54|Gotówka: 4.88|Akcje: 19|Wartość portfela: 148.23|Nagroda: 1.69|
# Krok: 17|Cena: 7.61|Gotówka: 4.88|Akcje: 19|Wartość portfela: 149.54|Nagroda: 2.48|
# Krok: 18|Cena: 7.74|Gotówka: 4.88|Akcje: 19|Wartość portfela: 151.86|Nagroda: 1.31|
# Krok: 19|Cena: 7.79|Gotówka: 4.88|Akcje: 19|Wartość portfela: 152.93|Nagroda: 2.32|
# Krok: 20|Cena: 7.85|Gotówka: 4.88|Akcje: 19|Wartość portfela: 154.08|Nagroda: 1.06|
# Krok: 21|Cena: 7.89|Gotówka: 4.88|Akcje: 19|Wartość portfela: 154.88|Nagroda: 1.15|
# Krok: 22|Cena: 7.97|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.38|Nagroda: 0.80|
# Krok: 23|Cena: 7.97|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.40|Nagroda: 1.49|
# Krok: 24|Cena: 7.99|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.62|Nagroda: 0.03|
# Krok: 25|Cena: 7.99|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.75|Nagroda: 0.22|
# Krok: 26|Cena: 8.00|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.96|Nagroda: 0.13|
# Krok: 27|Cena: 7.98|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.54|Nagroda: 0.21|
# Krok: 28|Cena: 7.95|Gotówka: 100.67|Akcje: 7|Wartość portfela: 156.34|Nagroda: -0.15|
# Krok: 29|Cena: 7.91|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 30|Cena: 7.89|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 31|Cena: 7.78|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 32|Cena: 7.70|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 33|Cena: 7.61|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 34|Cena: 7.54|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 35|Cena: 7.44|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 36|Cena: 7.30|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 37|Cena: 7.16|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 38|Cena: 7.02|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 39|Cena: 6.91|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 40|Cena: 6.76|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 41|Cena: 6.60|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 42|Cena: 6.41|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 43|Cena: 6.26|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 44|Cena: 6.09|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 45|Cena: 5.91|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 46|Cena: 5.74|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 47|Cena: 5.54|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 48|Cena: 5.37|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 49|Cena: 5.17|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 50|Cena: 4.98|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 51|Cena: 4.80|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 52|Cena: 4.57|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 53|Cena: 4.41|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 54|Cena: 4.22|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 55|Cena: 4.04|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 56|Cena: 3.87|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 57|Cena: 3.73|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 58|Cena: 3.51|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 59|Cena: 3.39|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 60|Cena: 3.18|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 61|Cena: 3.06|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 62|Cena: 2.93|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 63|Cena: 2.80|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 64|Cena: 2.68|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 65|Cena: 2.57|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 66|Cena: 2.44|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 67|Cena: 2.35|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 68|Cena: 2.29|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 69|Cena: 2.20|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 70|Cena: 2.11|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 71|Cena: 2.06|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 72|Cena: 2.03|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 73|Cena: 2.03|Gotówka: 156.34|Akcje: 0|Wartość portfela: 156.34|Nagroda: 0.00|
# Krok: 74|Cena: 2.01|Gotówka: 2.10|Akcje: 76|Wartość portfela: 154.61|Nagroda: 0.07|
# Krok: 75|Cena: 2.01|Gotówka: 154.61|Akcje: 0|Wartość portfela: 154.61|Nagroda: 0.00|
# Krok: 76|Cena: 2.00|Gotówka: 1.55|Akcje: 76|Wartość portfela: 153.53|Nagroda: 0.55|
# Krok: 77|Cena: 2.03|Gotówka: 111.54|Akcje: 21|Wartość portfela: 154.20|Nagroda: -0.30|
# Krok: 78|Cena: 2.07|Gotówka: 34.34|Akcje: 59|Wartość portfela: 156.63|Nagroda: 1.87|
# Krok: 79|Cena: 2.10|Gotówka: 1.17|Akcje: 75|Wartość portfela: 158.49|Nagroda: 3.09|
# Krok: 80|Cena: 2.17|Gotówka: 1.17|Akcje: 75|Wartość portfela: 163.76|Nagroda: 1.86|
# Krok: 81|Cena: 2.21|Gotówka: 1.17|Akcje: 75|Wartość portfela: 167.05|Nagroda: 5.27|
# Krok: 82|Cena: 2.29|Gotówka: 1.17|Akcje: 75|Wartość portfela: 173.30|Nagroda: 3.29|
# Krok: 83|Cena: 2.38|Gotówka: 1.17|Akcje: 75|Wartość portfela: 179.86|Nagroda: 6.24|
# Krok: 84|Cena: 2.46|Gotówka: 1.17|Akcje: 75|Wartość portfela: 186.02|Nagroda: 6.57|
# Krok: 85|Cena: 2.61|Gotówka: 1.17|Akcje: 75|Wartość portfela: 196.66|Nagroda: 6.15|
# Krok: 86|Cena: 2.71|Gotówka: 1.17|Akcje: 75|Wartość portfela: 204.06|Nagroda: 10.64|
# Krok: 87|Cena: 2.84|Gotówka: 1.17|Akcje: 75|Wartość portfela: 214.30|Nagroda: 7.40|
# Krok: 88|Cena: 2.99|Gotówka: 1.17|Akcje: 75|Wartość portfela: 225.16|Nagroda: 10.24|
# Krok: 89|Cena: 3.13|Gotówka: 1.17|Akcje: 75|Wartość portfela: 235.87|Nagroda: 10.86|
# Krok: 90|Cena: 3.28|Gotówka: 1.17|Akcje: 75|Wartość portfela: 247.51|Nagroda: 10.71|
# Krok: 91|Cena: 3.43|Gotówka: 1.17|Akcje: 75|Wartość portfela: 258.20|Nagroda: 11.65|
# Krok: 92|Cena: 3.58|Gotówka: 1.17|Akcje: 75|Wartość portfela: 270.01|Nagroda: 10.69|
# Krok: 93|Cena: 3.76|Gotówka: 1.17|Akcje: 75|Wartość portfela: 283.24|Nagroda: 11.81|
# Krok: 94|Cena: 3.90|Gotówka: 1.17|Akcje: 75|Wartość portfela: 293.92|Nagroda: 13.23|
# Krok: 95|Cena: 4.09|Gotówka: 1.17|Akcje: 75|Wartość portfela: 307.68|Nagroda: 10.67|
# Krok: 96|Cena: 4.27|Gotówka: 1.17|Akcje: 75|Wartość portfela: 321.53|Nagroda: 13.76|
# Krok: 97|Cena: 4.46|Gotówka: 1.17|Akcje: 75|Wartość portfela: 335.90|Nagroda: 13.85|
# Krok: 98|Cena: 4.68|Gotówka: 1.17|Akcje: 75|Wartość portfela: 352.02|Nagroda: 14.36|
# Krok: 99|Cena: 4.84|Gotówka: 1.17|Akcje: 75|Wartość portfela: 364.19|Nagroda: 16.12|
# Krok: 100|Cena: 5.04|Gotówka: 1.17|Akcje: 75|Wartość portfela: 379.15|Nagroda: 12.17|
# Krok: 101|Cena: 5.26|Gotówka: 1.17|Akcje: 75|Wartość portfela: 395.82|Nagroda: 14.96|
# Krok: 102|Cena: 5.42|Gotówka: 1.17|Akcje: 75|Wartość portfela: 407.42|Nagroda: 16.67|
# Krok: 103|Cena: 5.62|Gotówka: 1.17|Akcje: 75|Wartość portfela: 423.02|Nagroda: 11.60|
# Krok: 104|Cena: 5.77|Gotówka: 1.17|Akcje: 75|Wartość portfela: 434.29|Nagroda: 15.60|
# Krok: 105|Cena: 5.97|Gotówka: 1.17|Akcje: 75|Wartość portfela: 448.92|Nagroda: 11.27|
# Krok: 106|Cena: 6.13|Gotówka: 1.17|Akcje: 75|Wartość portfela: 461.06|Nagroda: 14.63|
# Krok: 107|Cena: 6.32|Gotówka: 1.17|Akcje: 75|Wartość portfela: 474.88|Nagroda: 12.13|
# Krok: 108|Cena: 6.51|Gotówka: 1.17|Akcje: 75|Wartość portfela: 489.16|Nagroda: 13.83|
# Krok: 109|Cena: 6.62|Gotówka: 1.17|Akcje: 75|Wartość portfela: 497.39|Nagroda: 14.28|
# Krok: 110|Cena: 6.81|Gotówka: 1.17|Akcje: 75|Wartość portfela: 512.21|Nagroda: 8.22|
# Krok: 111|Cena: 6.96|Gotówka: 1.17|Akcje: 75|Wartość portfela: 522.96|Nagroda: 14.82|
# Krok: 112|Cena: 7.08|Gotówka: 1.17|Akcje: 75|Wartość portfela: 532.17|Nagroda: 10.75|
# Krok: 113|Cena: 7.19|Gotówka: 1.17|Akcje: 75|Wartość portfela: 540.74|Nagroda: 9.22|
# Krok: 114|Cena: 7.35|Gotówka: 1.17|Akcje: 75|Wartość portfela: 552.19|Nagroda: 8.56|
# Krok: 115|Cena: 7.45|Gotówka: 1.17|Akcje: 75|Wartość portfela: 559.77|Nagroda: 11.46|
# Krok: 116|Cena: 7.57|Gotówka: 1.17|Akcje: 75|Wartość portfela: 568.67|Nagroda: 7.58|
# Krok: 117|Cena: 7.66|Gotówka: 1.17|Akcje: 75|Wartość portfela: 575.34|Nagroda: 8.89|
# Krok: 118|Cena: 7.77|Gotówka: 1.17|Akcje: 75|Wartość portfela: 583.91|Nagroda: 6.67|
# Krok: 119|Cena: 7.80|Gotówka: 1.17|Akcje: 75|Wartość portfela: 586.53|Nagroda: 8.57|
# Krok: 120|Cena: 7.85|Gotówka: 1.17|Akcje: 75|Wartość portfela: 589.90|Nagroda: 2.62|
# Krok: 121|Cena: 7.92|Gotówka: 1.17|Akcje: 75|Wartość portfela: 595.40|Nagroda: 3.37|
# Krok: 122|Cena: 7.96|Gotówka: 1.17|Akcje: 75|Wartość portfela: 598.29|Nagroda: 5.50|
# Krok: 123|Cena: 8.01|Gotówka: 1.17|Akcje: 75|Wartość portfela: 601.94|Nagroda: 2.89|
# Krok: 124|Cena: 8.01|Gotówka: 1.17|Akcje: 75|Wartość portfela: 602.21|Nagroda: 3.66|
# Krok: 125|Cena: 8.01|Gotówka: 1.17|Akcje: 75|Wartość portfela: 601.66|Nagroda: 0.27|
# Krok: 126|Cena: 8.02|Gotówka: 1.17|Akcje: 75|Wartość portfela: 602.60|Nagroda: -0.55|
# Krok: 127|Cena: 7.94|Gotówka: 1.17|Akcje: 75|Wartość portfela: 597.01|Nagroda: 0.93|
# Krok: 128|Cena: 7.92|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 129|Cena: 7.87|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 130|Cena: 7.83|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 131|Cena: 7.74|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 132|Cena: 7.70|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 133|Cena: 7.59|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 134|Cena: 7.47|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 135|Cena: 7.37|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 136|Cena: 7.28|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 137|Cena: 7.16|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 138|Cena: 7.05|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 139|Cena: 6.92|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 140|Cena: 6.72|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 141|Cena: 6.53|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 142|Cena: 6.34|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 143|Cena: 6.22|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 144|Cena: 6.02|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 145|Cena: 5.85|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 146|Cena: 5.67|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 147|Cena: 5.49|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 148|Cena: 5.33|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 149|Cena: 5.12|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 150|Cena: 4.93|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 151|Cena: 4.72|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 152|Cena: 4.52|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 153|Cena: 4.36|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 154|Cena: 4.18|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 155|Cena: 4.04|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 156|Cena: 3.83|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 157|Cena: 3.68|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 158|Cena: 3.48|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 159|Cena: 3.31|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 160|Cena: 3.16|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 161|Cena: 3.02|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 162|Cena: 2.93|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 163|Cena: 2.74|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 164|Cena: 2.66|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 165|Cena: 2.51|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 166|Cena: 2.44|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 167|Cena: 2.34|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 168|Cena: 2.25|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 169|Cena: 2.18|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 170|Cena: 2.11|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 171|Cena: 2.08|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 172|Cena: 2.03|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 173|Cena: 1.99|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 174|Cena: 1.98|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 175|Cena: 2.00|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 176|Cena: 2.04|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 177|Cena: 2.04|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 178|Cena: 2.07|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 179|Cena: 2.12|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 180|Cena: 2.20|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 181|Cena: 2.25|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 182|Cena: 2.32|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 183|Cena: 2.44|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 184|Cena: 2.52|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 185|Cena: 2.66|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 186|Cena: 2.75|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 187|Cena: 2.85|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 188|Cena: 2.98|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 189|Cena: 3.19|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 190|Cena: 3.34|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 191|Cena: 3.47|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 192|Cena: 3.63|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 193|Cena: 3.83|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 194|Cena: 3.96|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 195|Cena: 4.14|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 196|Cena: 4.36|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 197|Cena: 4.52|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 198|Cena: 4.72|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 199|Cena: 4.90|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 200|Cena: 5.10|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 201|Cena: 5.31|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 202|Cena: 5.47|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 203|Cena: 5.67|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 204|Cena: 5.80|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 205|Cena: 6.02|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 206|Cena: 6.18|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 207|Cena: 6.34|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 208|Cena: 6.51|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 209|Cena: 6.68|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 210|Cena: 6.86|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 211|Cena: 6.96|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 212|Cena: 7.13|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 213|Cena: 7.24|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 214|Cena: 7.37|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 215|Cena: 7.51|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 216|Cena: 7.60|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 217|Cena: 7.70|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 218|Cena: 7.75|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 219|Cena: 7.81|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 220|Cena: 7.88|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 221|Cena: 7.93|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 222|Cena: 7.97|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 223|Cena: 7.97|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 224|Cena: 8.00|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 225|Cena: 8.00|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 226|Cena: 8.04|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 227|Cena: 8.00|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 228|Cena: 7.91|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 229|Cena: 7.87|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 230|Cena: 7.79|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 231|Cena: 7.74|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 232|Cena: 7.67|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 233|Cena: 7.60|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 234|Cena: 7.46|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 235|Cena: 7.35|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 236|Cena: 7.20|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 237|Cena: 7.11|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 238|Cena: 6.95|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 239|Cena: 6.81|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 240|Cena: 6.65|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 241|Cena: 6.51|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 242|Cena: 6.31|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 243|Cena: 6.14|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 244|Cena: 6.04|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 245|Cena: 5.79|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 246|Cena: 5.61|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 247|Cena: 5.48|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 248|Cena: 5.32|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 249|Cena: 5.05|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 250|Cena: 4.87|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 251|Cena: 4.70|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 252|Cena: 4.54|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 253|Cena: 4.30|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 254|Cena: 4.13|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 255|Cena: 3.97|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 256|Cena: 3.79|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 257|Cena: 3.61|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 258|Cena: 3.45|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 259|Cena: 3.26|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 260|Cena: 3.13|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 261|Cena: 2.99|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 262|Cena: 2.86|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 263|Cena: 2.72|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 264|Cena: 2.62|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 265|Cena: 2.52|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 266|Cena: 2.41|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 267|Cena: 2.32|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 268|Cena: 2.24|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 269|Cena: 2.17|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 270|Cena: 2.10|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 271|Cena: 2.07|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 272|Cena: 2.03|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 273|Cena: 2.05|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 274|Cena: 2.03|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 275|Cena: 2.01|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 276|Cena: 2.00|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 277|Cena: 2.02|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 278|Cena: 2.10|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 279|Cena: 2.14|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 280|Cena: 2.20|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 281|Cena: 2.23|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 282|Cena: 2.36|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 283|Cena: 2.45|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 284|Cena: 2.52|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 285|Cena: 2.65|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 286|Cena: 2.78|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 287|Cena: 2.91|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 288|Cena: 3.04|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 289|Cena: 3.19|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 290|Cena: 3.34|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 291|Cena: 3.51|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 292|Cena: 3.71|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 293|Cena: 3.80|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 294|Cena: 4.02|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 295|Cena: 4.21|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 296|Cena: 4.40|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 297|Cena: 4.57|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 298|Cena: 4.73|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 299|Cena: 4.96|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 300|Cena: 5.18|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 301|Cena: 5.30|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 302|Cena: 5.53|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 303|Cena: 5.70|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 304|Cena: 5.88|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 305|Cena: 6.04|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 306|Cena: 6.23|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 307|Cena: 6.43|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 308|Cena: 6.58|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 309|Cena: 6.76|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 310|Cena: 6.90|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 311|Cena: 7.03|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 312|Cena: 7.19|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 313|Cena: 7.29|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 314|Cena: 7.42|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 315|Cena: 7.51|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 316|Cena: 7.61|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 317|Cena: 7.68|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 318|Cena: 7.79|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 319|Cena: 7.82|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 320|Cena: 7.91|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 321|Cena: 7.94|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 322|Cena: 7.99|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 323|Cena: 8.01|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 324|Cena: 8.04|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 325|Cena: 8.01|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 326|Cena: 7.95|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 327|Cena: 7.95|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 328|Cena: 7.89|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 329|Cena: 7.85|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 330|Cena: 7.83|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 331|Cena: 7.74|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 332|Cena: 7.63|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 333|Cena: 7.53|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 334|Cena: 7.45|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 335|Cena: 7.31|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 336|Cena: 7.19|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 337|Cena: 7.08|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 338|Cena: 6.96|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 339|Cena: 6.80|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 340|Cena: 6.59|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 341|Cena: 6.48|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 342|Cena: 6.30|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 343|Cena: 6.14|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 344|Cena: 5.98|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 345|Cena: 5.73|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 346|Cena: 5.57|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 347|Cena: 5.41|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 348|Cena: 5.18|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 349|Cena: 5.05|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 350|Cena: 4.84|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 351|Cena: 4.66|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 352|Cena: 4.45|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 353|Cena: 4.29|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 354|Cena: 4.11|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 355|Cena: 3.92|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 356|Cena: 3.75|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 357|Cena: 3.58|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 358|Cena: 3.39|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 359|Cena: 3.25|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 360|Cena: 3.10|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 361|Cena: 2.97|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 362|Cena: 2.85|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 363|Cena: 2.68|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 364|Cena: 2.58|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 365|Cena: 2.51|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 366|Cena: 2.36|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 367|Cena: 2.28|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 368|Cena: 2.22|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 369|Cena: 2.17|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 370|Cena: 2.10|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 371|Cena: 2.08|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 372|Cena: 2.04|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 373|Cena: 2.02|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 374|Cena: 2.01|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 375|Cena: 2.05|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 376|Cena: 2.02|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 377|Cena: 2.01|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 378|Cena: 2.12|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: 0.00|
# Krok: 379|Cena: 2.13|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 380|Cena: 2.21|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 381|Cena: 2.31|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 382|Cena: 2.34|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 383|Cena: 2.44|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 384|Cena: 2.54|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 385|Cena: 2.67|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 386|Cena: 2.82|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 387|Cena: 2.95|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 388|Cena: 3.09|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 389|Cena: 3.20|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 390|Cena: 3.34|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 391|Cena: 3.55|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 392|Cena: 3.71|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 393|Cena: 3.90|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 394|Cena: 4.08|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 395|Cena: 4.25|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 396|Cena: 4.45|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 397|Cena: 4.63|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 398|Cena: 4.82|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 399|Cena: 4.99|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|
# Krok: 400|Cena: 4.99|Gotówka: 597.01|Akcje: 0|Wartość portfela: 597.01|Nagroda: -100.00|

# %%
results_plot_continuous(env_predict=env_predict, prices=prices)

# %%
# Tworzenie instacji środowiska
env_agent = PortfolioValueTradingEnvUpdated(prices)
env_agent = Monitor(env_agent)

# Sprawdzenie zgodności środowiska z stable_baselines3
check_env(env_agent)

logger_callback = TrainingLoggerCallback()
# Tworzenie modelu PPO
model_agent = PPO(
    "MlpPolicy",
    env_agent,
    # policy_kwargs=dict(
    #     net_arch=[
    #         128,
    #         128,
    #     ]
    # ),
    #   learning_rate=0.00005,        # domyślnie 3e-4
    n_steps=400,  # liczba kroków zanim agent zrobi aktualizację
    batch_size=100,  # batch size do uczenia
    # n_epochs=10,                 # ile razy przebiega po danych przy każdej aktualizacji
    gamma=0.3,  # współczynnik dyskontujący nagrody
    # gae_lambda=0.95,             # współczynnik GAE
    # clip_range=0.2,              # zakres klipu PPO (stabilizacja treningu)
    # ent_coef=0.9,                # zachęta do eksploracji
    verbose=1,
)

# Trening modelu
model_agent.learn(total_timesteps=30_000, callback=logger_callback)


training_plot(logger_callback=logger_callback)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -5.9e+05 |
# | time/              |          |
# |    fps             | 720      |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 400      |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.65e+05    |
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 800          |
# | train/                  |              |
# |    approx_kl            | 0.0093213245 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -1.18e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17e+07     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0281      |
# |    std                  | 0.996        |
# |    value_loss           | 2.19e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.27e+05   |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1200        |
# | train/                  |             |
# |    approx_kl            | 0.012545411 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 4.46e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.82e+06    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.991       |
# |    value_loss           | 1.17e+07    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -3.6e+05   |
# | time/                   |            |
# |    fps                  | 623        |
# |    iterations           | 4          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 1600       |
# | train/                  |            |
# |    approx_kl            | 0.01572664 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 9.2e-05    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.68e+06   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0317    |
# |    std                  | 0.984      |
# |    value_loss           | 1.23e+07   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -3.16e+05   |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2000        |
# | train/                  |             |
# |    approx_kl            | 0.017519206 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.000159    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.21e+06    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0286     |
# |    std                  | 0.974       |
# |    value_loss           | 4.79e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.82e+05   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2400        |
# | train/                  |             |
# |    approx_kl            | 0.012129638 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 9.24e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+06    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.966       |
# |    value_loss           | 4.3e+06     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.49e+05   |
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2800        |
# | train/                  |             |
# |    approx_kl            | 0.008430725 |
# |    clip_fraction        | 0.0972      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 8.3e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.99e+05    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.959       |
# |    value_loss           | 3.12e+06    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -2.2e+05   |
# | time/                   |            |
# |    fps                  | 622        |
# |    iterations           | 8          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 3200       |
# | train/                  |            |
# |    approx_kl            | 0.02741669 |
# |    clip_fraction        | 0.271      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.000107   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.06e+05   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0153    |
# |    std                  | 0.951      |
# |    value_loss           | 1.33e+06   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.99e+05   |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.008390435 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000178    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.03e+04    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00658    |
# |    std                  | 0.945       |
# |    value_loss           | 5.42e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.79e+05   |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 10          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.013699476 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000424    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.04e+04    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.941       |
# |    value_loss           | 9.69e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.63e+05   |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 11          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4400        |
# | train/                  |             |
# |    approx_kl            | 0.002861314 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -1.99       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.6        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00805    |
# |    std                  | 0.927       |
# |    value_loss           | 125         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.5e+05     |
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 12           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4800         |
# | train/                  |              |
# |    approx_kl            | 0.0022231885 |
# |    clip_fraction        | 0.00875      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -1.68        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.7         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00361     |
# |    std                  | 0.92         |
# |    value_loss           | 47.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.38e+05   |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 13          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5200        |
# | train/                  |             |
# |    approx_kl            | 0.007918258 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -6.44e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5e+05       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00568    |
# |    std                  | 0.917       |
# |    value_loss           | 2.72e+05    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -1.29e+05 |
# | time/                   |           |
# |    fps                  | 618       |
# |    iterations           | 14        |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 5600      |
# | train/                  |           |
# |    approx_kl            | 0.00887   |
# |    clip_fraction        | 0.0575    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.34     |
# |    explained_variance   | 0.207     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.22      |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -0.00842  |
# |    std                  | 0.928     |
# |    value_loss           | 9.07      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.21e+05   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 15          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.011140404 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.000443   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.03e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00109    |
# |    std                  | 0.927       |
# |    value_loss           | 2.72e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.15e+05   |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 16          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.011218334 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.000385   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 272         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00923     |
# |    std                  | 0.93        |
# |    value_loss           | 2.72e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.08e+05    |
# | time/                   |              |
# |    fps                  | 624          |
# |    iterations           | 17           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6800         |
# | train/                  |              |
# |    approx_kl            | 0.0035926152 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000248    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.53e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00575     |
# |    std                  | 0.931        |
# |    value_loss           | 5.44e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.03e+05   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 18          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 7200        |
# | train/                  |             |
# |    approx_kl            | 0.007970249 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.937       |
# |    value_loss           | 40          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -9.79e+04    |
# | time/                   |              |
# |    fps                  | 619          |
# |    iterations           | 19           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 7600         |
# | train/                  |              |
# |    approx_kl            | 0.0062546153 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000174     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.4e+05      |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00426     |
# |    std                  | 0.939        |
# |    value_loss           | 2.72e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -9.4e+04    |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 20          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.020705167 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.000672   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.05e+04    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00131     |
# |    std                  | 0.941       |
# |    value_loss           | 2.72e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -8.99e+04   |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 21          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8400        |
# | train/                  |             |
# |    approx_kl            | 0.019767206 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.000305   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.74e+04    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0144      |
# |    std                  | 0.94        |
# |    value_loss           | 5.44e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -8.58e+04   |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 22          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8800        |
# | train/                  |             |
# |    approx_kl            | 0.014699755 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -9.48e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.5        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.938       |
# |    value_loss           | 2.72e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -8.33e+04   |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 23          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 9200        |
# | train/                  |             |
# |    approx_kl            | 0.013973587 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.183       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.8        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.94        |
# |    value_loss           | 126         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -8.19e+04    |
# | time/                   |              |
# |    fps                  | 611          |
# |    iterations           | 24           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 0.0046570287 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000148    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.7e+05      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00903     |
# |    std                  | 0.941        |
# |    value_loss           | 9.7e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -8.02e+04    |
# | time/                   |              |
# |    fps                  | 609          |
# |    iterations           | 25           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0065144524 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000136     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.57e+05     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00689     |
# |    std                  | 0.941        |
# |    value_loss           | 1.57e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -7.71e+04   |
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 26          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10400       |
# | train/                  |             |
# |    approx_kl            | 0.002689982 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000147    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.6        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00801    |
# |    std                  | 0.94        |
# |    value_loss           | 1.24e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -7.53e+04   |
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 27          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10800       |
# | train/                  |             |
# |    approx_kl            | 0.008882837 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 148         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00878    |
# |    std                  | 0.94        |
# |    value_loss           | 264         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -7.29e+04   |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 28          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 11200       |
# | train/                  |             |
# |    approx_kl            | 0.011385828 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00105     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00756    |
# |    std                  | 0.94        |
# |    value_loss           | 9.33e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -7.21e+04    |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 29           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 11600        |
# | train/                  |              |
# |    approx_kl            | 0.0052084187 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.000941    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00628     |
# |    std                  | 0.94         |
# |    value_loss           | 2.72e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -7e+04       |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 30           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0060901362 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000319     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.67e+04     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0143      |
# |    std                  | 0.94         |
# |    value_loss           | 1.71e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -6.8e+04    |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 31          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 12400       |
# | train/                  |             |
# |    approx_kl            | 0.016927535 |
# |    clip_fraction        | 0.0632      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -3.76e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 394         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.94        |
# |    value_loss           | 2.73e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -6.7e+04     |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 32           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0021705525 |
# |    clip_fraction        | 0.00575      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -8.43e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5e+05        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00426     |
# |    std                  | 0.939        |
# |    value_loss           | 2.72e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -6.52e+04    |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 33           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 13200        |
# | train/                  |              |
# |    approx_kl            | 0.0013901766 |
# |    clip_fraction        | 0.00375      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 2.71e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05e+06     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00261     |
# |    std                  | 0.938        |
# |    value_loss           | 1.08e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -6.36e+04    |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 34           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 13600        |
# | train/                  |              |
# |    approx_kl            | 0.0023790414 |
# |    clip_fraction        | 0.00875      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000105    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 543          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00186     |
# |    std                  | 0.938        |
# |    value_loss           | 2.72e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -6.17e+04    |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 35           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 14000        |
# | train/                  |              |
# |    approx_kl            | 0.0033590514 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.000477    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99e+05     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0139      |
# |    std                  | 0.937        |
# |    value_loss           | 2.71e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -6.02e+04   |
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 36          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14400       |
# | train/                  |             |
# |    approx_kl            | 0.026417052 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 645         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00625    |
# |    std                  | 0.939       |
# |    value_loss           | 1.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -6.04e+04   |
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 37          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 14800       |
# | train/                  |             |
# |    approx_kl            | 0.031519663 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00221     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.42e+04    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.000249   |
# |    std                  | 0.939       |
# |    value_loss           | 2.72e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -6.03e+04    |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 38           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 15200        |
# | train/                  |              |
# |    approx_kl            | 0.0006354695 |
# |    clip_fraction        | 0.00725      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00104      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.66e+05     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00494     |
# |    std                  | 0.939        |
# |    value_loss           | 2.62e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.99e+04   |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 39          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 15600       |
# | train/                  |             |
# |    approx_kl            | 0.001686423 |
# |    clip_fraction        | 0.00375     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000346    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.41e+05    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00375    |
# |    std                  | 0.938       |
# |    value_loss           | 2.19e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.91e+04   |
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 40          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.008003785 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00129     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+06    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.938       |
# |    value_loss           | 1.49e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.79e+04   |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 41          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16400       |
# | train/                  |             |
# |    approx_kl            | 0.008743875 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0015      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.39e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.937       |
# |    value_loss           | 7.93e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.66e+04   |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 42          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 16800       |
# | train/                  |             |
# |    approx_kl            | 0.026381068 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.000269    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 676         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00377    |
# |    std                  | 0.937       |
# |    value_loss           | 2.71e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.62e+04    |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 43           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 17200        |
# | train/                  |              |
# |    approx_kl            | 0.0049977787 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.0014      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.01e+05     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00922     |
# |    std                  | 0.936        |
# |    value_loss           | 2.73e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.51e+04    |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 44           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 17600        |
# | train/                  |              |
# |    approx_kl            | 0.0033426918 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.000648     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99e+05     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00979     |
# |    std                  | 0.935        |
# |    value_loss           | 1.09e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.51e+04   |
# | time/                   |             |
# |    fps                  | 609         |
# |    iterations           | 45          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.011768594 |
# |    clip_fraction        | 0.0737      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00293     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 347         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00763    |
# |    std                  | 0.936       |
# |    value_loss           | 2.5e+05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.47e+04   |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 46          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 18400       |
# | train/                  |             |
# |    approx_kl            | 0.013860982 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00151     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4e+06     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.937       |
# |    value_loss           | 2e+06       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.35e+04    |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 47           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 18800        |
# | train/                  |              |
# |    approx_kl            | 0.0020627212 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00274      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.19e+04     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00687     |
# |    std                  | 0.935        |
# |    value_loss           | 1.24e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.33e+04   |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 48          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.020858262 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.215       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00822    |
# |    std                  | 0.934       |
# |    value_loss           | 1.84e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.34e+04    |
# | time/                   |              |
# |    fps                  | 617          |
# |    iterations           | 49           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 19600        |
# | train/                  |              |
# |    approx_kl            | 0.0053227996 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00134      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.96e+03     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00805     |
# |    std                  | 0.933        |
# |    value_loss           | 1.51e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.22e+04   |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 50          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.011557922 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00163     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.28e+05    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00942    |
# |    std                  | 0.933       |
# |    value_loss           | 1.94e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.17e+04   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 51          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 20400       |
# | train/                  |             |
# |    approx_kl            | 0.012359852 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.81e+03    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.933       |
# |    value_loss           | 3.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.11e+04   |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 52          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 20800       |
# | train/                  |             |
# |    approx_kl            | 0.001290929 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.004       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.04e+03    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00668    |
# |    std                  | 0.933       |
# |    value_loss           | 8.59e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.05e+04   |
# ...
# |    policy_gradient_loss | -0.000371   |
# |    std                  | 0.933       |
# |    value_loss           | 3.91e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.77e+04    |
# | time/                   |              |
# |    fps                  | 633          |
# |    iterations           | 59           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 23600        |
# | train/                  |              |
# |    approx_kl            | 0.0014758399 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.000941     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.81e+05     |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00169     |
# |    std                  | 0.932        |
# |    value_loss           | 2.83e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.73e+04   |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 60          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 24000       |
# | train/                  |             |
# |    approx_kl            | 0.011941243 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0016      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00327    |
# |    std                  | 0.932       |
# |    value_loss           | 2.74e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.74e+04    |
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 61           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 24400        |
# | train/                  |              |
# |    approx_kl            | 0.0054583796 |
# |    clip_fraction        | 0.00925      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00104      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.68e+04     |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00343     |
# |    std                  | 0.931        |
# |    value_loss           | 8.14e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.72e+04   |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 62          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 24800       |
# | train/                  |             |
# |    approx_kl            | 0.058183916 |
# |    clip_fraction        | 0.066       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00291     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.85e+06    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.931       |
# |    value_loss           | 1.98e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.66e+04   |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 63          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 25200       |
# | train/                  |             |
# |    approx_kl            | 0.048356377 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00188     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+06    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.93        |
# |    value_loss           | 1.09e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.58e+04   |
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 64          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.020706935 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.000578   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.38e+05    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00502    |
# |    std                  | 0.93        |
# |    value_loss           | 2.71e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.59e+04   |
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 65          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 26000       |
# | train/                  |             |
# |    approx_kl            | 0.024845373 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 936         |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.012      |
# |    std                  | 0.928       |
# |    value_loss           | 2.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.56e+04   |
# | time/                   |             |
# |    fps                  | 636         |
# |    iterations           | 66          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 26400       |
# | train/                  |             |
# |    approx_kl            | 0.009477497 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00149     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.36e+05    |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.00732    |
# |    std                  | 0.928       |
# |    value_loss           | 2.14e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.5e+04     |
# | time/                   |              |
# |    fps                  | 637          |
# |    iterations           | 67           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 26800        |
# | train/                  |              |
# |    approx_kl            | 0.0050810385 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.000668    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.02e+05     |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.00114     |
# |    std                  | 0.927        |
# |    value_loss           | 9.69e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.44e+04    |
# | time/                   |              |
# |    fps                  | 638          |
# |    iterations           | 68           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 27200        |
# | train/                  |              |
# |    approx_kl            | 0.0030604233 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000165     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+03      |
# |    n_updates            | 670          |
# |    policy_gradient_loss | -0.00455     |
# |    std                  | 0.926        |
# |    value_loss           | 2.76e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.38e+04    |
# | time/                   |              |
# |    fps                  | 638          |
# |    iterations           | 69           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 27600        |
# | train/                  |              |
# |    approx_kl            | 0.0016500396 |
# |    clip_fraction        | 0.00325      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00199      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.54e+03     |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.00257     |
# |    std                  | 0.926        |
# |    value_loss           | 2.77e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.35e+04   |
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 70          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 28000       |
# | train/                  |             |
# |    approx_kl            | 0.004384374 |
# |    clip_fraction        | 0.0095      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00343     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.14e+03    |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00235    |
# |    std                  | 0.925       |
# |    value_loss           | 2.76e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.32e+04   |
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 71          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 28400       |
# | train/                  |             |
# |    approx_kl            | 0.000374192 |
# |    clip_fraction        | 0.00025     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00258     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+06    |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.00144    |
# |    std                  | 0.925       |
# |    value_loss           | 8.18e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.25e+04    |
# | time/                   |              |
# |    fps                  | 639          |
# |    iterations           | 72           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 28800        |
# | train/                  |              |
# |    approx_kl            | 0.0023291989 |
# |    clip_fraction        | 0.00875      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00242      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99e+05     |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.00539     |
# |    std                  | 0.924        |
# |    value_loss           | 9.5e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.21e+04   |
# | time/                   |             |
# |    fps                  | 639         |
# |    iterations           | 73          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 29200       |
# | train/                  |             |
# |    approx_kl            | 0.003568202 |
# |    clip_fraction        | 0.00975     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.185       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.32e+03    |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00241    |
# |    std                  | 0.924       |
# |    value_loss           | 5.37e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -4.21e+04  |
# | time/                   |            |
# |    fps                  | 639        |
# |    iterations           | 74         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 29600      |
# | train/                  |            |
# |    approx_kl            | 0.00402035 |
# |    clip_fraction        | 0.0127     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.00381    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.94e+03   |
# |    n_updates            | 730        |
# |    policy_gradient_loss | -0.00187   |
# |    std                  | 0.923      |
# |    value_loss           | 5.26e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.16e+04   |
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 75          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.012646271 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00286     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87e+06    |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.00545    |
# |    std                  | 0.922       |
# |    value_loss           | 2.14e+06    |
# -----------------------------------------

# %%
env_predict, lista = predict_data_env(
    env=PortfolioValueTradingEnvUpdated, data=prices, agent=model_agent
)
# Out:
# Krok: 1|Cena: 5.17|Gotówka: 4.88|Akcje: 19|Wartość portfela: 103.08|Nagroda: 0.38|
# Krok: 2|Cena: 5.39|Gotówka: 4.88|Akcje: 19|Wartość portfela: 107.33|Nagroda: 3.08|
# Krok: 3|Cena: 5.58|Gotówka: 4.88|Akcje: 19|Wartość portfela: 110.95|Nagroda: 4.25|
# Krok: 4|Cena: 5.71|Gotówka: 4.88|Akcje: 19|Wartość portfela: 113.35|Nagroda: 3.62|
# Krok: 5|Cena: 5.90|Gotówka: 4.88|Akcje: 19|Wartość portfela: 117.05|Nagroda: 2.40|
# Krok: 6|Cena: 6.11|Gotówka: 4.88|Akcje: 19|Wartość portfela: 120.97|Nagroda: 3.69|
# Krok: 7|Cena: 6.27|Gotówka: 4.88|Akcje: 19|Wartość portfela: 124.09|Nagroda: 3.92|
# Krok: 8|Cena: 6.45|Gotówka: 4.88|Akcje: 19|Wartość portfela: 127.40|Nagroda: 3.12|
# Krok: 9|Cena: 6.59|Gotówka: 4.88|Akcje: 19|Wartość portfela: 130.17|Nagroda: 3.31|
# Krok: 10|Cena: 6.78|Gotówka: 4.88|Akcje: 19|Wartość portfela: 133.79|Nagroda: 2.77|
# Krok: 11|Cena: 6.93|Gotówka: 4.88|Akcje: 19|Wartość portfela: 136.59|Nagroda: 3.62|
# Krok: 12|Cena: 7.06|Gotówka: 4.88|Akcje: 19|Wartość portfela: 139.01|Nagroda: 2.79|
# Krok: 13|Cena: 7.21|Gotówka: 4.88|Akcje: 19|Wartość portfela: 141.94|Nagroda: 2.42|
# Krok: 14|Cena: 7.33|Gotówka: 4.88|Akcje: 19|Wartość portfela: 144.06|Nagroda: 2.94|
# Krok: 15|Cena: 7.41|Gotówka: 4.88|Akcje: 19|Wartość portfela: 145.75|Nagroda: 2.12|
# Krok: 16|Cena: 7.54|Gotówka: 4.88|Akcje: 19|Wartość portfela: 148.23|Nagroda: 1.69|
# Krok: 17|Cena: 7.61|Gotówka: 4.88|Akcje: 19|Wartość portfela: 149.54|Nagroda: 2.48|
# Krok: 18|Cena: 7.74|Gotówka: 4.88|Akcje: 19|Wartość portfela: 151.86|Nagroda: 1.31|
# Krok: 19|Cena: 7.79|Gotówka: 4.88|Akcje: 19|Wartość portfela: 152.93|Nagroda: 2.32|
# Krok: 20|Cena: 7.85|Gotówka: 4.88|Akcje: 19|Wartość portfela: 154.08|Nagroda: 1.06|
# Krok: 21|Cena: 7.89|Gotówka: 4.88|Akcje: 19|Wartość portfela: 154.88|Nagroda: 1.15|
# Krok: 22|Cena: 7.97|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.38|Nagroda: 0.80|
# Krok: 23|Cena: 7.97|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.40|Nagroda: 1.49|
# Krok: 24|Cena: 7.99|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.62|Nagroda: 0.03|
# Krok: 25|Cena: 7.99|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.75|Nagroda: 0.22|
# Krok: 26|Cena: 8.00|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.96|Nagroda: 0.13|
# Krok: 27|Cena: 7.98|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.54|Nagroda: 0.21|
# Krok: 28|Cena: 7.95|Gotówka: 140.58|Akcje: 2|Wartość portfela: 156.48|Nagroda: -0.04|
# Krok: 29|Cena: 7.91|Gotówka: 140.58|Akcje: 2|Wartość portfela: 156.40|Nagroda: -0.06|
# Krok: 30|Cena: 7.89|Gotówka: 140.58|Akcje: 2|Wartość portfela: 156.36|Nagroda: -0.08|
# Krok: 31|Cena: 7.78|Gotówka: 140.58|Akcje: 2|Wartość portfela: 156.13|Nagroda: -0.04|
# Krok: 32|Cena: 7.70|Gotówka: 140.58|Akcje: 2|Wartość portfela: 155.97|Nagroda: -0.23|
# Krok: 33|Cena: 7.61|Gotówka: 140.58|Akcje: 2|Wartość portfela: 155.79|Nagroda: -0.16|
# Krok: 34|Cena: 7.54|Gotówka: 140.58|Akcje: 2|Wartość portfela: 155.65|Nagroda: -0.19|
# Krok: 35|Cena: 7.44|Gotówka: 140.58|Akcje: 2|Wartość portfela: 155.46|Nagroda: -0.14|
# Krok: 36|Cena: 7.30|Gotówka: 140.58|Akcje: 2|Wartość portfela: 155.18|Nagroda: -0.19|
# Krok: 37|Cena: 7.16|Gotówka: 140.58|Akcje: 2|Wartość portfela: 154.89|Nagroda: -0.28|
# Krok: 38|Cena: 7.02|Gotówka: 140.58|Akcje: 2|Wartość portfela: 154.63|Nagroda: -0.28|
# Krok: 39|Cena: 6.91|Gotówka: 140.58|Akcje: 2|Wartość portfela: 154.40|Nagroda: -0.27|
# Krok: 40|Cena: 6.76|Gotówka: 140.58|Akcje: 2|Wartość portfela: 154.10|Nagroda: -0.23|
# Krok: 41|Cena: 6.60|Gotówka: 140.58|Akcje: 2|Wartość portfela: 153.78|Nagroda: -0.30|
# Krok: 42|Cena: 6.41|Gotówka: 140.58|Akcje: 2|Wartość portfela: 153.41|Nagroda: -0.32|
# Krok: 43|Cena: 6.26|Gotówka: 140.58|Akcje: 2|Wartość portfela: 153.11|Nagroda: -0.37|
# Krok: 44|Cena: 6.09|Gotówka: 140.58|Akcje: 2|Wartość portfela: 152.75|Nagroda: -0.30|
# Krok: 45|Cena: 5.91|Gotówka: 140.58|Akcje: 2|Wartość portfela: 152.40|Nagroda: -0.35|
# Krok: 46|Cena: 5.74|Gotówka: 140.58|Akcje: 2|Wartość portfela: 152.06|Nagroda: -0.35|
# Krok: 47|Cena: 5.54|Gotówka: 140.58|Akcje: 2|Wartość portfela: 151.67|Nagroda: -0.34|
# Krok: 48|Cena: 5.37|Gotówka: 140.58|Akcje: 2|Wartość portfela: 151.31|Nagroda: -0.40|
# Krok: 49|Cena: 5.17|Gotówka: 140.58|Akcje: 2|Wartość portfela: 150.91|Nagroda: -0.36|
# Krok: 50|Cena: 4.98|Gotówka: 140.58|Akcje: 2|Wartość portfela: 150.54|Nagroda: -0.40|
# Krok: 51|Cena: 4.80|Gotówka: 140.58|Akcje: 2|Wartość portfela: 150.18|Nagroda: -0.37|
# Krok: 52|Cena: 4.57|Gotówka: 140.58|Akcje: 2|Wartość portfela: 149.72|Nagroda: -0.36|
# Krok: 53|Cena: 4.41|Gotówka: 145.15|Akcje: 1|Wartość portfela: 149.56|Nagroda: -0.23|
# Krok: 54|Cena: 4.22|Gotówka: 145.15|Akcje: 1|Wartość portfela: 149.37|Nagroda: -0.16|
# Krok: 55|Cena: 4.04|Gotówka: 145.15|Akcje: 1|Wartość portfela: 149.18|Nagroda: -0.19|
# Krok: 56|Cena: 3.87|Gotówka: 145.15|Akcje: 1|Wartość portfela: 149.01|Nagroda: -0.18|
# Krok: 57|Cena: 3.73|Gotówka: 145.15|Akcje: 1|Wartość portfela: 148.88|Nagroda: -0.17|
# Krok: 58|Cena: 3.51|Gotówka: 145.15|Akcje: 1|Wartość portfela: 148.66|Nagroda: -0.14|
# Krok: 59|Cena: 3.39|Gotówka: 145.15|Akcje: 1|Wartość portfela: 148.54|Nagroda: -0.21|
# Krok: 60|Cena: 3.18|Gotówka: 145.15|Akcje: 1|Wartość portfela: 148.33|Nagroda: -0.13|
# Krok: 61|Cena: 3.06|Gotówka: 145.15|Akcje: 1|Wartość portfela: 148.21|Nagroda: -0.21|
# Krok: 62|Cena: 2.93|Gotówka: 145.15|Akcje: 1|Wartość portfela: 148.08|Nagroda: -0.12|
# Krok: 63|Cena: 2.80|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.95|Nagroda: -0.13|
# Krok: 64|Cena: 2.68|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.83|Nagroda: -0.12|
# Krok: 65|Cena: 2.57|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.72|Nagroda: -0.12|
# Krok: 66|Cena: 2.44|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.59|Nagroda: -0.11|
# Krok: 67|Cena: 2.35|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.50|Nagroda: -0.13|
# Krok: 68|Cena: 2.29|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.44|Nagroda: -0.10|
# Krok: 69|Cena: 2.20|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.34|Nagroda: -0.06|
# Krok: 70|Cena: 2.11|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.26|Nagroda: -0.09|
# Krok: 71|Cena: 2.06|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.21|Nagroda: -0.08|
# Krok: 72|Cena: 2.03|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.18|Nagroda: -0.05|
# Krok: 73|Cena: 2.03|Gotówka: 145.15|Akcje: 1|Wartość portfela: 147.18|Nagroda: -0.03|
# Krok: 74|Cena: 2.01|Gotówka: 3.09|Akcje: 71|Wartość portfela: 145.57|Nagroda: 0.06|
# Krok: 75|Cena: 2.01|Gotówka: 145.57|Akcje: 0|Wartość portfela: 145.57|Nagroda: 0.00|
# Krok: 76|Cena: 2.00|Gotówka: 2.57|Akcje: 71|Wartość portfela: 144.56|Nagroda: 0.51|
# Krok: 77|Cena: 2.03|Gotówka: 144.56|Akcje: 0|Wartość portfela: 144.56|Nagroda: 0.00|
# Krok: 78|Cena: 2.07|Gotówka: 2.35|Akcje: 70|Wartość portfela: 147.44|Nagroda: 2.22|
# Krok: 79|Cena: 2.10|Gotówka: 0.28|Akcje: 71|Wartość portfela: 149.20|Nagroda: 2.92|
# Krok: 80|Cena: 2.17|Gotówka: 0.28|Akcje: 71|Wartość portfela: 154.19|Nagroda: 1.76|
# Krok: 81|Cena: 2.21|Gotówka: 0.28|Akcje: 71|Wartość portfela: 157.31|Nagroda: 4.99|
# Krok: 82|Cena: 2.29|Gotówka: 0.28|Akcje: 71|Wartość portfela: 163.22|Nagroda: 3.12|
# Krok: 83|Cena: 2.38|Gotówka: 0.28|Akcje: 71|Wartość portfela: 169.44|Nagroda: 5.91|
# Krok: 84|Cena: 2.46|Gotówka: 0.28|Akcje: 71|Wartość portfela: 175.26|Nagroda: 6.22|
# Krok: 85|Cena: 2.61|Gotówka: 0.28|Akcje: 71|Wartość portfela: 185.34|Nagroda: 5.82|
# Krok: 86|Cena: 2.71|Gotówka: 0.28|Akcje: 71|Wartość portfela: 192.34|Nagroda: 10.08|
# Krok: 87|Cena: 2.84|Gotówka: 0.28|Akcje: 71|Wartość portfela: 202.04|Nagroda: 7.01|
# Krok: 88|Cena: 2.99|Gotówka: 0.28|Akcje: 71|Wartość portfela: 212.32|Nagroda: 9.69|
# Krok: 89|Cena: 3.13|Gotówka: 0.28|Akcje: 71|Wartość portfela: 222.45|Nagroda: 10.28|
# Krok: 90|Cena: 3.28|Gotówka: 0.28|Akcje: 71|Wartość portfela: 233.48|Nagroda: 10.14|
# Krok: 91|Cena: 3.43|Gotówka: 0.28|Akcje: 71|Wartość portfela: 243.59|Nagroda: 11.03|
# Krok: 92|Cena: 3.58|Gotówka: 0.28|Akcje: 71|Wartość portfela: 254.78|Nagroda: 10.12|
# Krok: 93|Cena: 3.76|Gotówka: 0.28|Akcje: 71|Wartość portfela: 267.30|Nagroda: 11.18|
# Krok: 94|Cena: 3.90|Gotówka: 0.28|Akcje: 71|Wartość portfela: 277.41|Nagroda: 12.53|
# Krok: 95|Cena: 4.09|Gotówka: 0.28|Akcje: 71|Wartość portfela: 290.44|Nagroda: 10.11|
# Krok: 96|Cena: 4.27|Gotówka: 0.28|Akcje: 71|Wartość portfela: 303.55|Nagroda: 13.03|
# Krok: 97|Cena: 4.46|Gotówka: 0.28|Akcje: 71|Wartość portfela: 317.15|Nagroda: 13.11|
# Krok: 98|Cena: 4.68|Gotówka: 0.28|Akcje: 71|Wartość portfela: 332.41|Nagroda: 13.60|
# Krok: 99|Cena: 4.84|Gotówka: 0.28|Akcje: 71|Wartość portfela: 343.93|Nagroda: 15.26|
# Krok: 100|Cena: 5.04|Gotówka: 0.28|Akcje: 71|Wartość portfela: 358.09|Nagroda: 11.52|
# Krok: 101|Cena: 5.26|Gotówka: 0.28|Akcje: 71|Wartość portfela: 373.87|Nagroda: 14.16|
# Krok: 102|Cena: 5.42|Gotówka: 0.28|Akcje: 71|Wartość portfela: 384.86|Nagroda: 15.78|
# Krok: 103|Cena: 5.62|Gotówka: 0.28|Akcje: 71|Wartość portfela: 399.62|Nagroda: 10.98|
# Krok: 104|Cena: 5.77|Gotówka: 0.28|Akcje: 71|Wartość portfela: 410.29|Nagroda: 14.77|
# Krok: 105|Cena: 5.97|Gotówka: 0.28|Akcje: 71|Wartość portfela: 424.14|Nagroda: 10.67|
# Krok: 106|Cena: 6.13|Gotówka: 0.28|Akcje: 71|Wartość portfela: 435.63|Nagroda: 13.85|
# Krok: 107|Cena: 6.32|Gotówka: 0.28|Akcje: 71|Wartość portfela: 448.72|Nagroda: 11.49|
# Krok: 108|Cena: 6.51|Gotówka: 0.28|Akcje: 71|Wartość portfela: 462.24|Nagroda: 13.09|
# Krok: 109|Cena: 6.62|Gotówka: 0.28|Akcje: 71|Wartość portfela: 470.02|Nagroda: 13.52|
# Krok: 110|Cena: 6.81|Gotówka: 0.28|Akcje: 71|Wartość portfela: 484.06|Nagroda: 7.78|
# Krok: 111|Cena: 6.96|Gotówka: 0.28|Akcje: 71|Wartość portfela: 494.23|Nagroda: 14.03|
# Krok: 112|Cena: 7.08|Gotówka: 0.28|Akcje: 71|Wartość portfela: 502.96|Nagroda: 10.18|
# Krok: 113|Cena: 7.19|Gotówka: 0.28|Akcje: 71|Wartość portfela: 511.06|Nagroda: 8.72|
# Krok: 114|Cena: 7.35|Gotówka: 0.28|Akcje: 71|Wartość portfela: 521.91|Nagroda: 8.11|
# Krok: 115|Cena: 7.45|Gotówka: 0.28|Akcje: 71|Wartość portfela: 529.08|Nagroda: 10.85|
# Krok: 116|Cena: 7.57|Gotówka: 0.28|Akcje: 71|Wartość portfela: 537.50|Nagroda: 7.18|
# Krok: 117|Cena: 7.66|Gotówka: 0.28|Akcje: 71|Wartość portfela: 543.82|Nagroda: 8.42|
# Krok: 118|Cena: 7.77|Gotówka: 0.28|Akcje: 71|Wartość portfela: 551.93|Nagroda: 6.32|
# Krok: 119|Cena: 7.80|Gotówka: 0.28|Akcje: 71|Wartość portfela: 554.41|Nagroda: 8.11|
# Krok: 120|Cena: 7.85|Gotówka: 0.28|Akcje: 71|Wartość portfela: 557.60|Nagroda: 2.48|
# Krok: 121|Cena: 7.92|Gotówka: 0.28|Akcje: 71|Wartość portfela: 562.81|Nagroda: 3.19|
# Krok: 122|Cena: 7.96|Gotówka: 0.28|Akcje: 71|Wartość portfela: 565.54|Nagroda: 5.21|
# Krok: 123|Cena: 8.01|Gotówka: 0.28|Akcje: 71|Wartość portfela: 569.00|Nagroda: 2.73|
# Krok: 124|Cena: 8.01|Gotówka: 0.28|Akcje: 71|Wartość portfela: 569.26|Nagroda: 3.46|
# Krok: 125|Cena: 8.01|Gotówka: 0.28|Akcje: 71|Wartość portfela: 568.74|Nagroda: 0.26|
# Krok: 126|Cena: 8.02|Gotówka: 0.28|Akcje: 71|Wartość portfela: 569.63|Nagroda: -0.52|
# Krok: 127|Cena: 7.94|Gotówka: 0.28|Akcje: 71|Wartość portfela: 564.33|Nagroda: 0.88|
# Krok: 128|Cena: 7.92|Gotówka: 500.78|Akcje: 8|Wartość portfela: 564.15|Nagroda: -0.60|
# Krok: 129|Cena: 7.87|Gotówka: 508.70|Akcje: 7|Wartość portfela: 563.80|Nagroda: -0.16|
# Krok: 130|Cena: 7.83|Gotówka: 516.57|Akcje: 6|Wartość portfela: 563.52|Nagroda: -0.30|
# Krok: 131|Cena: 7.74|Gotówka: 532.22|Akcje: 4|Wartość portfela: 563.18|Nagroda: -0.18|
# Krok: 132|Cena: 7.70|Gotówka: 539.96|Akcje: 3|Wartość portfela: 563.06|Nagroda: -0.26|
# Krok: 133|Cena: 7.59|Gotówka: 547.66|Akcje: 2|Wartość portfela: 562.85|Nagroda: -0.08|
# Krok: 134|Cena: 7.47|Gotówka: 547.66|Akcje: 2|Wartość portfela: 562.60|Nagroda: -0.21|
# Krok: 135|Cena: 7.37|Gotówka: 547.66|Akcje: 2|Wartość portfela: 562.40|Nagroda: -0.25|
# Krok: 136|Cena: 7.28|Gotówka: 547.66|Akcje: 2|Wartość portfela: 562.21|Nagroda: -0.20|
# Krok: 137|Cena: 7.16|Gotówka: 547.66|Akcje: 2|Wartość portfela: 561.98|Nagroda: -0.18|
# Krok: 138|Cena: 7.05|Gotówka: 547.66|Akcje: 2|Wartość portfela: 561.75|Nagroda: -0.23|
# Krok: 139|Cena: 6.92|Gotówka: 547.66|Akcje: 2|Wartość portfela: 561.50|Nagroda: -0.23|
# Krok: 140|Cena: 6.72|Gotówka: 547.66|Akcje: 2|Wartość portfela: 561.10|Nagroda: -0.25|
# Krok: 141|Cena: 6.53|Gotówka: 547.66|Akcje: 2|Wartość portfela: 560.72|Nagroda: -0.40|
# Krok: 142|Cena: 6.34|Gotówka: 547.66|Akcje: 2|Wartość portfela: 560.35|Nagroda: -0.37|
# Krok: 143|Cena: 6.22|Gotówka: 547.66|Akcje: 2|Wartość portfela: 560.10|Nagroda: -0.38|
# Krok: 144|Cena: 6.02|Gotówka: 547.66|Akcje: 2|Wartość portfela: 559.71|Nagroda: -0.24|
# Krok: 145|Cena: 5.85|Gotówka: 547.66|Akcje: 2|Wartość portfela: 559.37|Nagroda: -0.39|
# Krok: 146|Cena: 5.67|Gotówka: 547.66|Akcje: 2|Wartość portfela: 558.99|Nagroda: -0.34|
# Krok: 147|Cena: 5.49|Gotówka: 547.66|Akcje: 2|Wartość portfela: 558.64|Nagroda: -0.37|
# Krok: 148|Cena: 5.33|Gotówka: 547.66|Akcje: 2|Wartość portfela: 558.32|Nagroda: -0.35|
# Krok: 149|Cena: 5.12|Gotówka: 547.66|Akcje: 2|Wartość portfela: 557.90|Nagroda: -0.33|
# Krok: 150|Cena: 4.93|Gotówka: 547.66|Akcje: 2|Wartość portfela: 557.51|Nagroda: -0.41|
# Krok: 151|Cena: 4.72|Gotówka: 547.66|Akcje: 2|Wartość portfela: 557.10|Nagroda: -0.39|
# Krok: 152|Cena: 4.52|Gotówka: 547.66|Akcje: 2|Wartość portfela: 556.70|Nagroda: -0.41|
# Krok: 153|Cena: 4.36|Gotówka: 547.66|Akcje: 2|Wartość portfela: 556.37|Nagroda: -0.40|
# Krok: 154|Cena: 4.18|Gotówka: 547.66|Akcje: 2|Wartość portfela: 556.03|Nagroda: -0.32|
# Krok: 155|Cena: 4.04|Gotówka: 547.66|Akcje: 2|Wartość portfela: 555.74|Nagroda: -0.35|
# Krok: 156|Cena: 3.83|Gotówka: 547.66|Akcje: 2|Wartość portfela: 555.32|Nagroda: -0.29|
# Krok: 157|Cena: 3.68|Gotówka: 547.66|Akcje: 2|Wartość portfela: 555.01|Nagroda: -0.42|
# Krok: 158|Cena: 3.48|Gotówka: 547.66|Akcje: 2|Wartość portfela: 554.62|Nagroda: -0.31|
# Krok: 159|Cena: 3.31|Gotówka: 547.66|Akcje: 2|Wartość portfela: 554.27|Nagroda: -0.39|
# Krok: 160|Cena: 3.16|Gotówka: 547.66|Akcje: 2|Wartość portfela: 553.97|Nagroda: -0.35|
# Krok: 161|Cena: 3.02|Gotówka: 547.66|Akcje: 2|Wartość portfela: 553.69|Nagroda: -0.30|
# Krok: 162|Cena: 2.93|Gotówka: 547.66|Akcje: 2|Wartość portfela: 553.53|Nagroda: -0.28|
# Krok: 163|Cena: 2.74|Gotówka: 547.66|Akcje: 2|Wartość portfela: 553.15|Nagroda: -0.16|
# Krok: 164|Cena: 2.66|Gotówka: 547.66|Akcje: 2|Wartość portfela: 552.97|Nagroda: -0.38|
# Krok: 165|Cena: 2.51|Gotówka: 547.66|Akcje: 2|Wartość portfela: 552.68|Nagroda: -0.18|
# Krok: 166|Cena: 2.44|Gotówka: 547.66|Akcje: 2|Wartość portfela: 552.55|Nagroda: -0.29|
# Krok: 167|Cena: 2.34|Gotówka: 547.66|Akcje: 2|Wartość portfela: 552.34|Nagroda: -0.13|
# Krok: 168|Cena: 2.25|Gotówka: 547.66|Akcje: 2|Wartość portfela: 552.16|Nagroda: -0.21|
# Krok: 169|Cena: 2.18|Gotówka: 547.66|Akcje: 2|Wartość portfela: 552.02|Nagroda: -0.18|
# Krok: 170|Cena: 2.11|Gotówka: 547.66|Akcje: 2|Wartość portfela: 551.88|Nagroda: -0.14|
# Krok: 171|Cena: 2.08|Gotówka: 547.66|Akcje: 2|Wartość portfela: 551.83|Nagroda: -0.14|
# Krok: 172|Cena: 2.03|Gotówka: 547.66|Akcje: 2|Wartość portfela: 551.72|Nagroda: -0.05|
# Krok: 173|Cena: 1.99|Gotówka: 547.66|Akcje: 2|Wartość portfela: 551.64|Nagroda: -0.11|
# Krok: 174|Cena: 1.98|Gotówka: 547.66|Akcje: 2|Wartość portfela: 551.61|Nagroda: -0.08|
# Krok: 175|Cena: 2.00|Gotówka: 547.66|Akcje: 2|Wartość portfela: 551.67|Nagroda: -0.03|
# Krok: 176|Cena: 2.04|Gotówka: 136.72|Akcje: 207|Wartość portfela: 559.80|Nagroda: 5.85|
# Krok: 177|Cena: 2.04|Gotówka: 1.82|Akcje: 273|Wartość portfela: 558.33|Nagroda: 10.72|
# Krok: 178|Cena: 2.07|Gotówka: 407.48|Akcje: 74|Wartość portfela: 560.49|Nagroda: -0.40|
# Krok: 179|Cena: 2.12|Gotówka: 14.62|Akcje: 264|Wartość portfela: 574.87|Nagroda: 7.71|
# Krok: 180|Cena: 2.20|Gotówka: 1.89|Akcje: 270|Wartość portfela: 595.99|Nagroda: 14.71|
# Krok: 181|Cena: 2.25|Gotówka: 1.89|Akcje: 270|Wartość portfela: 608.76|Nagroda: 21.12|
# Krok: 182|Cena: 2.32|Gotówka: 1.89|Akcje: 270|Wartość portfela: 626.95|Nagroda: 12.77|
# Krok: 183|Cena: 2.44|Gotówka: 1.89|Akcje: 270|Wartość portfela: 659.60|Nagroda: 18.19|
# Krok: 184|Cena: 2.52|Gotówka: 1.89|Akcje: 270|Wartość portfela: 683.16|Nagroda: 32.65|
# Krok: 185|Cena: 2.66|Gotówka: 1.89|Akcje: 270|Wartość portfela: 719.03|Nagroda: 23.57|
# Krok: 186|Cena: 2.75|Gotówka: 1.89|Akcje: 270|Wartość portfela: 744.15|Nagroda: 35.86|
# Krok: 187|Cena: 2.85|Gotówka: 1.89|Akcje: 270|Wartość portfela: 771.40|Nagroda: 25.13|
# Krok: 188|Cena: 2.98|Gotówka: 1.89|Akcje: 270|Wartość portfela: 807.74|Nagroda: 27.24|
# Krok: 189|Cena: 3.19|Gotówka: 1.89|Akcje: 270|Wartość portfela: 863.29|Nagroda: 36.34|
# Krok: 190|Cena: 3.34|Gotówka: 1.89|Akcje: 270|Wartość portfela: 904.91|Nagroda: 55.55|
# Krok: 191|Cena: 3.47|Gotówka: 1.89|Akcje: 270|Wartość portfela: 937.67|Nagroda: 41.62|
# Krok: 192|Cena: 3.63|Gotówka: 1.89|Akcje: 270|Wartość portfela: 981.24|Nagroda: 32.76|
# Krok: 193|Cena: 3.83|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1037.33|Nagroda: 43.57|
# Krok: 194|Cena: 3.96|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1070.88|Nagroda: 56.09|
# Krok: 195|Cena: 4.14|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1120.53|Nagroda: 33.54|
# Krok: 196|Cena: 4.36|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1178.23|Nagroda: 49.65|
# Krok: 197|Cena: 4.52|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1222.73|Nagroda: 57.71|
# Krok: 198|Cena: 4.72|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1275.45|Nagroda: 44.50|
# Krok: 199|Cena: 4.90|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1325.50|Nagroda: 52.71|
# Krok: 200|Cena: 5.10|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1379.22|Nagroda: 50.06|
# Krok: 201|Cena: 5.31|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1435.91|Nagroda: 53.72|
# Krok: 202|Cena: 5.47|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1479.41|Nagroda: 56.69|
# Krok: 203|Cena: 5.67|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1532.50|Nagroda: 43.50|
# Krok: 204|Cena: 5.80|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1567.35|Nagroda: 53.09|
# Krok: 205|Cena: 6.02|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1626.67|Nagroda: 34.85|
# Krok: 206|Cena: 6.18|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1669.79|Nagroda: 59.31|
# Krok: 207|Cena: 6.34|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1713.89|Nagroda: 43.12|
# Krok: 208|Cena: 6.51|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1760.41|Nagroda: 44.11|
# Krok: 209|Cena: 6.68|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1806.38|Nagroda: 46.51|
# Krok: 210|Cena: 6.86|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1854.35|Nagroda: 45.97|
# Krok: 211|Cena: 6.96|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1881.49|Nagroda: 47.97|
# Krok: 212|Cena: 7.13|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1925.94|Nagroda: 27.14|
# Krok: 213|Cena: 7.24|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1958.00|Nagroda: 44.45|
# Krok: 214|Cena: 7.37|Gotówka: 1.89|Akcje: 270|Wartość portfela: 1991.28|Nagroda: 32.06|
# Krok: 215|Cena: 7.51|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2028.35|Nagroda: 33.28|
# Krok: 216|Cena: 7.60|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2053.07|Nagroda: 37.07|
# Krok: 217|Cena: 7.70|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2081.84|Nagroda: 24.72|
# Krok: 218|Cena: 7.75|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2095.37|Nagroda: 28.77|
# Krok: 219|Cena: 7.81|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2111.09|Nagroda: 13.53|
# Krok: 220|Cena: 7.88|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2129.25|Nagroda: 15.71|
# Krok: 221|Cena: 7.93|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2144.29|Nagroda: 18.16|
# Krok: 222|Cena: 7.97|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2153.32|Nagroda: 15.04|
# Krok: 223|Cena: 7.97|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2152.72|Nagroda: 9.03|
# Krok: 224|Cena: 8.00|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2162.07|Nagroda: -0.60|
# Krok: 225|Cena: 8.00|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2162.62|Nagroda: 9.36|
# Krok: 226|Cena: 8.04|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2171.57|Nagroda: 0.54|
# Krok: 227|Cena: 8.00|Gotówka: 1.89|Akcje: 270|Wartość portfela: 2161.50|Nagroda: 8.95|
# Krok: 228|Cena: 7.91|Gotówka: 1585.60|Akcje: 72|Wartość portfela: 2154.96|Nagroda: -2.68|
# Krok: 229|Cena: 7.87|Gotówka: 1372.09|Akcje: 99|Wartość portfela: 2151.34|Nagroda: -8.99|
# Krok: 230|Cena: 7.79|Gotówka: 18.25|Akcje: 271|Wartość portfela: 2128.92|Nagroda: -9.89|
# Krok: 231|Cena: 7.74|Gotówka: 1856.32|Akcje: 35|Wartość portfela: 2127.06|Nagroda: -2.90|
# Krok: 232|Cena: 7.67|Gotówka: 1856.32|Akcje: 35|Wartość portfela: 2124.85|Nagroda: -1.85|
# Krok: 233|Cena: 7.60|Gotówka: 1894.68|Akcje: 30|Wartość portfela: 2122.63|Nagroda: -1.90|
# Krok: 234|Cena: 7.46|Gotówka: 1940.27|Akcje: 24|Wartość portfela: 2119.25|Nagroda: -1.78|
# Krok: 235|Cena: 7.35|Gotówka: 1977.56|Akcje: 19|Wartość portfela: 2117.15|Nagroda: -2.67|
# Krok: 236|Cena: 7.20|Gotówka: 2006.95|Akcje: 15|Wartość portfela: 2114.89|Nagroda: -1.66|
# Krok: 237|Cena: 7.11|Gotówka: 2050.12|Akcje: 9|Wartość portfela: 2114.07|Nagroda: -1.36|
# Krok: 238|Cena: 6.95|Gotówka: 2071.44|Akcje: 6|Wartość portfela: 2113.13|Nagroda: -0.54|
# Krok: 239|Cena: 6.81|Gotówka: 2085.34|Akcje: 4|Wartość portfela: 2112.59|Nagroda: -0.63|
# Krok: 240|Cena: 6.65|Gotówka: 2092.15|Akcje: 3|Wartość portfela: 2112.11|Nagroda: -0.41|
# Krok: 241|Cena: 6.51|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2111.82|Nagroda: -0.32|
# Krok: 242|Cena: 6.31|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2111.42|Nagroda: -0.29|
# Krok: 243|Cena: 6.14|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2111.09|Nagroda: -0.40|
# Krok: 244|Cena: 6.04|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2110.88|Nagroda: -0.33|
# Krok: 245|Cena: 5.79|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2110.39|Nagroda: -0.21|
# Krok: 246|Cena: 5.61|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2110.03|Nagroda: -0.50|
# Krok: 247|Cena: 5.48|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2109.77|Nagroda: -0.36|
# Krok: 248|Cena: 5.32|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2109.44|Nagroda: -0.25|
# Krok: 249|Cena: 5.05|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2108.90|Nagroda: -0.33|
# Krok: 250|Cena: 4.87|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2108.55|Nagroda: -0.54|
# Krok: 251|Cena: 4.70|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2108.21|Nagroda: -0.35|
# Krok: 252|Cena: 4.54|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2107.89|Nagroda: -0.35|
# Krok: 253|Cena: 4.30|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2107.41|Nagroda: -0.32|
# Krok: 254|Cena: 4.13|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2107.07|Nagroda: -0.48|
# Krok: 255|Cena: 3.97|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2106.75|Nagroda: -0.34|
# Krok: 256|Cena: 3.79|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2106.39|Nagroda: -0.32|
# Krok: 257|Cena: 3.61|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2106.02|Nagroda: -0.36|
# Krok: 258|Cena: 3.45|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2105.70|Nagroda: -0.37|
# Krok: 259|Cena: 3.26|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2105.33|Nagroda: -0.32|
# Krok: 260|Cena: 3.13|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2105.07|Nagroda: -0.37|
# Krok: 261|Cena: 2.99|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2104.78|Nagroda: -0.26|
# Krok: 262|Cena: 2.86|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2104.53|Nagroda: -0.29|
# Krok: 263|Cena: 2.72|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2104.24|Nagroda: -0.25|
# Krok: 264|Cena: 2.62|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2104.05|Nagroda: -0.29|
# Krok: 265|Cena: 2.52|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2103.85|Nagroda: -0.20|
# Krok: 266|Cena: 2.41|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2103.61|Nagroda: -0.20|
# Krok: 267|Cena: 2.32|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2103.44|Nagroda: -0.23|
# Krok: 268|Cena: 2.24|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2103.28|Nagroda: -0.17|
# Krok: 269|Cena: 2.17|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2103.14|Nagroda: -0.17|
# Krok: 270|Cena: 2.10|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2103.00|Nagroda: -0.14|
# Krok: 271|Cena: 2.07|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2102.95|Nagroda: -0.14|
# Krok: 272|Cena: 2.03|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2102.86|Nagroda: -0.05|
# Krok: 273|Cena: 2.05|Gotówka: 2098.80|Akcje: 2|Wartość portfela: 2102.91|Nagroda: -0.08|
# Krok: 274|Cena: 2.03|Gotówka: 1158.94|Akcje: 460|Wartość portfela: 2093.68|Nagroda: 10.25|
# Krok: 275|Cena: 2.01|Gotówka: 1608.02|Akcje: 239|Wartość portfela: 2088.54|Nagroda: -4.79|
# Krok: 276|Cena: 2.00|Gotówka: 1700.51|Akcje: 193|Wartość portfela: 2086.83|Nagroda: -4.15|
# Krok: 277|Cena: 2.02|Gotówka: 1778.57|Akcje: 154|Wartość portfela: 2089.75|Nagroda: -1.36|
# Krok: 278|Cena: 2.10|Gotówka: 446.97|Akcje: 813|Wartość portfela: 2157.84|Nagroda: 15.42|
# Krok: 279|Cena: 2.14|Gotówka: 5.05|Akcje: 1023|Wartość portfela: 2189.24|Nagroda: 85.68|
# Krok: 280|Cena: 2.20|Gotówka: 2.92|Akcje: 1024|Wartość portfela: 2255.79|Nagroda: 31.43|
# Krok: 281|Cena: 2.23|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 2283.76|Nagroda: 66.62|
# Krok: 282|Cena: 2.36|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 2423.25|Nagroda: 27.97|
# Krok: 283|Cena: 2.45|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 2509.06|Nagroda: 139.49|
# Krok: 284|Cena: 2.52|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 2582.90|Nagroda: 85.81|
# Krok: 285|Cena: 2.65|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 2711.92|Nagroda: 73.84|
# Krok: 286|Cena: 2.78|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 2852.44|Nagroda: 129.02|
# Krok: 287|Cena: 2.91|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 2982.60|Nagroda: 140.53|
# Krok: 288|Cena: 3.04|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 3118.53|Nagroda: 130.16|
# Krok: 289|Cena: 3.19|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 3273.34|Nagroda: 135.93|
# Krok: 290|Cena: 3.34|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 3428.56|Nagroda: 154.80|
# Krok: 291|Cena: 3.51|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 3601.84|Nagroda: 155.23|
# Krok: 292|Cena: 3.71|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 3799.92|Nagroda: 173.28|
# Krok: 293|Cena: 3.80|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 3893.55|Nagroda: 198.08|
# Krok: 294|Cena: 4.02|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 4122.41|Nagroda: 93.64|
# Krok: 295|Cena: 4.21|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 4315.94|Nagroda: 228.86|
# Krok: 296|Cena: 4.40|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 4506.67|Nagroda: 193.53|
# Krok: 297|Cena: 4.57|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 4683.74|Nagroda: 190.73|
# Krok: 298|Cena: 4.73|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 4847.84|Nagroda: 177.07|
# Krok: 299|Cena: 4.96|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 5084.02|Nagroda: 164.10|
# Krok: 300|Cena: 5.18|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 5306.34|Nagroda: 236.18|
# Krok: 301|Cena: 5.30|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 5432.55|Nagroda: 222.32|
# Krok: 302|Cena: 5.53|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 5673.42|Nagroda: 126.21|
# Krok: 303|Cena: 5.70|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 5838.59|Nagroda: 240.87|
# Krok: 304|Cena: 5.88|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 6030.83|Nagroda: 165.17|
# Krok: 305|Cena: 6.04|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 6193.67|Nagroda: 192.24|
# Krok: 306|Cena: 6.23|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 6387.24|Nagroda: 162.84|
# Krok: 307|Cena: 6.43|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 6594.57|Nagroda: 193.57|
# Krok: 308|Cena: 6.58|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 6747.95|Nagroda: 207.32|
# Krok: 309|Cena: 6.76|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 6933.23|Nagroda: 153.39|
# Krok: 310|Cena: 6.90|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 7076.53|Nagroda: 185.28|
# Krok: 311|Cena: 7.03|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 7208.44|Nagroda: 143.30|
# Krok: 312|Cena: 7.19|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 7374.00|Nagroda: 131.90|
# Krok: 313|Cena: 7.29|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 7477.28|Nagroda: 165.56|
# Krok: 314|Cena: 7.42|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 7606.00|Nagroda: 103.29|
# Krok: 315|Cena: 7.51|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 7693.92|Nagroda: 128.72|
# Krok: 316|Cena: 7.61|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 7802.13|Nagroda: 87.92|
# Krok: 317|Cena: 7.68|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 7876.62|Nagroda: 108.21|
# Krok: 318|Cena: 7.79|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 7990.39|Nagroda: 74.49|
# Krok: 319|Cena: 7.82|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 8013.86|Nagroda: 113.77|
# Krok: 320|Cena: 7.91|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 8110.40|Nagroda: 23.46|
# Krok: 321|Cena: 7.94|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 8135.04|Nagroda: 96.55|
# Krok: 322|Cena: 7.99|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 8195.58|Nagroda: 24.63|
# Krok: 323|Cena: 8.01|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 8207.51|Nagroda: 60.55|
# Krok: 324|Cena: 8.04|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 8237.83|Nagroda: 11.93|
# Krok: 325|Cena: 8.01|Gotówka: 0.72|Akcje: 1025|Wartość portfela: 8211.67|Nagroda: 30.31|
# Krok: 326|Cena: 7.95|Gotówka: 4959.33|Akcje: 406|Wartość portfela: 8186.64|Nagroda: -10.36|
# Krok: 327|Cena: 7.95|Gotówka: 54.78|Akcje: 1023|Wartość portfela: 8189.38|Nagroda: -63.08|
# Krok: 328|Cena: 7.89|Gotówka: 22.97|Akcje: 1027|Wartość portfela: 8126.49|Nagroda: 2.75|
# Krok: 329|Cena: 7.85|Gotówka: 7084.94|Akcje: 132|Wartość portfela: 8121.52|Nagroda: -8.08|
# Krok: 330|Cena: 7.83|Gotówka: 1776.42|Akcje: 808|Wartość portfela: 8104.18|Nagroda: -30.40|
# Krok: 331|Cena: 7.74|Gotówka: 22.19|Akcje: 1032|Wartość portfela: 8010.64|Nagroda: -22.15|
# Krok: 332|Cena: 7.63|Gotówka: 6988.87|Akcje: 132|Wartość portfela: 7996.03|Nagroda: -11.96|
# Krok: 333|Cena: 7.53|Gotówka: 7202.51|Akcje: 104|Wartość portfela: 7985.55|Nagroda: -11.51|
# Krok: 334|Cena: 7.45|Gotówka: 7368.15|Akcje: 82|Wartość portfela: 7978.69|Nagroda: -8.26|
# Krok: 335|Cena: 7.31|Gotówka: 7487.28|Akcje: 66|Wartość portfela: 7969.50|Nagroda: -5.52|
# Krok: 336|Cena: 7.19|Gotówka: 7589.57|Akcje: 52|Wartość portfela: 7963.64|Nagroda: -7.24|
# Krok: 337|Cena: 7.08|Gotówka: 7668.70|Akcje: 41|Wartość portfela: 7959.03|Nagroda: -4.62|
# Krok: 338|Cena: 6.96|Gotówka: 7789.08|Akcje: 24|Wartość portfela: 7956.06|Nagroda: -2.70|
# Krok: 339|Cena: 6.80|Gotówka: 7858.66|Akcje: 14|Wartość portfela: 7953.83|Nagroda: -1.73|
# Krok: 340|Cena: 6.59|Gotówka: 7899.45|Akcje: 8|Wartość portfela: 7952.13|Nagroda: -1.27|
# Krok: 341|Cena: 6.48|Gotówka: 7919.20|Akcje: 5|Wartość portfela: 7951.58|Nagroda: -1.07|
# Krok: 342|Cena: 6.30|Gotówka: 7932.15|Akcje: 3|Wartość portfela: 7951.06|Nagroda: -0.33|
# Krok: 343|Cena: 6.14|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7950.73|Nagroda: -0.34|
# Krok: 344|Cena: 5.98|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7950.42|Nagroda: -0.33|
# Krok: 345|Cena: 5.73|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7949.91|Nagroda: -0.31|
# Krok: 346|Cena: 5.57|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7949.60|Nagroda: -0.51|
# Krok: 347|Cena: 5.41|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7949.28|Nagroda: -0.31|
# Krok: 348|Cena: 5.18|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7948.82|Nagroda: -0.33|
# Krok: 349|Cena: 5.05|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7948.56|Nagroda: -0.46|
# Krok: 350|Cena: 4.84|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7948.14|Nagroda: -0.26|
# Krok: 351|Cena: 4.66|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7947.78|Nagroda: -0.42|
# Krok: 352|Cena: 4.45|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7947.35|Nagroda: -0.36|
# Krok: 353|Cena: 4.29|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7947.04|Nagroda: -0.43|
# Krok: 354|Cena: 4.11|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7946.68|Nagroda: -0.31|
# Krok: 355|Cena: 3.92|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7946.29|Nagroda: -0.35|
# Krok: 356|Cena: 3.75|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7945.95|Nagroda: -0.39|
# Krok: 357|Cena: 3.58|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7945.61|Nagroda: -0.35|
# Krok: 358|Cena: 3.39|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7945.24|Nagroda: -0.34|
# Krok: 359|Cena: 3.25|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7944.95|Nagroda: -0.37|
# Krok: 360|Cena: 3.10|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7944.65|Nagroda: -0.29|
# Krok: 361|Cena: 2.97|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7944.39|Nagroda: -0.30|
# Krok: 362|Cena: 2.85|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7944.14|Nagroda: -0.26|
# Krok: 363|Cena: 2.68|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7943.81|Nagroda: -0.24|
# Krok: 364|Cena: 2.58|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7943.61|Nagroda: -0.33|
# Krok: 365|Cena: 2.51|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7943.47|Nagroda: -0.20|
# Krok: 366|Cena: 2.36|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7943.18|Nagroda: -0.15|
# Krok: 367|Cena: 2.28|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7943.01|Nagroda: -0.28|
# Krok: 368|Cena: 2.22|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7942.89|Nagroda: -0.18|
# Krok: 369|Cena: 2.17|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7942.79|Nagroda: -0.11|
# Krok: 370|Cena: 2.10|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7942.65|Nagroda: -0.10|
# Krok: 371|Cena: 2.08|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7942.62|Nagroda: -0.14|
# Krok: 372|Cena: 2.04|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7942.54|Nagroda: -0.03|
# Krok: 373|Cena: 2.02|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7942.50|Nagroda: -0.08|
# Krok: 374|Cena: 2.01|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7942.48|Nagroda: -0.04|
# Krok: 375|Cena: 2.05|Gotówka: 7938.45|Akcje: 2|Wartość portfela: 7942.56|Nagroda: -0.02|
# Krok: 376|Cena: 2.02|Gotówka: 5332.69|Akcje: 1272|Wartość portfela: 7899.85|Nagroda: 51.74|
# Krok: 377|Cena: 2.01|Gotówka: 7027.99|Akcje: 432|Wartość portfela: 7896.80|Nagroda: -14.50|
# Krok: 378|Cena: 2.12|Gotówka: 4839.87|Akcje: 1520|Wartość portfela: 8068.17|Nagroda: -10.75|
# Krok: 379|Cena: 2.13|Gotówka: 48.39|Akcje: 3776|Wartość portfela: 8109.28|Nagroda: 425.73|
# Krok: 380|Cena: 2.21|Gotówka: 27.04|Akcje: 3786|Wartość portfela: 8392.34|Nagroda: 41.22|
# Krok: 381|Cena: 2.31|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 8766.69|Nagroda: 283.96|
# Krok: 382|Cena: 2.34|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 8869.52|Nagroda: 374.35|
# Krok: 383|Cena: 2.44|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 9259.82|Nagroda: 102.83|
# Krok: 384|Cena: 2.54|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 9635.16|Nagroda: 390.31|
# Krok: 385|Cena: 2.67|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 10134.98|Nagroda: 375.33|
# Krok: 386|Cena: 2.82|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 10702.10|Nagroda: 499.83|
# Krok: 387|Cena: 2.95|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 11214.93|Nagroda: 567.12|
# Krok: 388|Cena: 3.09|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 11733.50|Nagroda: 512.83|
# Krok: 389|Cena: 3.20|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 12171.48|Nagroda: 518.57|
# Krok: 390|Cena: 3.34|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 12696.21|Nagroda: 437.97|
# Krok: 391|Cena: 3.55|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 13492.98|Nagroda: 524.73|
# Krok: 392|Cena: 3.71|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 14092.00|Nagroda: 796.77|
# Krok: 393|Cena: 3.90|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 14821.00|Nagroda: 599.02|
# Krok: 394|Cena: 4.08|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 15514.37|Nagroda: 729.00|
# Krok: 395|Cena: 4.25|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 16160.50|Nagroda: 693.37|
# Krok: 396|Cena: 4.45|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 16907.95|Nagroda: 646.13|
# Krok: 397|Cena: 4.63|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 17576.33|Nagroda: 747.45|
# Krok: 398|Cena: 4.82|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 18313.56|Nagroda: 668.37|
# Krok: 399|Cena: 4.99|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 18937.00|Nagroda: 737.23|
# Krok: 400|Cena: 4.99|Gotówka: 0.52|Akcje: 3798|Wartość portfela: 18937.00|Nagroda: 623.44|

# %%
results_plot_continuous(env_predict=env_predict, prices=prices)

# %%
plot_shares_changes_fixed_size(lista, prices)

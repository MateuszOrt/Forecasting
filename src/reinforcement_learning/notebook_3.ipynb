# %%
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor


from trading_envs import PortfolioValueTradingEnv, PortfolioValueTradingEnvUpdated
from logger import TrainingLoggerCallback
from data_and_plots import (
    generate_sine_wave,
    training_plot,
    results_plot_continuous,
    plot,
)
from helper import predict_data_env
import torch
import random

# %%
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)

# ziarno dla NumPy
np.random.seed(42)

# ziarno dla standardowego generatora liczb losowych Pythona
random.seed(42)

# %%
prices = generate_sine_wave(seed=42)
plot(prices)

# %%
# Tworzenie instacji środowiska
env_agent = PortfolioValueTradingEnv(prices)
env_agent = Monitor(env_agent)

# Sprawdzenie zgodności środowiska z stable_baselines3
check_env(env_agent)

logger_callback = TrainingLoggerCallback()
# Tworzenie modelu PPO
model_agent = PPO(
    "MlpPolicy",
    env_agent,
    # policy_kwargs=dict(
    #     net_arch=[
    #         128,
    #         128,
    #     ]
    # ),
    #   learning_rate=0.00005,        # domyślnie 3e-4
    n_steps=400,  # liczba kroków zanim agent zrobi aktualizację
    batch_size=100,  # batch size do uczenia
    # n_epochs=10,                 # ile razy przebiega po danych przy każdej aktualizacji
    gamma=0.1,  # współczynnik dyskontujący nagrody
    # gae_lambda=0.95,             # współczynnik GAE
    # clip_range=0.2,              # zakres klipu PPO (stabilizacja treningu)
    # ent_coef=0.9,                # zachęta do eksploracji
    verbose=1,
)

# Trening modelu
model_agent.learn(total_timesteps=30_000, callback=logger_callback)


training_plot(logger_callback=logger_callback)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 400       |
# |    ep_rew_mean     | -3.61e+03 |
# | time/              |           |
# |    fps             | 646       |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 400       |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -3.05e+03   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 800         |
# | train/                  |             |
# |    approx_kl            | 0.023674227 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 7.89e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 721         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0384     |
# |    std                  | 0.993       |
# |    value_loss           | 959         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -2.72e+03  |
# | time/                   |            |
# |    fps                  | 604        |
# |    iterations           | 3          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 1200       |
# | train/                  |            |
# |    approx_kl            | 0.02434631 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.00215    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 251        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0364    |
# |    std                  | 0.985      |
# |    value_loss           | 634        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -2.25e+03  |
# | time/                   |            |
# |    fps                  | 607        |
# |    iterations           | 4          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 1600       |
# | train/                  |            |
# |    approx_kl            | 0.01598995 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | 0.00461    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 148        |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0342    |
# |    std                  | 0.974      |
# |    value_loss           | 529        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.91e+03    |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2000         |
# | train/                  |              |
# |    approx_kl            | 0.0074571352 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.000817    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 242          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0227      |
# |    std                  | 0.965        |
# |    value_loss           | 238          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.59e+03   |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2400        |
# | train/                  |             |
# |    approx_kl            | 0.005357722 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0121      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.7        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.022      |
# |    std                  | 0.957       |
# |    value_loss           | 201         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -1.38e+03  |
# | time/                   |            |
# |    fps                  | 615        |
# |    iterations           | 7          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 2800       |
# | train/                  |            |
# |    approx_kl            | 0.02776515 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.0704     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 50.9       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0214    |
# |    std                  | 0.95       |
# |    value_loss           | 66.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.16e+03   |
# | time/                   |             |
# |    fps                  | 614         |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.020286884 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0767      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70.8        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0278     |
# |    std                  | 0.945       |
# |    value_loss           | 172         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -964        |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.019845633 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0293     |
# |    std                  | 0.938       |
# |    value_loss           | 236         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -585       |
# | time/                   |            |
# |    fps                  | 624        |
# |    iterations           | 10         |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 4000       |
# | train/                  |            |
# |    approx_kl            | 0.01493522 |
# |    clip_fraction        | 0.088      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.132      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 177        |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0229    |
# |    std                  | 0.931      |
# |    value_loss           | 247        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -271         |
# | time/                   |              |
# |    fps                  | 625          |
# |    iterations           | 11           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4400         |
# | train/                  |              |
# |    approx_kl            | 0.0037071006 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 361          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00667     |
# |    std                  | 0.928        |
# |    value_loss           | 964          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 190         |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4800        |
# | train/                  |             |
# |    approx_kl            | 0.028643716 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.171       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 257         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.926       |
# |    value_loss           | 569         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 500          |
# | time/                   |              |
# |    fps                  | 625          |
# |    iterations           | 13           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 5200         |
# | train/                  |              |
# |    approx_kl            | 0.0037319753 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0987       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00802     |
# |    std                  | 0.925        |
# |    value_loss           | 2.19e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 962         |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 14          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5600        |
# | train/                  |             |
# |    approx_kl            | 0.010061549 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 820         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.922       |
# |    value_loss           | 1.7e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | 1.25e+03   |
# | time/                   |            |
# |    fps                  | 626        |
# |    iterations           | 15         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 6000       |
# | train/                  |            |
# |    approx_kl            | 0.01045974 |
# |    clip_fraction        | 0.0917     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.089      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.34e+03   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.021      |
# |    std                  | 0.922      |
# |    value_loss           | 3.78e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 1.82e+03    |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 16          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.003044688 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.115       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 720         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00314    |
# |    std                  | 0.921       |
# |    value_loss           | 2.51e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 2.07e+03     |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 17           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6800         |
# | train/                  |              |
# |    approx_kl            | 0.0027327386 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0773       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.8e+03      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00194     |
# |    std                  | 0.921        |
# |    value_loss           | 6.91e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 2.41e+03     |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 18           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 7200         |
# | train/                  |              |
# |    approx_kl            | 0.0069538774 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.17e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.92         |
# |    value_loss           | 3.36e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 2.46e+03     |
# | time/                   |              |
# |    fps                  | 628          |
# |    iterations           | 19           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 7600         |
# | train/                  |              |
# |    approx_kl            | 0.0049331035 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0997       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.35e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00153     |
# |    std                  | 0.92         |
# |    value_loss           | 4.89e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.74e+03    |
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 20          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.010303395 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.164       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 664         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00991    |
# |    std                  | 0.919       |
# |    value_loss           | 1.83e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 3.18e+03     |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 21           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 8400         |
# | train/                  |              |
# |    approx_kl            | 0.0049497834 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.94e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00241     |
# |    std                  | 0.919        |
# |    value_loss           | 4.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 3.43e+03     |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 22           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8800         |
# | train/                  |              |
# |    approx_kl            | 0.0012338357 |
# |    clip_fraction        | 0.053        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0711       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.69e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000175    |
# |    std                  | 0.918        |
# |    value_loss           | 9.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 3.55e+03     |
# | time/                   |              |
# |    fps                  | 625          |
# |    iterations           | 23           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 9200         |
# | train/                  |              |
# |    approx_kl            | 0.0015843695 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.096        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000881    |
# |    std                  | 0.918        |
# |    value_loss           | 5.08e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 400           |
# |    ep_rew_mean          | 3.7e+03       |
# | time/                   |               |
# |    fps                  | 624           |
# |    iterations           | 24            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 9600          |
# | train/                  |               |
# |    approx_kl            | 0.00074408186 |
# |    clip_fraction        | 0.002         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 0.12          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.78e+03      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.0017       |
# |    std                  | 0.918         |
# |    value_loss           | 3.82e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 3.88e+03    |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 25          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.016207272 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.119       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02e+03    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.000203    |
# |    std                  | 0.917       |
# |    value_loss           | 4.69e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 4.09e+03     |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 26           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 10400        |
# | train/                  |              |
# |    approx_kl            | 0.0036486394 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00564     |
# |    std                  | 0.916        |
# |    value_loss           | 4.34e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 4.34e+03     |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 27           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 10800        |
# | train/                  |              |
# |    approx_kl            | 0.0026101298 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.106        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 0.916        |
# |    value_loss           | 6.37e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 4.41e+03     |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 28           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 11200        |
# | train/                  |              |
# |    approx_kl            | 0.0007239096 |
# |    clip_fraction        | 0.0015       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.103        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.94e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00282     |
# |    std                  | 0.916        |
# |    value_loss           | 9.02e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 4.6e+03      |
# | time/                   |              |
# |    fps                  | 628          |
# |    iterations           | 29           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 11600        |
# | train/                  |              |
# |    approx_kl            | 0.0031777103 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.85e+03     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00465     |
# |    std                  | 0.916        |
# |    value_loss           | 3.79e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 4.9e+03      |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 30           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0026070424 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.49e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00231     |
# |    std                  | 0.916        |
# |    value_loss           | 6.13e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 400           |
# |    ep_rew_mean          | 5.11e+03      |
# | time/                   |               |
# |    fps                  | 628           |
# |    iterations           | 31            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 12400         |
# | train/                  |               |
# |    approx_kl            | 0.00027443244 |
# |    clip_fraction        | 0.00225       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 0.0785        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.02e+03      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000846     |
# |    std                  | 0.916         |
# |    value_loss           | 1.2e+04       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 5.27e+03     |
# | time/                   |              |
# |    fps                  | 628          |
# |    iterations           | 32           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0038081803 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.0914       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.34e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00138     |
# |    std                  | 0.916        |
# |    value_loss           | 8.53e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 5.35e+03     |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 33           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 13200        |
# | train/                  |              |
# |    approx_kl            | 0.0010984539 |
# |    clip_fraction        | 0.00475      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.42e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00171     |
# |    std                  | 0.916        |
# |    value_loss           | 7.18e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 5.52e+03     |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 34           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 13600        |
# | train/                  |              |
# |    approx_kl            | 0.0053968993 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00635     |
# |    std                  | 0.915        |
# |    value_loss           | 5.22e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 5.68e+03     |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 35           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 14000        |
# | train/                  |              |
# |    approx_kl            | 0.0014361782 |
# |    clip_fraction        | 0.00975      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.95e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00269     |
# |    std                  | 0.915        |
# |    value_loss           | 7.75e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 400           |
# |    ep_rew_mean          | 5.8e+03       |
# | time/                   |               |
# |    fps                  | 626           |
# |    iterations           | 36            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 14400         |
# | train/                  |               |
# |    approx_kl            | 0.00063943176 |
# |    clip_fraction        | 0.0142        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.33         |
# |    explained_variance   | 0.0996        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.54e+03      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -0.000222     |
# |    std                  | 0.915         |
# |    value_loss           | 8.09e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 5.81e+03    |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 37          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14800       |
# | train/                  |             |
# |    approx_kl            | 0.001198606 |
# |    clip_fraction        | 0.005       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.09e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0017     |
# |    std                  | 0.914       |
# |    value_loss           | 5.99e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 5.96e+03     |
# | time/                   |              |
# |    fps                  | 625          |
# |    iterations           | 38           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 15200        |
# | train/                  |              |
# |    approx_kl            | 0.0020050232 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00271     |
# |    std                  | 0.914        |
# |    value_loss           | 3.95e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.07e+03    |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 39          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 15600       |
# | train/                  |             |
# |    approx_kl            | 0.002790608 |
# |    clip_fraction        | 0.012       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19e+03    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00304     |
# |    std                  | 0.913       |
# |    value_loss           | 7.91e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 5.97e+03     |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 40           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 16000        |
# | train/                  |              |
# |    approx_kl            | 0.0027546268 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.52e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0039      |
# |    std                  | 0.914        |
# |    value_loss           | 7.02e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.1e+03     |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 41          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16400       |
# | train/                  |             |
# |    approx_kl            | 0.033580102 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.231       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 609         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.913       |
# |    value_loss           | 1.93e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.31e+03    |
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 42          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16800       |
# | train/                  |             |
# |    approx_kl            | 0.006846656 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.68e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00225    |
# |    std                  | 0.913       |
# |    value_loss           | 7.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.27e+03    |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 43          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 17200       |
# | train/                  |             |
# |    approx_kl            | 0.011908923 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0918      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07e+04    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00841    |
# |    std                  | 0.913       |
# |    value_loss           | 1.43e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.24e+03     |
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 44           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 17600        |
# | train/                  |              |
# |    approx_kl            | 0.0029932016 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 828          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00571     |
# |    std                  | 0.912        |
# |    value_loss           | 1.91e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.41e+03    |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 45          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.032613754 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.86e+03    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.912       |
# |    value_loss           | 2.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.52e+03    |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 46          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18400       |
# | train/                  |             |
# |    approx_kl            | 0.015061695 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0998      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.89e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00217    |
# |    std                  | 0.912       |
# |    value_loss           | 1.2e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.58e+03     |
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 47           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 18800        |
# | train/                  |              |
# |    approx_kl            | 0.0025953124 |
# |    clip_fraction        | 0.0065       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.11         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.02e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.002       |
# |    std                  | 0.911        |
# |    value_loss           | 8.87e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.7e+03     |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 48          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.053559184 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.137       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.911       |
# |    value_loss           | 6.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.75e+03    |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 49          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 19600       |
# | train/                  |             |
# |    approx_kl            | 0.007707203 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.14e+03    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00217    |
# |    std                  | 0.911       |
# |    value_loss           | 9.41e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.87e+03    |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 50          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.004367751 |
# |    clip_fraction        | 0.0155      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4e+03     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00318    |
# |    std                  | 0.911       |
# |    value_loss           | 5.53e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 6.87e+03     |
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 51           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 20400        |
# | train/                  |              |
# |    approx_kl            | 0.0005781637 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0.117        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.25e+03     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00197     |
# |    std                  | 0.911        |
# |    value_loss           | 9.59e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 6.96e+03    |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 52          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 20800       |
# | train/                  |             |
# |    approx_kl            | 0.003807384 |
# |    clip_fraction        | 0.0157      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.187       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17e+03    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00377    |
# |    std                  | 0.91        |
# ...
# |    value_loss           | 1e+04       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.21e+03     |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 59           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 23600        |
# | train/                  |              |
# |    approx_kl            | 0.0053080097 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.151        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.37e+03     |
# |    n_updates            | 580          |
# |    policy_gradient_loss | 0.00261      |
# |    std                  | 0.908        |
# |    value_loss           | 6.77e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.33e+03    |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 60          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 24000       |
# | train/                  |             |
# |    approx_kl            | 0.001121476 |
# |    clip_fraction        | 0.0155      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.26e+03    |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00151    |
# |    std                  | 0.908       |
# |    value_loss           | 8.12e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.42e+03     |
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 61           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 24400        |
# | train/                  |              |
# |    approx_kl            | 0.0032114831 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.97e+03     |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00344     |
# |    std                  | 0.907        |
# |    value_loss           | 1.34e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.51e+03    |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 62          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 24800       |
# | train/                  |             |
# |    approx_kl            | 0.014060476 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.123       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28e+04    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0088     |
# |    std                  | 0.907       |
# |    value_loss           | 1.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.6e+03     |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 63          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 25200       |
# | train/                  |             |
# |    approx_kl            | 0.016364127 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.124       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.94e+03    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0048     |
# |    std                  | 0.906       |
# |    value_loss           | 9.73e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.68e+03     |
# | time/                   |              |
# |    fps                  | 619          |
# |    iterations           | 64           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0073303925 |
# |    clip_fraction        | 0.0997       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.12         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.18e+03     |
# |    n_updates            | 630          |
# |    policy_gradient_loss | 0.00613      |
# |    std                  | 0.906        |
# |    value_loss           | 1.06e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.73e+03     |
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 65           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 26000        |
# | train/                  |              |
# |    approx_kl            | 0.0023072409 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.128        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.61e+03     |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00108     |
# |    std                  | 0.907        |
# |    value_loss           | 8.32e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | 7.61e+03   |
# | time/                   |            |
# |    fps                  | 620        |
# |    iterations           | 66         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 26400      |
# | train/                  |            |
# |    approx_kl            | 0.03315093 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.142      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.68e+03   |
# |    n_updates            | 650        |
# |    policy_gradient_loss | 0.0126     |
# |    std                  | 0.906      |
# |    value_loss           | 7.51e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.61e+03    |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 67          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 26800       |
# | train/                  |             |
# |    approx_kl            | 0.010926657 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.273       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 612         |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00869    |
# |    std                  | 0.905       |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.7e+03     |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 68          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 27200       |
# | train/                  |             |
# |    approx_kl            | 0.005319265 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.225       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.46e+03    |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00547    |
# |    std                  | 0.905       |
# |    value_loss           | 4.31e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.77e+03     |
# | time/                   |              |
# |    fps                  | 619          |
# |    iterations           | 69           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 27600        |
# | train/                  |              |
# |    approx_kl            | 0.0010322701 |
# |    clip_fraction        | 0.00375      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.133        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.12e+03     |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.000499    |
# |    std                  | 0.905        |
# |    value_loss           | 1.11e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.83e+03     |
# | time/                   |              |
# |    fps                  | 619          |
# |    iterations           | 70           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 28000        |
# | train/                  |              |
# |    approx_kl            | 0.0019540468 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.37e+03     |
# |    n_updates            | 690          |
# |    policy_gradient_loss | -0.0026      |
# |    std                  | 0.905        |
# |    value_loss           | 9.79e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.87e+03     |
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 71           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 28400        |
# | train/                  |              |
# |    approx_kl            | 0.0022782674 |
# |    clip_fraction        | 0.00125      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.139        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.25e+03     |
# |    n_updates            | 700          |
# |    policy_gradient_loss | -0.000227    |
# |    std                  | 0.905        |
# |    value_loss           | 9.5e+03      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 400           |
# |    ep_rew_mean          | 7.91e+03      |
# | time/                   |               |
# |    fps                  | 621           |
# |    iterations           | 72            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 28800         |
# | train/                  |               |
# |    approx_kl            | 0.00056684914 |
# |    clip_fraction        | 0.004         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.32         |
# |    explained_variance   | 0.168         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.62e+03      |
# |    n_updates            | 710           |
# |    policy_gradient_loss | -0.000925     |
# |    std                  | 0.905         |
# |    value_loss           | 6.56e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 7.86e+03     |
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 73           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 29200        |
# | train/                  |              |
# |    approx_kl            | 0.0013819982 |
# |    clip_fraction        | 0.00175      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.51e+03     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.00376     |
# |    std                  | 0.906        |
# |    value_loss           | 8.56e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.77e+03    |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 74          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 29600       |
# | train/                  |             |
# |    approx_kl            | 0.016683545 |
# |    clip_fraction        | 0.0505      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 820         |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.00241    |
# |    std                  | 0.906       |
# |    value_loss           | 2.74e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 7.8e+03     |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 75          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.058564495 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.417       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 536         |
# |    n_updates            | 740         |
# |    policy_gradient_loss | 0.00928     |
# |    std                  | 0.906       |
# |    value_loss           | 1.18e+03    |
# -----------------------------------------

# %%
env_predict, lista = predict_data_env(
    env=PortfolioValueTradingEnv, data=prices, agent=model_agent
)
# Out:
# Krok: 1|Cena: 5.17|Gotówka: 4.88|Akcje: 19|Wartość portfela: 103.08|Nagroda: 0.38|
# Krok: 2|Cena: 5.39|Gotówka: 4.88|Akcje: 19|Wartość portfela: 107.33|Nagroda: 3.08|
# Krok: 3|Cena: 5.58|Gotówka: 4.88|Akcje: 19|Wartość portfela: 110.95|Nagroda: 4.25|
# Krok: 4|Cena: 5.71|Gotówka: 4.88|Akcje: 19|Wartość portfela: 113.35|Nagroda: 3.62|
# Krok: 5|Cena: 5.90|Gotówka: 4.88|Akcje: 19|Wartość portfela: 117.05|Nagroda: 2.40|
# Krok: 6|Cena: 6.11|Gotówka: 4.88|Akcje: 19|Wartość portfela: 120.97|Nagroda: 3.69|
# Krok: 7|Cena: 6.27|Gotówka: 4.88|Akcje: 19|Wartość portfela: 124.09|Nagroda: 3.92|
# Krok: 8|Cena: 6.45|Gotówka: 4.88|Akcje: 19|Wartość portfela: 127.40|Nagroda: 3.12|
# Krok: 9|Cena: 6.59|Gotówka: 4.88|Akcje: 19|Wartość portfela: 130.17|Nagroda: 3.31|
# Krok: 10|Cena: 6.78|Gotówka: 4.88|Akcje: 19|Wartość portfela: 133.79|Nagroda: 2.77|
# Krok: 11|Cena: 6.93|Gotówka: 4.88|Akcje: 19|Wartość portfela: 136.59|Nagroda: 3.62|
# Krok: 12|Cena: 7.06|Gotówka: 4.88|Akcje: 19|Wartość portfela: 139.01|Nagroda: 2.79|
# Krok: 13|Cena: 7.21|Gotówka: 4.88|Akcje: 19|Wartość portfela: 141.94|Nagroda: 2.42|
# Krok: 14|Cena: 7.33|Gotówka: 4.88|Akcje: 19|Wartość portfela: 144.06|Nagroda: 2.94|
# Krok: 15|Cena: 7.41|Gotówka: 4.88|Akcje: 19|Wartość portfela: 145.75|Nagroda: 2.12|
# Krok: 16|Cena: 7.54|Gotówka: 4.88|Akcje: 19|Wartość portfela: 148.23|Nagroda: 1.69|
# Krok: 17|Cena: 7.61|Gotówka: 4.88|Akcje: 19|Wartość portfela: 149.54|Nagroda: 2.48|
# Krok: 18|Cena: 7.74|Gotówka: 4.88|Akcje: 19|Wartość portfela: 151.86|Nagroda: 1.31|
# Krok: 19|Cena: 7.79|Gotówka: 4.88|Akcje: 19|Wartość portfela: 152.93|Nagroda: 2.32|
# Krok: 20|Cena: 7.85|Gotówka: 4.88|Akcje: 19|Wartość portfela: 154.08|Nagroda: 1.06|
# Krok: 21|Cena: 7.89|Gotówka: 4.88|Akcje: 19|Wartość portfela: 154.88|Nagroda: 1.15|
# Krok: 22|Cena: 7.97|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.38|Nagroda: 0.80|
# Krok: 23|Cena: 7.97|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.40|Nagroda: 1.49|
# Krok: 24|Cena: 7.99|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.62|Nagroda: 0.03|
# Krok: 25|Cena: 7.99|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.75|Nagroda: 0.22|
# Krok: 26|Cena: 8.00|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.96|Nagroda: 0.13|
# Krok: 27|Cena: 7.98|Gotówka: 4.88|Akcje: 19|Wartość portfela: 156.54|Nagroda: 0.21|
# Krok: 28|Cena: 7.95|Gotówka: 84.70|Akcje: 9|Wartość portfela: 156.28|Nagroda: -0.20|
# Krok: 29|Cena: 7.91|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 30|Cena: 7.89|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 31|Cena: 7.78|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 32|Cena: 7.70|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 33|Cena: 7.61|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 34|Cena: 7.54|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 35|Cena: 7.44|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 36|Cena: 7.30|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 37|Cena: 7.16|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 38|Cena: 7.02|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 39|Cena: 6.91|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 40|Cena: 6.76|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 41|Cena: 6.60|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 42|Cena: 6.41|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 43|Cena: 6.26|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 44|Cena: 6.09|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 45|Cena: 5.91|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 46|Cena: 5.74|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 47|Cena: 5.54|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 48|Cena: 5.37|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 49|Cena: 5.17|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 50|Cena: 4.98|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 51|Cena: 4.80|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 52|Cena: 4.57|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 53|Cena: 4.41|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 54|Cena: 4.22|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 55|Cena: 4.04|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 56|Cena: 3.87|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 57|Cena: 3.73|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 58|Cena: 3.51|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 59|Cena: 3.39|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 60|Cena: 3.18|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 61|Cena: 3.06|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 62|Cena: 2.93|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 63|Cena: 2.80|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 64|Cena: 2.68|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 65|Cena: 2.57|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 66|Cena: 2.44|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 67|Cena: 2.35|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 68|Cena: 2.29|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 69|Cena: 2.20|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 70|Cena: 2.11|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 71|Cena: 2.06|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 72|Cena: 2.03|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 73|Cena: 2.03|Gotówka: 156.28|Akcje: 0|Wartość portfela: 156.28|Nagroda: 0.00|
# Krok: 74|Cena: 2.01|Gotówka: 22.33|Akcje: 66|Wartość portfela: 154.78|Nagroda: 0.06|
# Krok: 75|Cena: 2.01|Gotówka: 154.78|Akcje: 0|Wartość portfela: 154.78|Nagroda: 0.00|
# Krok: 76|Cena: 2.00|Gotówka: 17.83|Akcje: 68|Wartość portfela: 153.82|Nagroda: 0.49|
# Krok: 77|Cena: 2.03|Gotówka: 143.82|Akcje: 5|Wartość portfela: 153.97|Nagroda: -0.07|
# Krok: 78|Cena: 2.07|Gotówka: 1.60|Akcje: 75|Wartość portfela: 157.06|Nagroda: 2.38|
# Krok: 79|Cena: 2.10|Gotówka: 1.60|Akcje: 75|Wartość portfela: 158.92|Nagroda: 3.09|
# Krok: 80|Cena: 2.17|Gotówka: 1.60|Akcje: 75|Wartość portfela: 164.19|Nagroda: 1.86|
# Krok: 81|Cena: 2.21|Gotówka: 1.60|Akcje: 75|Wartość portfela: 167.49|Nagroda: 5.27|
# Krok: 82|Cena: 2.29|Gotówka: 1.60|Akcje: 75|Wartość portfela: 173.73|Nagroda: 3.29|
# Krok: 83|Cena: 2.38|Gotówka: 1.60|Akcje: 75|Wartość portfela: 180.30|Nagroda: 6.24|
# Krok: 84|Cena: 2.46|Gotówka: 1.60|Akcje: 75|Wartość portfela: 186.45|Nagroda: 6.57|
# Krok: 85|Cena: 2.61|Gotówka: 1.60|Akcje: 75|Wartość portfela: 197.09|Nagroda: 6.15|
# Krok: 86|Cena: 2.71|Gotówka: 1.60|Akcje: 75|Wartość portfela: 204.49|Nagroda: 10.64|
# Krok: 87|Cena: 2.84|Gotówka: 1.60|Akcje: 75|Wartość portfela: 214.73|Nagroda: 7.40|
# Krok: 88|Cena: 2.99|Gotówka: 1.60|Akcje: 75|Wartość portfela: 225.59|Nagroda: 10.24|
# Krok: 89|Cena: 3.13|Gotówka: 1.60|Akcje: 75|Wartość portfela: 236.30|Nagroda: 10.86|
# Krok: 90|Cena: 3.28|Gotówka: 1.60|Akcje: 75|Wartość portfela: 247.94|Nagroda: 10.71|
# Krok: 91|Cena: 3.43|Gotówka: 1.60|Akcje: 75|Wartość portfela: 258.63|Nagroda: 11.65|
# Krok: 92|Cena: 3.58|Gotówka: 1.60|Akcje: 75|Wartość portfela: 270.44|Nagroda: 10.69|
# Krok: 93|Cena: 3.76|Gotówka: 1.60|Akcje: 75|Wartość portfela: 283.68|Nagroda: 11.81|
# Krok: 94|Cena: 3.90|Gotówka: 1.60|Akcje: 75|Wartość portfela: 294.35|Nagroda: 13.23|
# Krok: 95|Cena: 4.09|Gotówka: 1.60|Akcje: 75|Wartość portfela: 308.11|Nagroda: 10.67|
# Krok: 96|Cena: 4.27|Gotówka: 1.60|Akcje: 75|Wartość portfela: 321.97|Nagroda: 13.76|
# Krok: 97|Cena: 4.46|Gotówka: 1.60|Akcje: 75|Wartość portfela: 336.33|Nagroda: 13.85|
# Krok: 98|Cena: 4.68|Gotówka: 1.60|Akcje: 75|Wartość portfela: 352.45|Nagroda: 14.36|
# Krok: 99|Cena: 4.84|Gotówka: 1.60|Akcje: 75|Wartość portfela: 364.62|Nagroda: 16.12|
# Krok: 100|Cena: 5.04|Gotówka: 1.60|Akcje: 75|Wartość portfela: 379.58|Nagroda: 12.17|
# Krok: 101|Cena: 5.26|Gotówka: 1.60|Akcje: 75|Wartość portfela: 396.25|Nagroda: 14.96|
# Krok: 102|Cena: 5.42|Gotówka: 1.60|Akcje: 75|Wartość portfela: 407.85|Nagroda: 16.67|
# Krok: 103|Cena: 5.62|Gotówka: 1.60|Akcje: 75|Wartość portfela: 423.45|Nagroda: 11.60|
# Krok: 104|Cena: 5.77|Gotówka: 1.60|Akcje: 75|Wartość portfela: 434.72|Nagroda: 15.60|
# Krok: 105|Cena: 5.97|Gotówka: 1.60|Akcje: 75|Wartość portfela: 449.35|Nagroda: 11.27|
# Krok: 106|Cena: 6.13|Gotówka: 1.60|Akcje: 75|Wartość portfela: 461.49|Nagroda: 14.63|
# Krok: 107|Cena: 6.32|Gotówka: 1.60|Akcje: 75|Wartość portfela: 475.31|Nagroda: 12.13|
# Krok: 108|Cena: 6.51|Gotówka: 1.60|Akcje: 75|Wartość portfela: 489.60|Nagroda: 13.83|
# Krok: 109|Cena: 6.62|Gotówka: 1.60|Akcje: 75|Wartość portfela: 497.82|Nagroda: 14.28|
# Krok: 110|Cena: 6.81|Gotówka: 1.60|Akcje: 75|Wartość portfela: 512.64|Nagroda: 8.22|
# Krok: 111|Cena: 6.96|Gotówka: 1.60|Akcje: 75|Wartość portfela: 523.39|Nagroda: 14.82|
# Krok: 112|Cena: 7.08|Gotówka: 1.60|Akcje: 75|Wartość portfela: 532.61|Nagroda: 10.75|
# Krok: 113|Cena: 7.19|Gotówka: 1.60|Akcje: 75|Wartość portfela: 541.17|Nagroda: 9.22|
# Krok: 114|Cena: 7.35|Gotówka: 1.60|Akcje: 75|Wartość portfela: 552.62|Nagroda: 8.56|
# Krok: 115|Cena: 7.45|Gotówka: 1.60|Akcje: 75|Wartość portfela: 560.20|Nagroda: 11.46|
# Krok: 116|Cena: 7.57|Gotówka: 1.60|Akcje: 75|Wartość portfela: 569.10|Nagroda: 7.58|
# Krok: 117|Cena: 7.66|Gotówka: 1.60|Akcje: 75|Wartość portfela: 575.77|Nagroda: 8.89|
# Krok: 118|Cena: 7.77|Gotówka: 1.60|Akcje: 75|Wartość portfela: 584.34|Nagroda: 6.67|
# Krok: 119|Cena: 7.80|Gotówka: 1.60|Akcje: 75|Wartość portfela: 586.96|Nagroda: 8.57|
# Krok: 120|Cena: 7.85|Gotówka: 1.60|Akcje: 75|Wartość portfela: 590.33|Nagroda: 2.62|
# Krok: 121|Cena: 7.92|Gotówka: 1.60|Akcje: 75|Wartość portfela: 595.83|Nagroda: 3.37|
# Krok: 122|Cena: 7.96|Gotówka: 1.60|Akcje: 75|Wartość portfela: 598.72|Nagroda: 5.50|
# Krok: 123|Cena: 8.01|Gotówka: 1.60|Akcje: 75|Wartość portfela: 602.37|Nagroda: 2.89|
# Krok: 124|Cena: 8.01|Gotówka: 1.60|Akcje: 75|Wartość portfela: 602.65|Nagroda: 3.66|
# Krok: 125|Cena: 8.01|Gotówka: 1.60|Akcje: 75|Wartość portfela: 602.10|Nagroda: 0.27|
# Krok: 126|Cena: 8.02|Gotówka: 1.60|Akcje: 75|Wartość portfela: 603.03|Nagroda: -0.55|
# Krok: 127|Cena: 7.94|Gotówka: 1.60|Akcje: 75|Wartość portfela: 597.44|Nagroda: 0.93|
# Krok: 128|Cena: 7.92|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 129|Cena: 7.87|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 130|Cena: 7.83|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 131|Cena: 7.74|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 132|Cena: 7.70|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 133|Cena: 7.59|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 134|Cena: 7.47|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 135|Cena: 7.37|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 136|Cena: 7.28|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 137|Cena: 7.16|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 138|Cena: 7.05|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 139|Cena: 6.92|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 140|Cena: 6.72|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 141|Cena: 6.53|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 142|Cena: 6.34|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 143|Cena: 6.22|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 144|Cena: 6.02|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 145|Cena: 5.85|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 146|Cena: 5.67|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 147|Cena: 5.49|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 148|Cena: 5.33|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 149|Cena: 5.12|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 150|Cena: 4.93|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 151|Cena: 4.72|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 152|Cena: 4.52|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 153|Cena: 4.36|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 154|Cena: 4.18|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 155|Cena: 4.04|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 156|Cena: 3.83|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 157|Cena: 3.68|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 158|Cena: 3.48|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 159|Cena: 3.31|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 160|Cena: 3.16|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 161|Cena: 3.02|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 162|Cena: 2.93|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 163|Cena: 2.74|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 164|Cena: 2.66|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 165|Cena: 2.51|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 166|Cena: 2.44|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 167|Cena: 2.34|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 168|Cena: 2.25|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 169|Cena: 2.18|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 170|Cena: 2.11|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 171|Cena: 2.08|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 172|Cena: 2.03|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 173|Cena: 1.99|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 174|Cena: 1.98|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 175|Cena: 2.00|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 176|Cena: 2.04|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 177|Cena: 2.04|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 178|Cena: 2.07|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 179|Cena: 2.12|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 180|Cena: 2.20|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 181|Cena: 2.25|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 182|Cena: 2.32|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 183|Cena: 2.44|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 184|Cena: 2.52|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 185|Cena: 2.66|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 186|Cena: 2.75|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 187|Cena: 2.85|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 188|Cena: 2.98|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 189|Cena: 3.19|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 190|Cena: 3.34|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 191|Cena: 3.47|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 192|Cena: 3.63|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 193|Cena: 3.83|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 194|Cena: 3.96|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 195|Cena: 4.14|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 196|Cena: 4.36|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 197|Cena: 4.52|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 198|Cena: 4.72|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 199|Cena: 4.90|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 200|Cena: 5.10|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 201|Cena: 5.31|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 202|Cena: 5.47|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 203|Cena: 5.67|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 204|Cena: 5.80|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 205|Cena: 6.02|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 206|Cena: 6.18|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 207|Cena: 6.34|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 208|Cena: 6.51|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 209|Cena: 6.68|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 210|Cena: 6.86|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 211|Cena: 6.96|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 212|Cena: 7.13|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 213|Cena: 7.24|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 214|Cena: 7.37|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 215|Cena: 7.51|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 216|Cena: 7.60|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 217|Cena: 7.70|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 218|Cena: 7.75|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 219|Cena: 7.81|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 220|Cena: 7.88|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 221|Cena: 7.93|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 222|Cena: 7.97|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 223|Cena: 7.97|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 224|Cena: 8.00|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 225|Cena: 8.00|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 226|Cena: 8.04|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 227|Cena: 8.00|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 228|Cena: 7.91|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 229|Cena: 7.87|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 230|Cena: 7.79|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 231|Cena: 7.74|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 232|Cena: 7.67|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 233|Cena: 7.60|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 234|Cena: 7.46|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 235|Cena: 7.35|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 236|Cena: 7.20|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 237|Cena: 7.11|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 238|Cena: 6.95|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 239|Cena: 6.81|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 240|Cena: 6.65|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 241|Cena: 6.51|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 242|Cena: 6.31|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 243|Cena: 6.14|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 244|Cena: 6.04|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 245|Cena: 5.79|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 246|Cena: 5.61|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 247|Cena: 5.48|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 248|Cena: 5.32|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 249|Cena: 5.05|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 250|Cena: 4.87|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 251|Cena: 4.70|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 252|Cena: 4.54|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 253|Cena: 4.30|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 254|Cena: 4.13|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 255|Cena: 3.97|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 256|Cena: 3.79|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 257|Cena: 3.61|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 258|Cena: 3.45|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 259|Cena: 3.26|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 260|Cena: 3.13|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 261|Cena: 2.99|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 262|Cena: 2.86|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 263|Cena: 2.72|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 264|Cena: 2.62|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 265|Cena: 2.52|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 266|Cena: 2.41|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 267|Cena: 2.32|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 268|Cena: 2.24|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 269|Cena: 2.17|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 270|Cena: 2.10|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 271|Cena: 2.07|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 272|Cena: 2.03|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 273|Cena: 2.05|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 274|Cena: 2.03|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 275|Cena: 2.01|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 276|Cena: 2.00|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 277|Cena: 2.02|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 278|Cena: 2.10|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 279|Cena: 2.14|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 280|Cena: 2.20|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 281|Cena: 2.23|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 282|Cena: 2.36|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 283|Cena: 2.45|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 284|Cena: 2.52|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 285|Cena: 2.65|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 286|Cena: 2.78|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 287|Cena: 2.91|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 288|Cena: 3.04|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 289|Cena: 3.19|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 290|Cena: 3.34|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 291|Cena: 3.51|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 292|Cena: 3.71|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 293|Cena: 3.80|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 294|Cena: 4.02|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 295|Cena: 4.21|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 296|Cena: 4.40|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 297|Cena: 4.57|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 298|Cena: 4.73|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 299|Cena: 4.96|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 300|Cena: 5.18|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 301|Cena: 5.30|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 302|Cena: 5.53|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 303|Cena: 5.70|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 304|Cena: 5.88|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 305|Cena: 6.04|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 306|Cena: 6.23|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 307|Cena: 6.43|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 308|Cena: 6.58|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 309|Cena: 6.76|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 310|Cena: 6.90|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 311|Cena: 7.03|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 312|Cena: 7.19|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 313|Cena: 7.29|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 314|Cena: 7.42|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 315|Cena: 7.51|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 316|Cena: 7.61|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 317|Cena: 7.68|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 318|Cena: 7.79|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 319|Cena: 7.82|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 320|Cena: 7.91|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 321|Cena: 7.94|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 322|Cena: 7.99|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 323|Cena: 8.01|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 324|Cena: 8.04|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 325|Cena: 8.01|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 326|Cena: 7.95|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 327|Cena: 7.95|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 328|Cena: 7.89|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 329|Cena: 7.85|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 330|Cena: 7.83|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 331|Cena: 7.74|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 332|Cena: 7.63|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 333|Cena: 7.53|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 334|Cena: 7.45|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 335|Cena: 7.31|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 336|Cena: 7.19|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 337|Cena: 7.08|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 338|Cena: 6.96|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 339|Cena: 6.80|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 340|Cena: 6.59|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 341|Cena: 6.48|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 342|Cena: 6.30|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 343|Cena: 6.14|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 344|Cena: 5.98|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 345|Cena: 5.73|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 346|Cena: 5.57|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 347|Cena: 5.41|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 348|Cena: 5.18|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 349|Cena: 5.05|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 350|Cena: 4.84|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 351|Cena: 4.66|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 352|Cena: 4.45|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 353|Cena: 4.29|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 354|Cena: 4.11|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 355|Cena: 3.92|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 356|Cena: 3.75|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 357|Cena: 3.58|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 358|Cena: 3.39|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 359|Cena: 3.25|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 360|Cena: 3.10|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 361|Cena: 2.97|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 362|Cena: 2.85|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 363|Cena: 2.68|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 364|Cena: 2.58|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 365|Cena: 2.51|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 366|Cena: 2.36|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 367|Cena: 2.28|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 368|Cena: 2.22|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 369|Cena: 2.17|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 370|Cena: 2.10|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 371|Cena: 2.08|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 372|Cena: 2.04|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 373|Cena: 2.02|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 374|Cena: 2.01|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 375|Cena: 2.05|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 376|Cena: 2.02|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 377|Cena: 2.01|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 378|Cena: 2.12|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: 0.00|
# Krok: 379|Cena: 2.13|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 380|Cena: 2.21|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 381|Cena: 2.31|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 382|Cena: 2.34|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 383|Cena: 2.44|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 384|Cena: 2.54|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 385|Cena: 2.67|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 386|Cena: 2.82|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 387|Cena: 2.95|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 388|Cena: 3.09|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 389|Cena: 3.20|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 390|Cena: 3.34|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 391|Cena: 3.55|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 392|Cena: 3.71|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 393|Cena: 3.90|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 394|Cena: 4.08|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 395|Cena: 4.25|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 396|Cena: 4.45|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 397|Cena: 4.63|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 398|Cena: 4.82|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 399|Cena: 4.99|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|
# Krok: 400|Cena: 4.99|Gotówka: 597.44|Akcje: 0|Wartość portfela: 597.44|Nagroda: -100.00|

# %%
results_plot_continuous(env_predict=env_predict, prices=prices)

# %%
# Tworzenie instacji środowiska
env_agent = PortfolioValueTradingEnvUpdated(prices)
env_agent = Monitor(env_agent)

# Sprawdzenie zgodności środowiska z stable_baselines3
check_env(env_agent)

logger_callback = TrainingLoggerCallback()
# Tworzenie modelu PPO
model_agent = PPO(
    "MlpPolicy",
    env_agent,
    # policy_kwargs=dict(
    #     net_arch=[
    #         128,
    #         128,
    #     ]
    # ),
    #   learning_rate=0.00005,        # domyślnie 3e-4
    n_steps=400,  # liczba kroków zanim agent zrobi aktualizację
    batch_size=100,  # batch size do uczenia
    # n_epochs=10,                 # ile razy przebiega po danych przy każdej aktualizacji
    gamma=0.3,  # współczynnik dyskontujący nagrody
    # gae_lambda=0.95,             # współczynnik GAE
    # clip_range=0.2,              # zakres klipu PPO (stabilizacja treningu)
    # ent_coef=0.9,                # zachęta do eksploracji
    verbose=1,
)

# Trening modelu
model_agent.learn(total_timesteps=30_000, callback=logger_callback)


training_plot(logger_callback=logger_callback)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# c:\Users\ortek\AppData\Local\pypoetry\Cache\virtualenvs\forecasting-uBk3YmnA-py3.12\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -3.6e+05 |
# | time/              |          |
# |    fps             | 796      |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 400      |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -3.25e+05   |
# | time/                   |             |
# |    fps                  | 681         |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 800         |
# | train/                  |             |
# |    approx_kl            | 0.011142615 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -1.79e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.92e+06    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0241     |
# |    std                  | 0.995       |
# |    value_loss           | 1.3e+07     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.9e+05    |
# | time/                   |             |
# |    fps                  | 682         |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 1200        |
# | train/                  |             |
# |    approx_kl            | 0.012690199 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -2.56e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.12e+06    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.989       |
# |    value_loss           | 9.93e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.57e+05   |
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1600        |
# | train/                  |             |
# |    approx_kl            | 0.014276212 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -1.07e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56e+06    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0291     |
# |    std                  | 0.982       |
# |    value_loss           | 7.21e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.3e+05    |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2000        |
# | train/                  |             |
# |    approx_kl            | 0.014764796 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.88e+06    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.025      |
# |    std                  | 0.973       |
# |    value_loss           | 5.29e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2e+05      |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2400        |
# | train/                  |             |
# |    approx_kl            | 0.013168426 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -2.26e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.72e+06    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.022      |
# |    std                  | 0.965       |
# |    value_loss           | 3.97e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.77e+05    |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 7            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 2800         |
# | train/                  |              |
# |    approx_kl            | 0.0009381026 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 1.84e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99e+05     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0103      |
# |    std                  | 0.955        |
# |    value_loss           | 1.71e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.59e+05   |
# | time/                   |             |
# |    fps                  | 698         |
# |    iterations           | 8           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.014100673 |
# |    clip_fraction        | 0.09        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 3.28e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+06    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.95        |
# |    value_loss           | 1.25e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.42e+05    |
# | time/                   |              |
# |    fps                  | 696          |
# |    iterations           | 9            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3600         |
# | train/                  |              |
# |    approx_kl            | 0.0023963563 |
# |    clip_fraction        | 0.0045       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 3.96e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.31e+03     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0028      |
# |    std                  | 0.946        |
# |    value_loss           | 9.69e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.31e+05    |
# | time/                   |              |
# |    fps                  | 700          |
# |    iterations           | 10           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0040118396 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 6.14e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 75.6         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00464     |
# |    std                  | 0.946        |
# |    value_loss           | 2.71e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.23e+05   |
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 11          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4400        |
# | train/                  |             |
# |    approx_kl            | 0.002433381 |
# |    clip_fraction        | 0.012       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000153    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.99e+05    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.943       |
# |    value_loss           | 8.14e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 400           |
# |    ep_rew_mean          | -1.13e+05     |
# | time/                   |               |
# |    fps                  | 694           |
# |    iterations           | 12            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 4800          |
# | train/                  |               |
# |    approx_kl            | 0.00051706476 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.000191      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.39e+05      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | 0.00153       |
# |    std                  | 0.941         |
# |    value_loss           | 1.24e+06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.07e+05   |
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 13          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 5200        |
# | train/                  |             |
# |    approx_kl            | 0.002273555 |
# |    clip_fraction        | 0.00225     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000217    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0034     |
# |    std                  | 0.942       |
# |    value_loss           | 2.71e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -9.92e+04   |
# | time/                   |             |
# |    fps                  | 685         |
# |    iterations           | 14          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5600        |
# | train/                  |             |
# |    approx_kl            | 0.011484106 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.000448    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.42e+05    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.942       |
# |    value_loss           | 8.13e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -9.4e+04     |
# | time/                   |              |
# |    fps                  | 683          |
# |    iterations           | 15           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 6000         |
# | train/                  |              |
# |    approx_kl            | 0.0060698083 |
# |    clip_fraction        | 0.0565       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -1.11        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.6         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00838     |
# |    std                  | 0.944        |
# |    value_loss           | 145          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -8.87e+04    |
# | time/                   |              |
# |    fps                  | 683          |
# |    iterations           | 16           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0014311974 |
# |    clip_fraction        | 0.0025       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000116     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.42e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00385     |
# |    std                  | 0.946        |
# |    value_loss           | 5.43e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -8.35e+04    |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 17           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 6800         |
# | train/                  |              |
# |    approx_kl            | 0.0016937165 |
# |    clip_fraction        | 0.00225      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000173     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99e+05     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00487     |
# |    std                  | 0.947        |
# |    value_loss           | 2.71e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -7.99e+04   |
# | time/                   |             |
# |    fps                  | 674         |
# |    iterations           | 18          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 7200        |
# | train/                  |             |
# |    approx_kl            | 0.009120627 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.461      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00849    |
# |    std                  | 0.948       |
# |    value_loss           | 78.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -7.73e+04    |
# | time/                   |              |
# |    fps                  | 670          |
# |    iterations           | 19           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 7600         |
# | train/                  |              |
# |    approx_kl            | 0.0049890205 |
# |    clip_fraction        | 0.0162       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 3.43e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33           |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0039      |
# |    std                  | 0.95         |
# |    value_loss           | 6.98e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -7.34e+04    |
# | time/                   |              |
# |    fps                  | 666          |
# |    iterations           | 20           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 8000         |
# | train/                  |              |
# |    approx_kl            | 0.0018247416 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000393     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.15e+05     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 0.948        |
# |    value_loss           | 8.18e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -6.99e+04    |
# | time/                   |              |
# |    fps                  | 663          |
# |    iterations           | 21           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 8400         |
# | train/                  |              |
# |    approx_kl            | 0.0147953015 |
# |    clip_fraction        | 0.0872       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0788       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.4         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0158      |
# |    std                  | 0.954        |
# |    value_loss           | 67.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -6.72e+04   |
# | time/                   |             |
# |    fps                  | 661         |
# |    iterations           | 22          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8800        |
# | train/                  |             |
# |    approx_kl            | 0.019498862 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.281       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0225     |
# |    std                  | 0.973       |
# |    value_loss           | 33.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -6.51e+04   |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 23          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 9200        |
# | train/                  |             |
# |    approx_kl            | 0.028924324 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.000391   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.3e+03     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0143      |
# |    std                  | 0.973       |
# |    value_loss           | 2.72e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -6.32e+04   |
# | time/                   |             |
# |    fps                  | 658         |
# |    iterations           | 24          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 9600        |
# | train/                  |             |
# |    approx_kl            | 0.014153989 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -3.53e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.1        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000444   |
# |    std                  | 0.972       |
# |    value_loss           | 6.98e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -6.18e+04  |
# | time/                   |            |
# |    fps                  | 656        |
# |    iterations           | 25         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 10000      |
# | train/                  |            |
# |    approx_kl            | 0.01593865 |
# |    clip_fraction        | 0.0895     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.000219   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.56e+04   |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.00532    |
# |    std                  | 0.973      |
# |    value_loss           | 6.97e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -6.09e+04   |
# | time/                   |             |
# |    fps                  | 655         |
# |    iterations           | 26          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10400       |
# | train/                  |             |
# |    approx_kl            | 0.000568283 |
# |    clip_fraction        | 0.00075     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.000303    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+06    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00177    |
# |    std                  | 0.972       |
# |    value_loss           | 7.94e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -6.01e+04   |
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 27          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 10800       |
# | train/                  |             |
# |    approx_kl            | 0.000509156 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -0.000275   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39e+06    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00313    |
# |    std                  | 0.971       |
# |    value_loss           | 1.24e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.9e+04     |
# | time/                   |              |
# |    fps                  | 652          |
# |    iterations           | 28           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 11200        |
# | train/                  |              |
# |    approx_kl            | 0.0005678926 |
# |    clip_fraction        | 0.00125      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000232     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.79e+05     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00269     |
# |    std                  | 0.97         |
# |    value_loss           | 1.09e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.79e+04   |
# | time/                   |             |
# |    fps                  | 651         |
# |    iterations           | 29          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 11600       |
# | train/                  |             |
# |    approx_kl            | 0.002471988 |
# |    clip_fraction        | 0.0175      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.00056     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.59e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00394    |
# |    std                  | 0.969       |
# |    value_loss           | 9.69e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.73e+04    |
# | time/                   |              |
# |    fps                  | 648          |
# |    iterations           | 30           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0015720427 |
# |    clip_fraction        | 0.00025      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000843     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.46e+05     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00466     |
# |    std                  | 0.969        |
# |    value_loss           | 8.14e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.63e+04    |
# | time/                   |              |
# |    fps                  | 646          |
# |    iterations           | 31           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 12400        |
# | train/                  |              |
# |    approx_kl            | 0.0028234243 |
# |    clip_fraction        | 0.0065       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000104     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.4e+05      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00767     |
# |    std                  | 0.967        |
# |    value_loss           | 1.24e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.49e+04    |
# | time/                   |              |
# |    fps                  | 645          |
# |    iterations           | 32           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 0.0050548427 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000337     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.02e+05     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00789     |
# |    std                  | 0.967        |
# |    value_loss           | 8.13e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.43e+04   |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 33          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 13200       |
# | train/                  |             |
# |    approx_kl            | 0.008167494 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000123    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.36e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00891    |
# |    std                  | 0.967       |
# |    value_loss           | 2.72e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.56e+04    |
# | time/                   |              |
# |    fps                  | 638          |
# |    iterations           | 34           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 13600        |
# | train/                  |              |
# |    approx_kl            | 0.0010746575 |
# |    clip_fraction        | 0.00325      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.000577     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+06     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00256     |
# |    std                  | 0.967        |
# |    value_loss           | 1.13e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.43e+04    |
# | time/                   |              |
# |    fps                  | 636          |
# |    iterations           | 35           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 14000        |
# | train/                  |              |
# |    approx_kl            | 0.0037724061 |
# |    clip_fraction        | 0.00825      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00055      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.73e+04     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0124      |
# |    std                  | 0.966        |
# |    value_loss           | 3.59e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.27e+04    |
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 36           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 14400        |
# | train/                  |              |
# |    approx_kl            | 0.0031331875 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000923     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.99e+05     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00508     |
# |    std                  | 0.967        |
# |    value_loss           | 2.5e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.26e+04   |
# | time/                   |             |
# |    fps                  | 633         |
# |    iterations           | 37          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14800       |
# | train/                  |             |
# |    approx_kl            | 0.028327169 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.256       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 194         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.966       |
# |    value_loss           | 440         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.19e+04    |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 38           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 15200        |
# | train/                  |              |
# |    approx_kl            | 0.0029366438 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000422     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4e+06      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0101      |
# |    std                  | 0.965        |
# |    value_loss           | 1.71e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.07e+04    |
# | time/                   |              |
# |    fps                  | 631          |
# |    iterations           | 39           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 15600        |
# | train/                  |              |
# |    approx_kl            | 0.0007982021 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.000885     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+06     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.00175      |
# |    std                  | 0.964        |
# |    value_loss           | 7.93e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -5.24e+04  |
# | time/                   |            |
# |    fps                  | 629        |
# |    iterations           | 40         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 16000      |
# | train/                  |            |
# |    approx_kl            | 0.01119817 |
# |    clip_fraction        | 0.0437     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | -0.000936  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.09e+03   |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00409   |
# |    std                  | 0.963      |
# |    value_loss           | 2.73e+05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -5.2e+04   |
# | time/                   |            |
# |    fps                  | 628        |
# |    iterations           | 41         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 16400      |
# | train/                  |            |
# |    approx_kl            | 0.01823054 |
# |    clip_fraction        | 0.0592     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.000529   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.37e+05   |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0207    |
# |    std                  | 0.962      |
# |    value_loss           | 4.5e+06    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.21e+04   |
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 42          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16800       |
# | train/                  |             |
# |    approx_kl            | 0.004141624 |
# |    clip_fraction        | 0.011       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0004      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.5e+06     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00468    |
# |    std                  | 0.961       |
# |    value_loss           | 1.09e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.18e+04    |
# | time/                   |              |
# |    fps                  | 628          |
# |    iterations           | 43           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 17200        |
# | train/                  |              |
# |    approx_kl            | 0.0037988315 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00068      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.27e+05     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00994     |
# |    std                  | 0.96         |
# |    value_loss           | 2.15e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.28e+04    |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 44           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 17600        |
# | train/                  |              |
# |    approx_kl            | 0.0022053544 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00075      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.07e+05     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00332     |
# |    std                  | 0.959        |
# |    value_loss           | 1.21e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.18e+04   |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 45          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 18000       |
# | train/                  |             |
# |    approx_kl            | 0.024037138 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000856    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36e+06    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.958       |
# |    value_loss           | 4.08e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -5.06e+04    |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 46           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 18400        |
# | train/                  |              |
# |    approx_kl            | 0.0031223255 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00203      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.07e+04     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00463     |
# |    std                  | 0.957        |
# |    value_loss           | 2.72e+05     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -5.08e+04  |
# | time/                   |            |
# |    fps                  | 625        |
# |    iterations           | 47         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 18800      |
# | train/                  |            |
# |    approx_kl            | 0.03521324 |
# |    clip_fraction        | 0.147      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | 0.268      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 213        |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0204    |
# |    std                  | 0.957      |
# |    value_loss           | 694        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.05e+04   |
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 48          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 19200       |
# | train/                  |             |
# |    approx_kl            | 0.008551681 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00288     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+06    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.957       |
# |    value_loss           | 1.78e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.98e+04    |
# | time/                   |              |
# |    fps                  | 624          |
# |    iterations           | 49           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 19600        |
# | train/                  |              |
# |    approx_kl            | 0.0059015513 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00164      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.66e+03     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0107      |
# |    std                  | 0.956        |
# |    value_loss           | 1.24e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.89e+04   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 50          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.005589616 |
# |    clip_fraction        | 0.0192      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.000546    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.98e+05    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00158    |
# |    std                  | 0.953       |
# |    value_loss           | 5.21e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.81e+04   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 51          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 20400       |
# | train/                  |             |
# |    approx_kl            | 0.008592462 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00412     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.1e+04     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.000822   |
# |    std                  | 0.952       |
# |    value_loss           | 2.73e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.73e+04   |
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 52          |
# ...
# |    policy_gradient_loss | -0.00272     |
# |    std                  | 0.951        |
# |    value_loss           | 9.19e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.9e+04    |
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 59          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 23600       |
# | train/                  |             |
# |    approx_kl            | 0.015131682 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00334     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.48e+04    |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.951       |
# |    value_loss           | 3.46e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.83e+04    |
# | time/                   |              |
# |    fps                  | 625          |
# |    iterations           | 60           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 24000        |
# | train/                  |              |
# |    approx_kl            | 0.0045659556 |
# |    clip_fraction        | 0.0802       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00339      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.52e+04     |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.017       |
# |    std                  | 0.951        |
# |    value_loss           | 2.37e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.89e+04   |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 61          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 24400       |
# | train/                  |             |
# |    approx_kl            | 0.021514453 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00767     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.65e+03    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0005     |
# |    std                  | 0.95        |
# |    value_loss           | 2.74e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.81e+04   |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 62          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 24800       |
# | train/                  |             |
# |    approx_kl            | 0.008515998 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0034      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.73e+06    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00928    |
# |    std                  | 0.95        |
# |    value_loss           | 3.86e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.84e+04   |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 63          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 25200       |
# | train/                  |             |
# |    approx_kl            | 0.011924645 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00944     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5e+05       |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.000876    |
# |    std                  | 0.95        |
# |    value_loss           | 2.76e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.8e+04    |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 64          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.004571197 |
# |    clip_fraction        | 0.0135      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0047      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34e+06    |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00874    |
# |    std                  | 0.95        |
# |    value_loss           | 2.47e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.75e+04   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 65          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 26000       |
# | train/                  |             |
# |    approx_kl            | 0.023698969 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00645     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.99e+05    |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.949       |
# |    value_loss           | 8.15e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.69e+04   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 66          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 26400       |
# | train/                  |             |
# |    approx_kl            | 0.019916104 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00497     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.95e+05    |
# |    n_updates            | 650         |
# |    policy_gradient_loss | 0.00559     |
# |    std                  | 0.947       |
# |    value_loss           | 6.96e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.63e+04   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 67          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 26800       |
# | train/                  |             |
# |    approx_kl            | 0.006648632 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0073      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 665         |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.00449    |
# |    std                  | 0.947       |
# |    value_loss           | 2.71e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.56e+04   |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 68          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 27200       |
# | train/                  |             |
# |    approx_kl            | 0.004074633 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00612     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 465         |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.00456    |
# |    std                  | 0.946       |
# |    value_loss           | 2.71e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.51e+04   |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 69          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 27600       |
# | train/                  |             |
# |    approx_kl            | 0.038719047 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.389       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 506         |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.946       |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.44e+04   |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 70          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 28000       |
# | train/                  |             |
# |    approx_kl            | 0.003139922 |
# |    clip_fraction        | 0.0142      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00746     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.95e+05    |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00192    |
# |    std                  | 0.946       |
# |    value_loss           | 5.2e+05     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -4.4e+04   |
# | time/                   |            |
# |    fps                  | 626        |
# |    iterations           | 71         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 28400      |
# | train/                  |            |
# |    approx_kl            | 0.03632895 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.259      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.51e+03   |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.00941   |
# |    std                  | 0.945      |
# |    value_loss           | 2.65e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.39e+04    |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 72           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 28800        |
# | train/                  |              |
# |    approx_kl            | 0.0021404182 |
# |    clip_fraction        | 0.0055       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0067       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.68e+03     |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.0011      |
# |    std                  | 0.945        |
# |    value_loss           | 6.65e+05     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 400           |
# |    ep_rew_mean          | -4.34e+04     |
# | time/                   |               |
# |    fps                  | 626           |
# |    iterations           | 73            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 29200         |
# | train/                  |               |
# |    approx_kl            | 0.00048300083 |
# |    clip_fraction        | 0.0035        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.36         |
# |    explained_variance   | 0.00471       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.51e+05      |
# |    n_updates            | 720           |
# |    policy_gradient_loss | 0.00058       |
# |    std                  | 0.944         |
# |    value_loss           | 1.93e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -4.29e+04    |
# | time/                   |              |
# |    fps                  | 626          |
# |    iterations           | 74           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 29600        |
# | train/                  |              |
# |    approx_kl            | 0.0006103772 |
# |    clip_fraction        | 0.0025       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.0105       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.99e+03     |
# |    n_updates            | 730          |
# |    policy_gradient_loss | -0.00134     |
# |    std                  | 0.945        |
# |    value_loss           | 2.75e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.26e+04   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 75          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 30000       |
# | train/                  |             |
# |    approx_kl            | 0.007158684 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00835     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.98e+05    |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.00468    |
# |    std                  | 0.945       |
# |    value_loss           | 5.25e+05    |
# -----------------------------------------

# %%
env_predict, lista = predict_data_env(
    env=PortfolioValueTradingEnvUpdated, data=prices, agent=model_agent
)
# Out:
# Krok: 1|Cena: 5.17|Gotówka: 34.92|Akcje: 13|Wartość portfela: 102.11|Nagroda: 0.26|
# Krok: 2|Cena: 5.39|Gotówka: 3.91|Akcje: 19|Wartość portfela: 106.36|Nagroda: 3.08|
# Krok: 3|Cena: 5.58|Gotówka: 3.91|Akcje: 19|Wartość portfela: 109.98|Nagroda: 4.25|
# Krok: 4|Cena: 5.71|Gotówka: 3.91|Akcje: 19|Wartość portfela: 112.38|Nagroda: 3.62|
# Krok: 5|Cena: 5.90|Gotówka: 3.91|Akcje: 19|Wartość portfela: 116.07|Nagroda: 2.40|
# Krok: 6|Cena: 6.11|Gotówka: 3.91|Akcje: 19|Wartość portfela: 119.99|Nagroda: 3.69|
# Krok: 7|Cena: 6.27|Gotówka: 3.91|Akcje: 19|Wartość portfela: 123.12|Nagroda: 3.92|
# Krok: 8|Cena: 6.45|Gotówka: 3.91|Akcje: 19|Wartość portfela: 126.43|Nagroda: 3.12|
# Krok: 9|Cena: 6.59|Gotówka: 3.91|Akcje: 19|Wartość portfela: 129.20|Nagroda: 3.31|
# Krok: 10|Cena: 6.78|Gotówka: 3.91|Akcje: 19|Wartość portfela: 132.82|Nagroda: 2.77|
# Krok: 11|Cena: 6.93|Gotówka: 3.91|Akcje: 19|Wartość portfela: 135.62|Nagroda: 3.62|
# Krok: 12|Cena: 7.06|Gotówka: 3.91|Akcje: 19|Wartość portfela: 138.04|Nagroda: 2.79|
# Krok: 13|Cena: 7.21|Gotówka: 3.91|Akcje: 19|Wartość portfela: 140.97|Nagroda: 2.42|
# Krok: 14|Cena: 7.33|Gotówka: 3.91|Akcje: 19|Wartość portfela: 143.09|Nagroda: 2.94|
# Krok: 15|Cena: 7.41|Gotówka: 3.91|Akcje: 19|Wartość portfela: 144.78|Nagroda: 2.12|
# Krok: 16|Cena: 7.54|Gotówka: 3.91|Akcje: 19|Wartość portfela: 147.26|Nagroda: 1.69|
# Krok: 17|Cena: 7.61|Gotówka: 3.91|Akcje: 19|Wartość portfela: 148.57|Nagroda: 2.48|
# Krok: 18|Cena: 7.74|Gotówka: 3.91|Akcje: 19|Wartość portfela: 150.89|Nagroda: 1.31|
# Krok: 19|Cena: 7.79|Gotówka: 3.91|Akcje: 19|Wartość portfela: 151.95|Nagroda: 2.32|
# Krok: 20|Cena: 7.85|Gotówka: 3.91|Akcje: 19|Wartość portfela: 153.11|Nagroda: 1.06|
# Krok: 21|Cena: 7.89|Gotówka: 3.91|Akcje: 19|Wartość portfela: 153.91|Nagroda: 1.15|
# Krok: 22|Cena: 7.97|Gotówka: 3.91|Akcje: 19|Wartość portfela: 155.40|Nagroda: 0.80|
# Krok: 23|Cena: 7.97|Gotówka: 3.91|Akcje: 19|Wartość portfela: 155.43|Nagroda: 1.49|
# Krok: 24|Cena: 7.99|Gotówka: 3.91|Akcje: 19|Wartość portfela: 155.65|Nagroda: 0.03|
# Krok: 25|Cena: 7.99|Gotówka: 3.91|Akcje: 19|Wartość portfela: 155.78|Nagroda: 0.22|
# Krok: 26|Cena: 8.00|Gotówka: 3.91|Akcje: 19|Wartość portfela: 155.99|Nagroda: 0.13|
# Krok: 27|Cena: 7.98|Gotówka: 3.91|Akcje: 19|Wartość portfela: 155.57|Nagroda: 0.21|
# Krok: 28|Cena: 7.95|Gotówka: 3.91|Akcje: 19|Wartość portfela: 155.01|Nagroda: -0.42|
# Krok: 29|Cena: 7.91|Gotówka: 3.91|Akcje: 19|Wartość portfela: 154.22|Nagroda: -0.56|
# Krok: 30|Cena: 7.89|Gotówka: 11.82|Akcje: 18|Wartość portfela: 153.87|Nagroda: -0.75|
# Krok: 31|Cena: 7.78|Gotówka: 11.82|Akcje: 18|Wartość portfela: 151.79|Nagroda: -0.35|
# Krok: 32|Cena: 7.70|Gotówka: 66.25|Akcje: 11|Wartość portfela: 150.93|Nagroda: -1.27|
# Krok: 33|Cena: 7.61|Gotówka: 81.65|Akcje: 9|Wartość portfela: 150.10|Nagroda: -0.70|
# Krok: 34|Cena: 7.54|Gotówka: 119.67|Akcje: 4|Wartość portfela: 149.82|Nagroda: -0.37|
# Krok: 35|Cena: 7.44|Gotówka: 134.75|Akcje: 2|Wartość portfela: 149.63|Nagroda: -0.14|
# Krok: 36|Cena: 7.30|Gotówka: 134.75|Akcje: 2|Wartość portfela: 149.34|Nagroda: -0.19|
# Krok: 37|Cena: 7.16|Gotówka: 134.75|Akcje: 2|Wartość portfela: 149.06|Nagroda: -0.28|
# Krok: 38|Cena: 7.02|Gotówka: 134.75|Akcje: 2|Wartość portfela: 148.80|Nagroda: -0.28|
# Krok: 39|Cena: 6.91|Gotówka: 134.75|Akcje: 2|Wartość portfela: 148.57|Nagroda: -0.27|
# Krok: 40|Cena: 6.76|Gotówka: 134.75|Akcje: 2|Wartość portfela: 148.27|Nagroda: -0.23|
# Krok: 41|Cena: 6.60|Gotówka: 134.75|Akcje: 2|Wartość portfela: 147.95|Nagroda: -0.30|
# Krok: 42|Cena: 6.41|Gotówka: 134.75|Akcje: 2|Wartość portfela: 147.58|Nagroda: -0.32|
# Krok: 43|Cena: 6.26|Gotówka: 134.75|Akcje: 2|Wartość portfela: 147.28|Nagroda: -0.37|
# Krok: 44|Cena: 6.09|Gotówka: 134.75|Akcje: 2|Wartość portfela: 146.92|Nagroda: -0.30|
# Krok: 45|Cena: 5.91|Gotówka: 134.75|Akcje: 2|Wartość portfela: 146.57|Nagroda: -0.35|
# Krok: 46|Cena: 5.74|Gotówka: 134.75|Akcje: 2|Wartość portfela: 146.23|Nagroda: -0.35|
# Krok: 47|Cena: 5.54|Gotówka: 134.75|Akcje: 2|Wartość portfela: 145.84|Nagroda: -0.34|
# Krok: 48|Cena: 5.37|Gotówka: 134.75|Akcje: 2|Wartość portfela: 145.48|Nagroda: -0.40|
# Krok: 49|Cena: 5.17|Gotówka: 134.75|Akcje: 2|Wartość portfela: 145.08|Nagroda: -0.36|
# Krok: 50|Cena: 4.98|Gotówka: 134.75|Akcje: 2|Wartość portfela: 144.71|Nagroda: -0.40|
# Krok: 51|Cena: 4.80|Gotówka: 134.75|Akcje: 2|Wartość portfela: 144.35|Nagroda: -0.37|
# Krok: 52|Cena: 4.57|Gotówka: 134.75|Akcje: 2|Wartość portfela: 143.89|Nagroda: -0.36|
# Krok: 53|Cena: 4.41|Gotówka: 134.75|Akcje: 2|Wartość portfela: 143.56|Nagroda: -0.46|
# Krok: 54|Cena: 4.22|Gotówka: 134.75|Akcje: 2|Wartość portfela: 143.19|Nagroda: -0.33|
# Krok: 55|Cena: 4.04|Gotówka: 134.75|Akcje: 2|Wartość portfela: 142.82|Nagroda: -0.37|
# Krok: 56|Cena: 3.87|Gotówka: 134.75|Akcje: 2|Wartość portfela: 142.48|Nagroda: -0.37|
# Krok: 57|Cena: 3.73|Gotówka: 134.75|Akcje: 2|Wartość portfela: 142.20|Nagroda: -0.34|
# Krok: 58|Cena: 3.51|Gotówka: 134.75|Akcje: 2|Wartość portfela: 141.78|Nagroda: -0.27|
# Krok: 59|Cena: 3.39|Gotówka: 134.75|Akcje: 2|Wartość portfela: 141.53|Nagroda: -0.43|
# Krok: 60|Cena: 3.18|Gotówka: 134.75|Akcje: 2|Wartość portfela: 141.11|Nagroda: -0.25|
# Krok: 61|Cena: 3.06|Gotówka: 134.75|Akcje: 2|Wartość portfela: 140.87|Nagroda: -0.42|
# Krok: 62|Cena: 2.93|Gotówka: 134.75|Akcje: 2|Wartość portfela: 140.60|Nagroda: -0.24|
# Krok: 63|Cena: 2.80|Gotówka: 134.75|Akcje: 2|Wartość portfela: 140.36|Nagroda: -0.26|
# Krok: 64|Cena: 2.68|Gotówka: 134.75|Akcje: 2|Wartość portfela: 140.12|Nagroda: -0.25|
# Krok: 65|Cena: 2.57|Gotówka: 134.75|Akcje: 2|Wartość portfela: 139.89|Nagroda: -0.24|
# Krok: 66|Cena: 2.44|Gotówka: 134.75|Akcje: 2|Wartość portfela: 139.64|Nagroda: -0.23|
# Krok: 67|Cena: 2.35|Gotówka: 134.75|Akcje: 2|Wartość portfela: 139.44|Nagroda: -0.25|
# Krok: 68|Cena: 2.29|Gotówka: 134.75|Akcje: 2|Wartość portfela: 139.33|Nagroda: -0.19|
# Krok: 69|Cena: 2.20|Gotówka: 134.75|Akcje: 2|Wartość portfela: 139.14|Nagroda: -0.12|
# Krok: 70|Cena: 2.11|Gotówka: 134.75|Akcje: 2|Wartość portfela: 138.97|Nagroda: -0.19|
# Krok: 71|Cena: 2.06|Gotówka: 134.75|Akcje: 2|Wartość portfela: 138.88|Nagroda: -0.17|
# Krok: 72|Cena: 2.03|Gotówka: 134.75|Akcje: 2|Wartość portfela: 138.81|Nagroda: -0.10|
# Krok: 73|Cena: 2.03|Gotówka: 134.75|Akcje: 2|Wartość portfela: 138.81|Nagroda: -0.07|
# Krok: 74|Cena: 2.01|Gotówka: 43.42|Akcje: 47|Wartość portfela: 137.74|Nagroda: 0.04|
# Krok: 75|Cena: 2.01|Gotówka: 47.44|Akcje: 45|Wartość portfela: 138.07|Nagroda: -1.02|
# Krok: 76|Cena: 2.00|Gotówka: 1.11|Akcje: 68|Wartość portfela: 137.10|Nagroda: 0.49|
# Krok: 77|Cena: 2.03|Gotówka: 1.11|Akcje: 68|Wartość portfela: 139.26|Nagroda: -0.96|
# Krok: 78|Cena: 2.07|Gotówka: 1.11|Akcje: 68|Wartość portfela: 142.06|Nagroda: 2.16|
# Krok: 79|Cena: 2.10|Gotówka: 1.11|Akcje: 68|Wartość portfela: 143.75|Nagroda: 2.80|
# Krok: 80|Cena: 2.17|Gotówka: 1.11|Akcje: 68|Wartość portfela: 148.53|Nagroda: 1.69|
# Krok: 81|Cena: 2.21|Gotówka: 1.11|Akcje: 68|Wartość portfela: 151.51|Nagroda: 4.78|
# Krok: 82|Cena: 2.29|Gotówka: 1.11|Akcje: 68|Wartość portfela: 157.17|Nagroda: 2.98|
# Krok: 83|Cena: 2.38|Gotówka: 1.11|Akcje: 68|Wartość portfela: 163.13|Nagroda: 5.66|
# Krok: 84|Cena: 2.46|Gotówka: 1.11|Akcje: 68|Wartość portfela: 168.70|Nagroda: 5.96|
# Krok: 85|Cena: 2.61|Gotówka: 1.11|Akcje: 68|Wartość portfela: 178.36|Nagroda: 5.58|
# Krok: 86|Cena: 2.71|Gotówka: 1.11|Akcje: 68|Wartość portfela: 185.07|Nagroda: 9.65|
# Krok: 87|Cena: 2.84|Gotówka: 1.11|Akcje: 68|Wartość portfela: 194.35|Nagroda: 6.71|
# Krok: 88|Cena: 2.99|Gotówka: 1.11|Akcje: 68|Wartość portfela: 204.19|Nagroda: 9.28|
# Krok: 89|Cena: 3.13|Gotówka: 1.11|Akcje: 68|Wartość portfela: 213.90|Nagroda: 9.85|
# Krok: 90|Cena: 3.28|Gotówka: 1.11|Akcje: 68|Wartość portfela: 224.46|Nagroda: 9.71|
# Krok: 91|Cena: 3.43|Gotówka: 1.11|Akcje: 68|Wartość portfela: 234.15|Nagroda: 10.56|
# Krok: 92|Cena: 3.58|Gotówka: 1.11|Akcje: 68|Wartość portfela: 244.86|Nagroda: 9.69|
# Krok: 93|Cena: 3.76|Gotówka: 1.11|Akcje: 68|Wartość portfela: 256.86|Nagroda: 10.71|
# Krok: 94|Cena: 3.90|Gotówka: 1.11|Akcje: 68|Wartość portfela: 266.54|Nagroda: 12.00|
# Krok: 95|Cena: 4.09|Gotówka: 1.11|Akcje: 68|Wartość portfela: 279.01|Nagroda: 9.68|
# Krok: 96|Cena: 4.27|Gotówka: 1.11|Akcje: 68|Wartość portfela: 291.57|Nagroda: 12.48|
# Krok: 97|Cena: 4.46|Gotówka: 1.11|Akcje: 68|Wartość portfela: 304.60|Nagroda: 12.56|
# Krok: 98|Cena: 4.68|Gotówka: 1.11|Akcje: 68|Wartość portfela: 319.22|Nagroda: 13.02|
# Krok: 99|Cena: 4.84|Gotówka: 1.11|Akcje: 68|Wartość portfela: 330.25|Nagroda: 14.62|
# Krok: 100|Cena: 5.04|Gotówka: 1.11|Akcje: 68|Wartość portfela: 343.81|Nagroda: 11.03|
# Krok: 101|Cena: 5.26|Gotówka: 1.11|Akcje: 68|Wartość portfela: 358.93|Nagroda: 13.56|
# Krok: 102|Cena: 5.42|Gotówka: 1.11|Akcje: 68|Wartość portfela: 369.44|Nagroda: 15.11|
# Krok: 103|Cena: 5.62|Gotówka: 1.11|Akcje: 68|Wartość portfela: 383.59|Nagroda: 10.52|
# Krok: 104|Cena: 5.77|Gotówka: 1.11|Akcje: 68|Wartość portfela: 393.81|Nagroda: 14.14|
# Krok: 105|Cena: 5.97|Gotówka: 1.11|Akcje: 68|Wartość portfela: 407.07|Nagroda: 10.22|
# Krok: 106|Cena: 6.13|Gotówka: 1.11|Akcje: 68|Wartość portfela: 418.07|Nagroda: 13.27|
# Krok: 107|Cena: 6.32|Gotówka: 1.11|Akcje: 68|Wartość portfela: 430.61|Nagroda: 11.00|
# Krok: 108|Cena: 6.51|Gotówka: 1.11|Akcje: 68|Wartość portfela: 443.56|Nagroda: 12.53|
# Krok: 109|Cena: 6.62|Gotówka: 1.11|Akcje: 68|Wartość portfela: 451.01|Nagroda: 12.95|
# Krok: 110|Cena: 6.81|Gotówka: 1.11|Akcje: 68|Wartość portfela: 464.45|Nagroda: 7.45|
# Krok: 111|Cena: 6.96|Gotówka: 1.11|Akcje: 68|Wartość portfela: 474.20|Nagroda: 13.44|
# Krok: 112|Cena: 7.08|Gotówka: 1.11|Akcje: 68|Wartość portfela: 482.55|Nagroda: 9.75|
# Krok: 113|Cena: 7.19|Gotówka: 1.11|Akcje: 68|Wartość portfela: 490.32|Nagroda: 8.36|
# Krok: 114|Cena: 7.35|Gotówka: 1.11|Akcje: 68|Wartość portfela: 500.70|Nagroda: 7.76|
# Krok: 115|Cena: 7.45|Gotówka: 1.11|Akcje: 68|Wartość portfela: 507.58|Nagroda: 10.39|
# Krok: 116|Cena: 7.57|Gotówka: 1.11|Akcje: 68|Wartość portfela: 515.64|Nagroda: 6.87|
# Krok: 117|Cena: 7.66|Gotówka: 1.11|Akcje: 68|Wartość portfela: 521.69|Nagroda: 8.06|
# Krok: 118|Cena: 7.77|Gotówka: 1.11|Akcje: 68|Wartość portfela: 529.46|Nagroda: 6.05|
# Krok: 119|Cena: 7.80|Gotówka: 1.11|Akcje: 68|Wartość portfela: 531.84|Nagroda: 7.77|
# Krok: 120|Cena: 7.85|Gotówka: 1.11|Akcje: 68|Wartość portfela: 534.89|Nagroda: 2.38|
# Krok: 121|Cena: 7.92|Gotówka: 1.11|Akcje: 68|Wartość portfela: 539.88|Nagroda: 3.06|
# Krok: 122|Cena: 7.96|Gotówka: 1.11|Akcje: 68|Wartość portfela: 542.50|Nagroda: 4.99|
# Krok: 123|Cena: 8.01|Gotówka: 1.11|Akcje: 68|Wartość portfela: 545.81|Nagroda: 2.62|
# Krok: 124|Cena: 8.01|Gotówka: 1.11|Akcje: 68|Wartość portfela: 546.06|Nagroda: 3.31|
# Krok: 125|Cena: 8.01|Gotówka: 1.11|Akcje: 68|Wartość portfela: 545.56|Nagroda: 0.25|
# Krok: 126|Cena: 8.02|Gotówka: 1.11|Akcje: 68|Wartość portfela: 546.41|Nagroda: -0.50|
# Krok: 127|Cena: 7.94|Gotówka: 1.11|Akcje: 68|Wartość portfela: 541.34|Nagroda: 0.85|
# Krok: 128|Cena: 7.92|Gotówka: 1.11|Akcje: 68|Wartość portfela: 539.82|Nagroda: -5.07|
# Krok: 129|Cena: 7.87|Gotówka: 1.11|Akcje: 68|Wartość portfela: 536.37|Nagroda: -1.52|
# Krok: 130|Cena: 7.83|Gotówka: 1.11|Akcje: 68|Wartość portfela: 533.27|Nagroda: -3.45|
# Krok: 131|Cena: 7.74|Gotówka: 1.11|Akcje: 68|Wartość portfela: 527.33|Nagroda: -3.11|
# Krok: 132|Cena: 7.70|Gotówka: 1.11|Akcje: 68|Wartość portfela: 524.72|Nagroda: -5.94|
# Krok: 133|Cena: 7.59|Gotówka: 1.11|Akcje: 68|Wartość portfela: 517.48|Nagroda: -2.61|
# Krok: 134|Cena: 7.47|Gotówka: 8.71|Akcje: 67|Wartość portfela: 509.14|Nagroda: -7.13|
# Krok: 135|Cena: 7.37|Gotówka: 98.34|Akcje: 55|Wartość portfela: 503.61|Nagroda: -6.85|
# Krok: 136|Cena: 7.28|Gotówka: 334.13|Akcje: 23|Wartość portfela: 501.49|Nagroda: -2.31|
# Krok: 137|Cena: 7.16|Gotówka: 450.56|Akcje: 7|Wartość portfela: 500.67|Nagroda: -0.65|
# Krok: 138|Cena: 7.05|Gotówka: 472.03|Akcje: 4|Wartość portfela: 500.21|Nagroda: -0.47|
# Krok: 139|Cena: 6.92|Gotówka: 479.08|Akcje: 3|Wartość portfela: 499.84|Nagroda: -0.34|
# Krok: 140|Cena: 6.72|Gotówka: 486.00|Akcje: 2|Wartość portfela: 499.43|Nagroda: -0.25|
# Krok: 141|Cena: 6.53|Gotówka: 486.00|Akcje: 2|Wartość portfela: 499.06|Nagroda: -0.40|
# Krok: 142|Cena: 6.34|Gotówka: 486.00|Akcje: 2|Wartość portfela: 498.68|Nagroda: -0.37|
# Krok: 143|Cena: 6.22|Gotówka: 486.00|Akcje: 2|Wartość portfela: 498.44|Nagroda: -0.38|
# Krok: 144|Cena: 6.02|Gotówka: 486.00|Akcje: 2|Wartość portfela: 498.05|Nagroda: -0.24|
# Krok: 145|Cena: 5.85|Gotówka: 486.00|Akcje: 2|Wartość portfela: 497.70|Nagroda: -0.39|
# Krok: 146|Cena: 5.67|Gotówka: 486.00|Akcje: 2|Wartość portfela: 497.33|Nagroda: -0.34|
# Krok: 147|Cena: 5.49|Gotówka: 486.00|Akcje: 2|Wartość portfela: 496.98|Nagroda: -0.37|
# Krok: 148|Cena: 5.33|Gotówka: 486.00|Akcje: 2|Wartość portfela: 496.65|Nagroda: -0.35|
# Krok: 149|Cena: 5.12|Gotówka: 486.00|Akcje: 2|Wartość portfela: 496.24|Nagroda: -0.33|
# Krok: 150|Cena: 4.93|Gotówka: 486.00|Akcje: 2|Wartość portfela: 495.85|Nagroda: -0.41|
# Krok: 151|Cena: 4.72|Gotówka: 486.00|Akcje: 2|Wartość portfela: 495.44|Nagroda: -0.39|
# Krok: 152|Cena: 4.52|Gotówka: 486.00|Akcje: 2|Wartość portfela: 495.04|Nagroda: -0.41|
# Krok: 153|Cena: 4.36|Gotówka: 486.00|Akcje: 2|Wartość portfela: 494.71|Nagroda: -0.40|
# Krok: 154|Cena: 4.18|Gotówka: 486.00|Akcje: 2|Wartość portfela: 494.36|Nagroda: -0.32|
# Krok: 155|Cena: 4.04|Gotówka: 486.00|Akcje: 2|Wartość portfela: 494.08|Nagroda: -0.35|
# Krok: 156|Cena: 3.83|Gotówka: 486.00|Akcje: 2|Wartość portfela: 493.66|Nagroda: -0.29|
# Krok: 157|Cena: 3.68|Gotówka: 486.00|Akcje: 2|Wartość portfela: 493.35|Nagroda: -0.42|
# Krok: 158|Cena: 3.48|Gotówka: 486.00|Akcje: 2|Wartość portfela: 492.96|Nagroda: -0.31|
# Krok: 159|Cena: 3.31|Gotówka: 486.00|Akcje: 2|Wartość portfela: 492.61|Nagroda: -0.39|
# Krok: 160|Cena: 3.16|Gotówka: 486.00|Akcje: 2|Wartość portfela: 492.31|Nagroda: -0.35|
# Krok: 161|Cena: 3.02|Gotówka: 486.00|Akcje: 2|Wartość portfela: 492.03|Nagroda: -0.30|
# Krok: 162|Cena: 2.93|Gotówka: 486.00|Akcje: 2|Wartość portfela: 491.86|Nagroda: -0.28|
# Krok: 163|Cena: 2.74|Gotówka: 486.00|Akcje: 2|Wartość portfela: 491.49|Nagroda: -0.16|
# Krok: 164|Cena: 2.66|Gotówka: 486.00|Akcje: 2|Wartość portfela: 491.31|Nagroda: -0.38|
# Krok: 165|Cena: 2.51|Gotówka: 486.00|Akcje: 2|Wartość portfela: 491.02|Nagroda: -0.18|
# Krok: 166|Cena: 2.44|Gotówka: 486.00|Akcje: 2|Wartość portfela: 490.89|Nagroda: -0.29|
# Krok: 167|Cena: 2.34|Gotówka: 486.00|Akcje: 2|Wartość portfela: 490.68|Nagroda: -0.13|
# Krok: 168|Cena: 2.25|Gotówka: 486.00|Akcje: 2|Wartość portfela: 490.50|Nagroda: -0.21|
# Krok: 169|Cena: 2.18|Gotówka: 486.00|Akcje: 2|Wartość portfela: 490.36|Nagroda: -0.18|
# Krok: 170|Cena: 2.11|Gotówka: 486.00|Akcje: 2|Wartość portfela: 490.22|Nagroda: -0.14|
# Krok: 171|Cena: 2.08|Gotówka: 486.00|Akcje: 2|Wartość portfela: 490.17|Nagroda: -0.14|
# Krok: 172|Cena: 2.03|Gotówka: 486.00|Akcje: 2|Wartość portfela: 490.06|Nagroda: -0.05|
# Krok: 173|Cena: 1.99|Gotówka: 486.00|Akcje: 2|Wartość portfela: 489.98|Nagroda: -0.11|
# Krok: 174|Cena: 1.98|Gotówka: 486.00|Akcje: 2|Wartość portfela: 489.95|Nagroda: -0.08|
# Krok: 175|Cena: 2.00|Gotówka: 486.00|Akcje: 2|Wartość portfela: 490.01|Nagroda: -0.03|
# Krok: 176|Cena: 2.04|Gotówka: 141.21|Akcje: 174|Wartość portfela: 496.84|Nagroda: 4.92|
# Krok: 177|Cena: 2.04|Gotówka: 2.22|Akcje: 242|Wartość portfela: 495.54|Nagroda: 9.51|
# Krok: 178|Cena: 2.07|Gotówka: 2.22|Akcje: 242|Wartość portfela: 502.60|Nagroda: -1.30|
# Krok: 179|Cena: 2.12|Gotówka: 0.16|Akcje: 243|Wartość portfela: 515.84|Nagroda: 7.09|
# Krok: 180|Cena: 2.20|Gotówka: 0.16|Akcje: 243|Wartość portfela: 534.85|Nagroda: 13.24|
# Krok: 181|Cena: 2.25|Gotówka: 0.16|Akcje: 243|Wartość portfela: 546.34|Nagroda: 19.01|
# Krok: 182|Cena: 2.32|Gotówka: 0.16|Akcje: 243|Wartość portfela: 562.71|Nagroda: 11.49|
# Krok: 183|Cena: 2.44|Gotówka: 0.16|Akcje: 243|Wartość portfela: 592.09|Nagroda: 16.37|
# Krok: 184|Cena: 2.52|Gotówka: 0.16|Akcje: 243|Wartość portfela: 613.30|Nagroda: 29.38|
# Krok: 185|Cena: 2.66|Gotówka: 0.16|Akcje: 243|Wartość portfela: 645.58|Nagroda: 21.21|
# Krok: 186|Cena: 2.75|Gotówka: 0.16|Akcje: 243|Wartość portfela: 668.19|Nagroda: 32.28|
# Krok: 187|Cena: 2.85|Gotówka: 0.16|Akcje: 243|Wartość portfela: 692.71|Nagroda: 22.61|
# Krok: 188|Cena: 2.98|Gotówka: 0.16|Akcje: 243|Wartość portfela: 725.42|Nagroda: 24.52|
# Krok: 189|Cena: 3.19|Gotówka: 0.16|Akcje: 243|Wartość portfela: 775.42|Nagroda: 32.71|
# Krok: 190|Cena: 3.34|Gotówka: 0.16|Akcje: 243|Wartość portfela: 812.87|Nagroda: 50.00|
# Krok: 191|Cena: 3.47|Gotówka: 0.16|Akcje: 243|Wartość portfela: 842.35|Nagroda: 37.45|
# Krok: 192|Cena: 3.63|Gotówka: 0.16|Akcje: 243|Wartość portfela: 881.57|Nagroda: 29.48|
# Krok: 193|Cena: 3.83|Gotówka: 0.16|Akcje: 243|Wartość portfela: 932.05|Nagroda: 39.21|
# Krok: 194|Cena: 3.96|Gotówka: 0.16|Akcje: 243|Wartość portfela: 962.24|Nagroda: 50.49|
# Krok: 195|Cena: 4.14|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1006.93|Nagroda: 30.19|
# Krok: 196|Cena: 4.36|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1058.86|Nagroda: 44.69|
# Krok: 197|Cena: 4.52|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1098.91|Nagroda: 51.94|
# Krok: 198|Cena: 4.72|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1146.36|Nagroda: 40.05|
# Krok: 199|Cena: 4.90|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1191.41|Nagroda: 47.44|
# Krok: 200|Cena: 5.10|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1239.75|Nagroda: 45.05|
# Krok: 201|Cena: 5.31|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1290.77|Nagroda: 48.35|
# Krok: 202|Cena: 5.47|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1329.92|Nagroda: 51.02|
# Krok: 203|Cena: 5.67|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1377.70|Nagroda: 39.15|
# Krok: 204|Cena: 5.80|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1409.07|Nagroda: 47.78|
# Krok: 205|Cena: 6.02|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1462.45|Nagroda: 31.37|
# Krok: 206|Cena: 6.18|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1501.26|Nagroda: 53.38|
# Krok: 207|Cena: 6.34|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1540.96|Nagroda: 38.81|
# Krok: 208|Cena: 6.51|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1582.82|Nagroda: 39.70|
# Krok: 209|Cena: 6.68|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1624.19|Nagroda: 41.86|
# Krok: 210|Cena: 6.86|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1667.37|Nagroda: 41.37|
# Krok: 211|Cena: 6.96|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1691.80|Nagroda: 43.18|
# Krok: 212|Cena: 7.13|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1731.80|Nagroda: 24.43|
# Krok: 213|Cena: 7.24|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1760.66|Nagroda: 40.00|
# Krok: 214|Cena: 7.37|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1790.61|Nagroda: 28.86|
# Krok: 215|Cena: 7.51|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1823.97|Nagroda: 29.95|
# Krok: 216|Cena: 7.60|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1846.21|Nagroda: 33.36|
# Krok: 217|Cena: 7.70|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1872.11|Nagroda: 22.24|
# Krok: 218|Cena: 7.75|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1884.29|Nagroda: 25.89|
# Krok: 219|Cena: 7.81|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1898.43|Nagroda: 12.18|
# Krok: 220|Cena: 7.88|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1914.78|Nagroda: 14.14|
# Krok: 221|Cena: 7.93|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1928.31|Nagroda: 16.34|
# Krok: 222|Cena: 7.97|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1936.44|Nagroda: 13.54|
# Krok: 223|Cena: 7.97|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1935.90|Nagroda: 8.13|
# Krok: 224|Cena: 8.00|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1944.32|Nagroda: -0.54|
# Krok: 225|Cena: 8.00|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1944.81|Nagroda: 8.42|
# Krok: 226|Cena: 8.04|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1952.86|Nagroda: 0.49|
# Krok: 227|Cena: 8.00|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1943.80|Nagroda: 8.06|
# Krok: 228|Cena: 7.91|Gotówka: 0.16|Akcje: 243|Wartość portfela: 1921.73|Nagroda: -9.06|
# Krok: 229|Cena: 7.87|Gotówka: 23.88|Akcje: 240|Wartość portfela: 1912.97|Nagroda: -21.80|
# Krok: 230|Cena: 7.79|Gotówka: 8.14|Akcje: 242|Wartość portfela: 1892.94|Nagroda: -8.83|
# Krok: 231|Cena: 7.74|Gotówka: 8.14|Akcje: 242|Wartość portfela: 1880.13|Nagroda: -20.03|
# Krok: 232|Cena: 7.67|Gotówka: 8.14|Akcje: 242|Wartość portfela: 1864.84|Nagroda: -12.81|
# Krok: 233|Cena: 7.60|Gotówka: 8.14|Akcje: 242|Wartość portfela: 1846.91|Nagroda: -15.29|
# Krok: 234|Cena: 7.46|Gotówka: 8.14|Akcje: 242|Wartość portfela: 1812.84|Nagroda: -17.93|
# Krok: 235|Cena: 7.35|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 236|Cena: 7.20|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 237|Cena: 7.11|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 238|Cena: 6.95|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 239|Cena: 6.81|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 240|Cena: 6.65|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 241|Cena: 6.51|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 242|Cena: 6.31|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 243|Cena: 6.14|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 244|Cena: 6.04|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 245|Cena: 5.79|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 246|Cena: 5.61|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 247|Cena: 5.48|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 248|Cena: 5.32|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 249|Cena: 5.05|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 250|Cena: 4.87|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 251|Cena: 4.70|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 252|Cena: 4.54|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 253|Cena: 4.30|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 254|Cena: 4.13|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 255|Cena: 3.97|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 256|Cena: 3.79|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 257|Cena: 3.61|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 258|Cena: 3.45|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 259|Cena: 3.26|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 260|Cena: 3.13|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 261|Cena: 2.99|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 262|Cena: 2.86|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 263|Cena: 2.72|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 264|Cena: 2.62|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 265|Cena: 2.52|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 266|Cena: 2.41|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 267|Cena: 2.32|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 268|Cena: 2.24|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 269|Cena: 2.17|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 270|Cena: 2.10|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 271|Cena: 2.07|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 272|Cena: 2.03|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 273|Cena: 2.05|Gotówka: 1812.84|Akcje: 0|Wartość portfela: 1812.84|Nagroda: 0.00|
# Krok: 274|Cena: 2.03|Gotówka: 550.80|Akcje: 615|Wartość portfela: 1800.51|Nagroda: 13.71|
# Krok: 275|Cena: 2.01|Gotówka: 1030.36|Akcje: 379|Wartość portfela: 1792.35|Nagroda: -7.60|
# Krok: 276|Cena: 2.00|Gotówka: 1402.31|Akcje: 194|Wartość portfela: 1790.63|Nagroda: -4.17|
# Krok: 277|Cena: 2.02|Gotówka: 1674.53|Akcje: 58|Wartość portfela: 1791.73|Nagroda: -0.51|
# Krok: 278|Cena: 2.10|Gotówka: 452.05|Akcje: 663|Wartość portfela: 1847.26|Nagroda: 12.57|
# Krok: 279|Cena: 2.14|Gotówka: 5.92|Akcje: 875|Wartość portfela: 1874.11|Nagroda: 73.28|
# Krok: 280|Cena: 2.20|Gotówka: 1.65|Akcje: 877|Wartość portfela: 1931.11|Nagroda: 26.92|
# Krok: 281|Cena: 2.23|Gotówka: 1.65|Akcje: 877|Wartość portfela: 1955.05|Nagroda: 57.00|
# Krok: 282|Cena: 2.36|Gotówka: 1.65|Akcje: 877|Wartość portfela: 2074.39|Nagroda: 23.94|
# Krok: 283|Cena: 2.45|Gotówka: 1.65|Akcje: 877|Wartość portfela: 2147.81|Nagroda: 119.35|
# Krok: 284|Cena: 2.52|Gotówka: 1.65|Akcje: 877|Wartość portfela: 2210.99|Nagroda: 73.42|
# Krok: 285|Cena: 2.65|Gotówka: 1.65|Akcje: 877|Wartość portfela: 2321.38|Nagroda: 63.18|
# Krok: 286|Cena: 2.78|Gotówka: 1.65|Akcje: 877|Wartość portfela: 2441.62|Nagroda: 110.39|
# Krok: 287|Cena: 2.91|Gotówka: 1.65|Akcje: 877|Wartość portfela: 2552.98|Nagroda: 120.24|
# Krok: 288|Cena: 3.04|Gotówka: 1.65|Akcje: 877|Wartość portfela: 2669.29|Nagroda: 111.37|
# Krok: 289|Cena: 3.19|Gotówka: 1.65|Akcje: 877|Wartość portfela: 2801.74|Nagroda: 116.30|
# Krok: 290|Cena: 3.34|Gotówka: 1.65|Akcje: 877|Wartość portfela: 2934.55|Nagroda: 132.45|
# Krok: 291|Cena: 3.51|Gotówka: 1.65|Akcje: 877|Wartość portfela: 3082.81|Nagroda: 132.81|
# Krok: 292|Cena: 3.71|Gotówka: 1.65|Akcje: 877|Wartość portfela: 3252.28|Nagroda: 148.26|
# Krok: 293|Cena: 3.80|Gotówka: 1.65|Akcje: 877|Wartość portfela: 3332.40|Nagroda: 169.48|
# Krok: 294|Cena: 4.02|Gotówka: 1.65|Akcje: 877|Wartość portfela: 3528.21|Nagroda: 80.12|
# Krok: 295|Cena: 4.21|Gotówka: 1.65|Akcje: 877|Wartość portfela: 3693.80|Nagroda: 195.81|
# Krok: 296|Cena: 4.40|Gotówka: 1.65|Akcje: 877|Wartość portfela: 3856.99|Nagroda: 165.59|
# Krok: 297|Cena: 4.57|Gotówka: 1.65|Akcje: 877|Wartość portfela: 4008.49|Nagroda: 163.19|
# Krok: 298|Cena: 4.73|Gotówka: 1.65|Akcje: 877|Wartość portfela: 4148.90|Nagroda: 151.50|
# Krok: 299|Cena: 4.96|Gotówka: 1.65|Akcje: 877|Wartość portfela: 4350.97|Nagroda: 140.40|
# Krok: 300|Cena: 5.18|Gotówka: 1.65|Akcje: 877|Wartość portfela: 4541.20|Nagroda: 202.08|
# Krok: 301|Cena: 5.30|Gotówka: 1.65|Akcje: 877|Wartość portfela: 4649.18|Nagroda: 190.22|
# Krok: 302|Cena: 5.53|Gotówka: 1.65|Akcje: 877|Wartość portfela: 4855.27|Nagroda: 107.98|
# Krok: 303|Cena: 5.70|Gotówka: 1.65|Akcje: 877|Wartość portfela: 4996.59|Nagroda: 206.09|
# Krok: 304|Cena: 5.88|Gotówka: 1.65|Akcje: 877|Wartość portfela: 5161.08|Nagroda: 141.32|
# Krok: 305|Cena: 6.04|Gotówka: 1.65|Akcje: 877|Wartość portfela: 5300.40|Nagroda: 164.48|
# Krok: 306|Cena: 6.23|Gotówka: 1.65|Akcje: 877|Wartość portfela: 5466.03|Nagroda: 139.33|
# Krok: 307|Cena: 6.43|Gotówka: 1.65|Akcje: 877|Wartość portfela: 5643.41|Nagroda: 165.62|
# Krok: 308|Cena: 6.58|Gotówka: 1.65|Akcje: 877|Wartość portfela: 5774.65|Nagroda: 177.39|
# Krok: 309|Cena: 6.76|Gotówka: 1.65|Akcje: 877|Wartość portfela: 5933.18|Nagroda: 131.24|
# Krok: 310|Cena: 6.90|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6055.79|Nagroda: 158.52|
# Krok: 311|Cena: 7.03|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6168.65|Nagroda: 122.61|
# Krok: 312|Cena: 7.19|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6310.30|Nagroda: 112.86|
# Krok: 313|Cena: 7.29|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6398.67|Nagroda: 141.66|
# Krok: 314|Cena: 7.42|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6508.81|Nagroda: 88.37|
# Krok: 315|Cena: 7.51|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6584.03|Nagroda: 110.13|
# Krok: 316|Cena: 7.61|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6676.62|Nagroda: 75.23|
# Krok: 317|Cena: 7.68|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6740.35|Nagroda: 92.58|
# Krok: 318|Cena: 7.79|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6837.70|Nagroda: 63.74|
# Krok: 319|Cena: 7.82|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6857.77|Nagroda: 97.34|
# Krok: 320|Cena: 7.91|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6940.38|Nagroda: 20.08|
# Krok: 321|Cena: 7.94|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6961.45|Nagroda: 82.61|
# Krok: 322|Cena: 7.99|Gotówka: 1.65|Akcje: 877|Wartość portfela: 7013.26|Nagroda: 21.08|
# Krok: 323|Cena: 8.01|Gotówka: 1.65|Akcje: 877|Wartość portfela: 7023.46|Nagroda: 51.80|
# Krok: 324|Cena: 8.04|Gotówka: 1.65|Akcje: 877|Wartość portfela: 7049.40|Nagroda: 10.21|
# Krok: 325|Cena: 8.01|Gotówka: 1.65|Akcje: 877|Wartość portfela: 7027.02|Nagroda: 25.94|
# Krok: 326|Cena: 7.95|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6972.95|Nagroda: -22.38|
# Krok: 327|Cena: 7.95|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6975.30|Nagroda: -54.07|
# Krok: 328|Cena: 7.89|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6921.59|Nagroda: 2.35|
# Krok: 329|Cena: 7.85|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6888.60|Nagroda: -53.71|
# Krok: 330|Cena: 7.83|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6869.78|Nagroda: -32.99|
# Krok: 331|Cena: 7.74|Gotówka: 1.65|Akcje: 877|Wartość portfela: 6790.29|Nagroda: -18.82|
# Krok: 332|Cena: 7.63|Gotówka: 117.76|Akcje: 862|Wartość portfela: 6694.86|Nagroda: -78.13|
# Krok: 333|Cena: 7.53|Gotówka: 232.21|Akcje: 847|Wartość portfela: 6609.51|Nagroda: -93.77|
# Krok: 334|Cena: 7.45|Gotówka: 322.56|Akcje: 835|Wartość portfela: 6539.66|Nagroda: -84.14|
# Krok: 335|Cena: 7.31|Gotówka: 99.19|Akcje: 865|Wartość portfela: 6419.20|Nagroda: -72.36|
# Krok: 336|Cena: 7.19|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 337|Cena: 7.08|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 338|Cena: 6.96|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 339|Cena: 6.80|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 340|Cena: 6.59|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 341|Cena: 6.48|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 342|Cena: 6.30|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 343|Cena: 6.14|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 344|Cena: 5.98|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 345|Cena: 5.73|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 346|Cena: 5.57|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 347|Cena: 5.41|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 348|Cena: 5.18|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 349|Cena: 5.05|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 350|Cena: 4.84|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 351|Cena: 4.66|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 352|Cena: 4.45|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 353|Cena: 4.29|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 354|Cena: 4.11|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 355|Cena: 3.92|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 356|Cena: 3.75|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 357|Cena: 3.58|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 358|Cena: 3.39|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 359|Cena: 3.25|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 360|Cena: 3.10|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 361|Cena: 2.97|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 362|Cena: 2.85|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 363|Cena: 2.68|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 364|Cena: 2.58|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 365|Cena: 2.51|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 366|Cena: 2.36|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 367|Cena: 2.28|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 368|Cena: 2.22|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 369|Cena: 2.17|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 370|Cena: 2.10|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 371|Cena: 2.08|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 372|Cena: 2.04|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 373|Cena: 2.02|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 374|Cena: 2.01|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 375|Cena: 2.05|Gotówka: 6419.20|Akcje: 0|Wartość portfela: 6419.20|Nagroda: 0.00|
# Krok: 376|Cena: 2.02|Gotówka: 2877.82|Akcje: 1726|Wartość portfela: 6361.25|Nagroda: 70.21|
# Krok: 377|Cena: 2.01|Gotówka: 5886.97|Akcje: 235|Wartość portfela: 6359.59|Nagroda: -7.89|
# Krok: 378|Cena: 2.12|Gotówka: 6076.02|Akcje: 141|Wartość portfela: 6375.49|Nagroda: -1.00|
# Krok: 379|Cena: 2.13|Gotówka: 1632.86|Akcje: 2233|Wartość portfela: 6399.80|Nagroda: 251.76|
# Krok: 380|Cena: 2.21|Gotówka: 16.83|Akcje: 2990|Wartość portfela: 6623.35|Nagroda: 32.55|
# Krok: 381|Cena: 2.31|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 6918.74|Nagroda: 224.07|
# Krok: 382|Cena: 2.34|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 6999.89|Nagroda: 295.40|
# Krok: 383|Cena: 2.44|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 7307.88|Nagroda: 81.14|
# Krok: 384|Cena: 2.54|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 7604.05|Nagroda: 307.99|
# Krok: 385|Cena: 2.67|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 7998.46|Nagroda: 296.18|
# Krok: 386|Cena: 2.82|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 8445.98|Nagroda: 394.41|
# Krok: 387|Cena: 2.95|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 8850.65|Nagroda: 447.51|
# Krok: 388|Cena: 3.09|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 9259.86|Nagroda: 404.67|
# Krok: 389|Cena: 3.20|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 9605.46|Nagroda: 409.21|
# Krok: 390|Cena: 3.34|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 10019.53|Nagroda: 345.60|
# Krok: 391|Cena: 3.55|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 10648.26|Nagroda: 414.07|
# Krok: 392|Cena: 3.71|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 11120.94|Nagroda: 628.73|
# Krok: 393|Cena: 3.90|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 11696.20|Nagroda: 472.69|
# Krok: 394|Cena: 4.08|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 12243.34|Nagroda: 575.26|
# Krok: 395|Cena: 4.25|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 12753.20|Nagroda: 547.14|
# Krok: 396|Cena: 4.45|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 13343.01|Nagroda: 509.86|
# Krok: 397|Cena: 4.63|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 13870.43|Nagroda: 589.81|
# Krok: 398|Cena: 4.82|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 14452.18|Nagroda: 527.41|
# Krok: 399|Cena: 4.99|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 14944.13|Nagroda: 581.75|
# Krok: 400|Cena: 4.99|Gotówka: 1.37|Akcje: 2997|Wartość portfela: 14944.13|Nagroda: 491.95|

# %%
results_plot_continuous(env_predict=env_predict, prices=prices)

# %%
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor


from trading_envs import ProfitTradingEnv
from logger import TrainingLoggerCallback
from data_and_plots import (
    generate_sine_wave,
    training_plot,
    results_plot_continuous,
    plot_shares_changes_fixed_size,
    plot,
)
from helper import predict_data_env
import torch
import random

# %%
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)

# ziarno dla NumPy
np.random.seed(42)

# ziarno dla standardowego generatora liczb losowych Pythona
random.seed(42)

# %%
prices = generate_sine_wave(seed=42)
plot(prices)

# %%
# Tworzenie instacji środowiska
env_agent = ProfitTradingEnv(prices)
env_agent = Monitor(env_agent)

# Sprawdzenie zgodności środowiska z stable_baselines3
check_env(env_agent)

logger_callback = TrainingLoggerCallback()
# Tworzenie modelu PPO
model_agent = PPO(
    "MlpPolicy",
    env_agent,
    # policy_kwargs=dict(
    #     net_arch=[
    #         256,
    #         256,
    #         256,
    #     ]
    # ),
    #   learning_rate=0.00005,        # domyślnie 3e-4
    n_steps=400,  # liczba kroków zanim agent zrobi aktualizację
    batch_size=100,  # batch size do uczenia
    # n_epochs=10,                 # ile razy przebiega po danych przy każdej aktualizacji
    gamma=0.3,  # współczynnik dyskontujący nagrody
    # gae_lambda=0.95,             # współczynnik GAE
    # clip_range=0.2,              # zakres klipu PPO (stabilizacja treningu)
    # ent_coef=0.9,                # zachęta do eksploracji
    verbose=1,
)

# Trening modelu
model_agent.learn(total_timesteps=100_000, callback=logger_callback)


training_plot(logger_callback=logger_callback)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# c:\Users\ortek\AppData\Local\pypoetry\Cache\virtualenvs\forecasting-uBk3YmnA-py3.12\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 400       |
# |    ep_rew_mean     | -6.73e+04 |
# | time/              |           |
# |    fps             | 624       |
# |    iterations      | 1         |
# |    time_elapsed    | 0         |
# |    total_timesteps | 400       |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.99e+04   |
# | time/                   |             |
# |    fps                  | 580         |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 800         |
# | train/                  |             |
# |    approx_kl            | 0.010179893 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.000324    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29e+05    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 1           |
# |    value_loss           | 2.44e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -5.57e+04   |
# | time/                   |             |
# |    fps                  | 571         |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 1200        |
# | train/                  |             |
# |    approx_kl            | 0.010497993 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.000251    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.58e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 1.01        |
# |    value_loss           | 1.71e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -4.91e+04  |
# | time/                   |            |
# |    fps                  | 583        |
# |    iterations           | 4          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 1600       |
# | train/                  |            |
# |    approx_kl            | 0.01478726 |
# |    clip_fraction        | 0.098      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.43      |
# |    explained_variance   | 0.000382   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.44e+04   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0362    |
# |    std                  | 1.01       |
# |    value_loss           | 1.53e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -4.36e+04   |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 2000        |
# | train/                  |             |
# |    approx_kl            | 0.015082141 |
# |    clip_fraction        | 0.0817      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 2.03e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.12e+04    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0228     |
# |    std                  | 1           |
# |    value_loss           | 9.43e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -3.91e+04    |
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2400         |
# | train/                  |              |
# |    approx_kl            | 0.0124115655 |
# |    clip_fraction        | 0.0945       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 5.74e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.06e+04     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0239      |
# |    std                  | 0.993        |
# |    value_loss           | 5.98e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -3.5e+04    |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2800        |
# | train/                  |             |
# |    approx_kl            | 0.011117969 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.000179   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.985       |
# |    value_loss           | 4.28e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -3.09e+04   |
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.007059132 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 3.71e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.15e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.974       |
# |    value_loss           | 2.68e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.81e+04   |
# | time/                   |             |
# |    fps                  | 608         |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 3600        |
# | train/                  |             |
# |    approx_kl            | 0.013999923 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.000156    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 468         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.967       |
# |    value_loss           | 5.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.6e+04    |
# | time/                   |             |
# |    fps                  | 609         |
# |    iterations           | 10          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4000        |
# | train/                  |             |
# |    approx_kl            | 0.011069136 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000248    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.61e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.963       |
# |    value_loss           | 1.39e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -2.43e+04    |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 11           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 4400         |
# | train/                  |              |
# |    approx_kl            | 0.0061284034 |
# |    clip_fraction        | 0.087        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00057      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.91e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0153      |
# |    std                  | 0.961        |
# |    value_loss           | 1.86e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.27e+04   |
# | time/                   |             |
# |    fps                  | 607         |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4800        |
# | train/                  |             |
# |    approx_kl            | 0.009919339 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.000615    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.38e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.957       |
# |    value_loss           | 1.6e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -2.12e+04   |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 13          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 5200        |
# | train/                  |             |
# |    approx_kl            | 0.008095572 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00145     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55e+04    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.956       |
# |    value_loss           | 1.33e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.99e+04   |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 5600        |
# | train/                  |             |
# |    approx_kl            | 0.020201758 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00204     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.93e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00743    |
# |    std                  | 0.955       |
# |    value_loss           | 5.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.87e+04   |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 15          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6000        |
# | train/                  |             |
# |    approx_kl            | 0.020531526 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.003       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.1        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00568    |
# |    std                  | 0.951       |
# |    value_loss           | 8.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.8e+04    |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 16          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6400        |
# | train/                  |             |
# |    approx_kl            | 0.022404911 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00179    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00239    |
# |    std                  | 0.954       |
# |    value_loss           | 2.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.71e+04   |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 17          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6800        |
# | train/                  |             |
# |    approx_kl            | 0.004843555 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00294     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.72e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.954       |
# |    value_loss           | 1.61e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.63e+04   |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 18          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 7200        |
# | train/                  |             |
# |    approx_kl            | 0.005723738 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.0041      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.91e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00244    |
# |    std                  | 0.948       |
# |    value_loss           | 5.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.55e+04   |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 19          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 7600        |
# | train/                  |             |
# |    approx_kl            | 0.008794765 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.000715   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 432         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.943       |
# |    value_loss           | 8.08e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.5e+04    |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 20          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8000        |
# | train/                  |             |
# |    approx_kl            | 0.009547549 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00219     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.96e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00825    |
# |    std                  | 0.944       |
# |    value_loss           | 2.71e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.43e+04   |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 21          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8400        |
# | train/                  |             |
# |    approx_kl            | 0.025771726 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00248     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.68e+03    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00971    |
# |    std                  | 0.944       |
# |    value_loss           | 8.07e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.38e+04    |
# | time/                   |              |
# |    fps                  | 619          |
# |    iterations           | 22           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 8800         |
# | train/                  |              |
# |    approx_kl            | 0.0110004805 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.000483     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.4         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0115      |
# |    std                  | 0.94         |
# |    value_loss           | 2.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.34e+04   |
# | time/                   |             |
# |    fps                  | 618         |
# |    iterations           | 23          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 9200        |
# | train/                  |             |
# |    approx_kl            | 0.024004495 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00299     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.05e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.939       |
# |    value_loss           | 8.07e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.29e+04   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 24          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 9600        |
# | train/                  |             |
# |    approx_kl            | 0.010290391 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00254     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.82e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.939       |
# |    value_loss           | 5.36e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.25e+04    |
# | time/                   |              |
# |    fps                  | 619          |
# |    iterations           | 25           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0077928617 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00725      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.91e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.01        |
# |    std                  | 0.938        |
# |    value_loss           | 5.37e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.2e+04    |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 26          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 10400       |
# | train/                  |             |
# |    approx_kl            | 0.012808842 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0339      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49          |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.936       |
# |    value_loss           | 57          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.17e+04   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 27          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 10800       |
# | train/                  |             |
# |    approx_kl            | 0.020058047 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0824      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23          |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0198     |
# |    std                  | 0.94        |
# |    value_loss           | 43.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.14e+04   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 28          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 11200       |
# | train/                  |             |
# |    approx_kl            | 0.010601352 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00662     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.4        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00196    |
# |    std                  | 0.938       |
# |    value_loss           | 5.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.1e+04    |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 29          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 11600       |
# | train/                  |             |
# |    approx_kl            | 0.003163449 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0108      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.4e+03     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0116     |
# |    std                  | 0.938       |
# |    value_loss           | 5.54e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -1.15e+04  |
# | time/                   |            |
# |    fps                  | 619        |
# |    iterations           | 30         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 12000      |
# | train/                  |            |
# |    approx_kl            | 0.08211486 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.00156    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 60         |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0151    |
# |    std                  | 0.94       |
# |    value_loss           | 2.83e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.14e+04   |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 31          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 12400       |
# | train/                  |             |
# |    approx_kl            | 0.046481308 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00346     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.47e+04    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0052     |
# |    std                  | 0.94        |
# |    value_loss           | 1.04e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.12e+04   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 32          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.010970737 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.00428     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46e+04    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.939       |
# |    value_loss           | 2.34e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -1.1e+04   |
# | time/                   |            |
# |    fps                  | 620        |
# |    iterations           | 33         |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 13200      |
# | train/                  |            |
# |    approx_kl            | 0.00774319 |
# |    clip_fraction        | 0.0402     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.00451    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 461        |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.939      |
# |    value_loss           | 8.49e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.07e+04    |
# | time/                   |              |
# |    fps                  | 621          |
# |    iterations           | 34           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 13600        |
# | train/                  |              |
# |    approx_kl            | 0.0108296955 |
# |    clip_fraction        | 0.0532       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00516      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.02e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00861     |
# |    std                  | 0.936        |
# |    value_loss           | 9.12e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.06e+04   |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 35          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 14000       |
# | train/                  |             |
# |    approx_kl            | 0.012891158 |
# |    clip_fraction        | 0.0782      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00817     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.41e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.934       |
# |    value_loss           | 5.68e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.05e+04   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 36          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14400       |
# | train/                  |             |
# |    approx_kl            | 0.008865702 |
# |    clip_fraction        | 0.0692      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00771     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+04    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00791    |
# |    std                  | 0.933       |
# |    value_loss           | 1.87e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -1.03e+04  |
# | time/                   |            |
# |    fps                  | 620        |
# |    iterations           | 37         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 14800      |
# | train/                  |            |
# |    approx_kl            | 0.01356503 |
# |    clip_fraction        | 0.0665     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.00523    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.09e+03   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0126    |
# |    std                  | 0.933      |
# |    value_loss           | 2.27e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.01e+04   |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 38          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 15200       |
# | train/                  |             |
# |    approx_kl            | 0.013242136 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00151     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 224         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.932       |
# |    value_loss           | 7.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -9.98e+03   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 39          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 15600       |
# | train/                  |             |
# |    approx_kl            | 0.014056865 |
# |    clip_fraction        | 0.0905      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00818     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 693         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.93        |
# |    value_loss           | 1.18e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.02e+04   |
# | time/                   |             |
# |    fps                  | 620         |
# |    iterations           | 40          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 16000       |
# | train/                  |             |
# |    approx_kl            | 0.010472973 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.000231    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.86e+04    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00808    |
# |    std                  | 0.929       |
# |    value_loss           | 7.3e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.01e+04   |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 41          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16400       |
# | train/                  |             |
# |    approx_kl            | 0.004987772 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00203     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+05    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00317    |
# |    std                  | 0.929       |
# |    value_loss           | 1.23e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1e+04      |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 42          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 16800       |
# | train/                  |             |
# |    approx_kl            | 0.017594598 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00536     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.28e+04    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00804    |
# |    std                  | 0.929       |
# |    value_loss           | 2.45e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -1.03e+04  |
# | time/                   |            |
# |    fps                  | 621        |
# |    iterations           | 43         |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 17200      |
# | train/                  |            |
# |    approx_kl            | 0.03768277 |
# |    clip_fraction        | 0.123      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 0.00166    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.95e+04   |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.03       |
# |    std                  | 0.929      |
# |    value_loss           | 3.48e+04   |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -1.03e+04 |
# | time/                   |           |
# |    fps                  | 621       |
# |    iterations           | 44        |
# |    time_elapsed         | 28        |
# |    total_timesteps      | 17600     |
# | train/                  |           |
# |    approx_kl            | 0.0240799 |
# |    clip_fraction        | 0.0665    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.35     |
# |    explained_variance   | 0.00369   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.96e+04  |
# |    n_updates            | 430       |
# |    policy_gradient_loss | 0.0387    |
# |    std                  | 0.929     |
# |    value_loss           | 9.16e+04  |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | -1.03e+04    |
# | time/                   |              |
# |    fps                  | 620          |
# |    iterations           | 45           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 18000        |
# | train/                  |              |
# |    approx_kl            | 0.0066968785 |
# |    clip_fraction        | 0.0697       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.0035       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.91e+04     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0093      |
# |    std                  | 0.929        |
# |    value_loss           | 3.08e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.02e+04   |
# | time/                   |             |
# |    fps                  | 621         |
# |    iterations           | 46          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18400       |
# | train/                  |             |
# |    approx_kl            | 0.029837769 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00155     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.57e+04    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.929       |
# |    value_loss           | 4.21e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1e+04      |
# | time/                   |             |
# |    fps                  | 622         |
# |    iterations           | 47          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 18800       |
# | train/                  |             |
# |    approx_kl            | 0.021538833 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.00364     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.86e+03    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.928       |
# |    value_loss           | 9.81e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 400       |
# |    ep_rew_mean          | -1.01e+04 |
# | time/                   |           |
# |    fps                  | 623       |
# |    iterations           | 48        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 19200     |
# | train/                  |           |
# |    approx_kl            | 0.0217156 |
# |    clip_fraction        | 0.0705    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.34     |
# |    explained_variance   | 0.000705  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.52e+03  |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -0.00635  |
# |    std                  | 0.926     |
# |    value_loss           | 2.82e+04  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -1.04e+04  |
# | time/                   |            |
# |    fps                  | 623        |
# |    iterations           | 49         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 19600      |
# | train/                  |            |
# |    approx_kl            | 0.06696452 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.00208    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.53e+04   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00447   |
# |    std                  | 0.923      |
# |    value_loss           | 6.5e+04    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.03e+04   |
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 50          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.013475815 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.000797    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38e+04    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0131     |
# |    std                  | 0.922       |
# |    value_loss           | 6.56e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | -1.02e+04   |
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 51          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 20400       |
# | train/                  |             |
# |    approx_kl            | 0.012051774 |
# |    clip_fraction        | 0.0392      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.000285    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+04    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00316    |
# |    std                  | 0.922       |
# |    value_loss           | 6.4e+04     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | -9.91e+03  |
# | time/                   |            |
# |    fps                  | 627        |
# |    iterations           | 52         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 20800      |
# | train/                  |            |
# |    approx_kl            | 0.01869708 |
# |    clip_fraction        | 0.0587     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.34      |
# |    explained_variance   | 0.00101    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.99e+04   |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0123    |
# |    std                  | 0.921      |
# ...
# |    explained_variance   | 0.00938     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97e+05    |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | 0.0108      |
# |    std                  | 0.826       |
# |    value_loss           | 1.16e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.29e+03    |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 234         |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 93600       |
# | train/                  |             |
# |    approx_kl            | 0.031916574 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0133      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+05    |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | 0.00231     |
# |    std                  | 0.826       |
# |    value_loss           | 1.18e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.31e+03    |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 235         |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 94000       |
# | train/                  |             |
# |    approx_kl            | 0.060514465 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.00687     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.46e+04    |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00826    |
# |    std                  | 0.825       |
# |    value_loss           | 2.43e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 2.45e+03     |
# | time/                   |              |
# |    fps                  | 644          |
# |    iterations           | 236          |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 94400        |
# | train/                  |              |
# |    approx_kl            | 0.0072957794 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0.015        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77e+03     |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.00403     |
# |    std                  | 0.825        |
# |    value_loss           | 1.44e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.33e+03    |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 237         |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 94800       |
# | train/                  |             |
# |    approx_kl            | 0.044575542 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0125      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+04    |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00629    |
# |    std                  | 0.825       |
# |    value_loss           | 1.8e+05     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | 2.39e+03   |
# | time/                   |            |
# |    fps                  | 644        |
# |    iterations           | 238        |
# |    time_elapsed         | 147        |
# |    total_timesteps      | 95200      |
# | train/                  |            |
# |    approx_kl            | 0.03294388 |
# |    clip_fraction        | 0.074      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.0127     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.41e+04   |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.00387   |
# |    std                  | 0.824      |
# |    value_loss           | 2.08e+05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | 2.47e+03   |
# | time/                   |            |
# |    fps                  | 644        |
# |    iterations           | 239        |
# |    time_elapsed         | 148        |
# |    total_timesteps      | 95600      |
# | train/                  |            |
# |    approx_kl            | 0.23472658 |
# |    clip_fraction        | 0.165      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.00847    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.35e+04   |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.00303   |
# |    std                  | 0.823      |
# |    value_loss           | 2.97e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.42e+03    |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 240         |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 96000       |
# | train/                  |             |
# |    approx_kl            | 0.024872238 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.00998     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.75e+04    |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00222    |
# |    std                  | 0.823       |
# |    value_loss           | 4.66e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.63e+03    |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 241         |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 96400       |
# | train/                  |             |
# |    approx_kl            | 0.034249537 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0259      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+04    |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.0111     |
# |    std                  | 0.823       |
# |    value_loss           | 1.02e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.56e+03    |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 242         |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 96800       |
# | train/                  |             |
# |    approx_kl            | 0.005778035 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0125      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29e+04    |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | 0.0023      |
# |    std                  | 0.823       |
# |    value_loss           | 1.82e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.68e+03    |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 243         |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 97200       |
# | train/                  |             |
# |    approx_kl            | 0.025876587 |
# |    clip_fraction        | 0.0262      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0217      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.75e+04    |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.00388    |
# |    std                  | 0.822       |
# |    value_loss           | 3.48e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | 2.75e+03   |
# | time/                   |            |
# |    fps                  | 644        |
# |    iterations           | 244        |
# |    time_elapsed         | 151        |
# |    total_timesteps      | 97600      |
# | train/                  |            |
# |    approx_kl            | 0.08620601 |
# |    clip_fraction        | 0.131      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.00973    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.1e+04    |
# |    n_updates            | 2430       |
# |    policy_gradient_loss | 0.0158     |
# |    std                  | 0.823      |
# |    value_loss           | 2.51e+05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 400        |
# |    ep_rew_mean          | 2.81e+03   |
# | time/                   |            |
# |    fps                  | 644        |
# |    iterations           | 245        |
# |    time_elapsed         | 151        |
# |    total_timesteps      | 98000      |
# | train/                  |            |
# |    approx_kl            | 0.25967765 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.22      |
# |    explained_variance   | 0.013      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.5e+05    |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | 0.0286     |
# |    std                  | 0.823      |
# |    value_loss           | 2.22e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.88e+03    |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 246         |
# |    time_elapsed         | 152         |
# |    total_timesteps      | 98400       |
# | train/                  |             |
# |    approx_kl            | 0.014154078 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0188      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.17e+03    |
# |    n_updates            | 2450        |
# |    policy_gradient_loss | -0.0055     |
# |    std                  | 0.823       |
# |    value_loss           | 1.65e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 2.95e+03    |
# | time/                   |             |
# |    fps                  | 644         |
# |    iterations           | 247         |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 98800       |
# | train/                  |             |
# |    approx_kl            | 0.012481345 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0164      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.03e+03    |
# |    n_updates            | 2460        |
# |    policy_gradient_loss | 0.00269     |
# |    std                  | 0.822       |
# |    value_loss           | 2.16e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 400          |
# |    ep_rew_mean          | 2.97e+03     |
# | time/                   |              |
# |    fps                  | 645          |
# |    iterations           | 248          |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 99200        |
# | train/                  |              |
# |    approx_kl            | 0.0012098374 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.0126       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.52e+03     |
# |    n_updates            | 2470         |
# |    policy_gradient_loss | 0.00717      |
# |    std                  | 0.822        |
# |    value_loss           | 2.55e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 3.05e+03    |
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 249         |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 99600       |
# | train/                  |             |
# |    approx_kl            | 0.037565544 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0122      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39e+04    |
# |    n_updates            | 2480        |
# |    policy_gradient_loss | 0.00894     |
# |    std                  | 0.821       |
# |    value_loss           | 1.89e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 400         |
# |    ep_rew_mean          | 3.12e+03    |
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 250         |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.013342319 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.0143      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54e+05    |
# |    n_updates            | 2490        |
# |    policy_gradient_loss | -0.00297    |
# |    std                  | 0.821       |
# |    value_loss           | 1.15e+05    |
# -----------------------------------------

# %%
env_predict, lista = predict_data_env(
    env=ProfitTradingEnv, data=prices, agent=model_agent
)
# Out:
# Krok: 1|Cena: 5.17|Gotówka: 3.93|Akcje: 39|Wartość portfela: 205.49|Reward: -0.5474|Profit: 5.4867|
# Krok: 2|Cena: 5.39|Gotówka: 3.93|Akcje: 39|Wartość portfela: 214.22|Reward: 0.0000|Profit: 14.2189|
# Krok: 3|Cena: 5.58|Gotówka: 3.93|Akcje: 39|Wartość portfela: 221.64|Reward: 0.0000|Profit: 21.6446|
# Krok: 4|Cena: 5.71|Gotówka: 3.93|Akcje: 39|Wartość portfela: 226.58|Reward: 0.0000|Profit: 26.5793|
# Krok: 5|Cena: 5.90|Gotówka: 3.93|Akcje: 39|Wartość portfela: 234.16|Reward: 0.0000|Profit: 34.1599|
# Krok: 6|Cena: 6.11|Gotówka: 3.93|Akcje: 39|Wartość portfela: 242.21|Reward: 0.0000|Profit: 42.2061|
# Krok: 7|Cena: 6.27|Gotówka: 3.93|Akcje: 39|Wartość portfela: 248.62|Reward: 0.0000|Profit: 48.6192|
# Krok: 8|Cena: 6.45|Gotówka: 3.93|Akcje: 39|Wartość portfela: 255.41|Reward: 0.0000|Profit: 55.4142|
# Krok: 9|Cena: 6.59|Gotówka: 3.93|Akcje: 39|Wartość portfela: 261.10|Reward: 0.0000|Profit: 61.0994|
# Krok: 10|Cena: 6.78|Gotówka: 3.93|Akcje: 39|Wartość portfela: 268.54|Reward: 0.0000|Profit: 68.5388|
# Krok: 11|Cena: 6.93|Gotówka: 3.93|Akcje: 39|Wartość portfela: 274.27|Reward: 0.0000|Profit: 74.2744|
# Krok: 12|Cena: 7.06|Gotówka: 3.93|Akcje: 39|Wartość portfela: 279.24|Reward: 0.0000|Profit: 79.2376|
# Krok: 13|Cena: 7.21|Gotówka: 3.93|Akcje: 39|Wartość portfela: 285.27|Reward: 0.0000|Profit: 85.2654|
# Krok: 14|Cena: 7.33|Gotówka: 3.93|Akcje: 39|Wartość portfela: 289.61|Reward: 0.0000|Profit: 89.6120|
# Krok: 15|Cena: 7.41|Gotówka: 3.93|Akcje: 39|Wartość portfela: 293.08|Reward: 0.0000|Profit: 93.0800|
# Krok: 16|Cena: 7.54|Gotówka: 3.93|Akcje: 39|Wartość portfela: 298.16|Reward: 0.0000|Profit: 98.1647|
# Krok: 17|Cena: 7.61|Gotówka: 3.93|Akcje: 39|Wartość portfela: 300.86|Reward: 0.0000|Profit: 100.8635|
# Krok: 18|Cena: 7.74|Gotówka: 3.93|Akcje: 39|Wartość portfela: 305.62|Reward: 0.0000|Profit: 105.6238|
# Krok: 19|Cena: 7.79|Gotówka: 3.93|Akcje: 39|Wartość portfela: 307.81|Reward: 0.0000|Profit: 107.8063|
# Krok: 20|Cena: 7.85|Gotówka: 3.93|Akcje: 39|Wartość portfela: 310.18|Reward: 0.0000|Profit: 110.1758|
# Krok: 21|Cena: 7.89|Gotówka: 3.93|Akcje: 39|Wartość portfela: 311.82|Reward: 0.0000|Profit: 111.8218|
# Krok: 22|Cena: 7.97|Gotówka: 3.93|Akcje: 39|Wartość portfela: 314.89|Reward: 0.0000|Profit: 114.8895|
# Krok: 23|Cena: 7.97|Gotówka: 3.93|Akcje: 39|Wartość portfela: 314.94|Reward: 0.0000|Profit: 114.9423|
# Krok: 24|Cena: 7.99|Gotówka: 3.93|Akcje: 39|Wartość portfela: 315.40|Reward: 0.0000|Profit: 115.3950|
# Krok: 25|Cena: 7.99|Gotówka: 3.93|Akcje: 39|Wartość portfela: 315.66|Reward: 0.0000|Profit: 115.6575|
# Krok: 26|Cena: 8.00|Gotówka: 3.93|Akcje: 39|Wartość portfela: 316.09|Reward: 0.0000|Profit: 116.0863|
# Krok: 27|Cena: 7.98|Gotówka: 3.93|Akcje: 39|Wartość portfela: 315.23|Reward: 0.0000|Profit: 115.2321|
# Krok: 28|Cena: 7.95|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 116.0863|Profit: 0.0000|
# Krok: 29|Cena: 7.91|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 30|Cena: 7.89|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 31|Cena: 7.78|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 32|Cena: 7.70|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 33|Cena: 7.61|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 34|Cena: 7.54|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 35|Cena: 7.44|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 36|Cena: 7.30|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 37|Cena: 7.16|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 38|Cena: 7.02|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 39|Cena: 6.91|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 40|Cena: 6.76|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 41|Cena: 6.60|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 42|Cena: 6.41|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 43|Cena: 6.26|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 44|Cena: 6.09|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 45|Cena: 5.91|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 46|Cena: 5.74|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 47|Cena: 5.54|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 48|Cena: 5.37|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 49|Cena: 5.17|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 50|Cena: 4.98|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 51|Cena: 4.80|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 52|Cena: 4.57|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 53|Cena: 4.41|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 54|Cena: 4.22|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 55|Cena: 4.04|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 56|Cena: 3.87|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 57|Cena: 3.73|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 58|Cena: 3.51|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 59|Cena: 3.39|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 60|Cena: 3.18|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 61|Cena: 3.06|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 62|Cena: 2.93|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 63|Cena: 2.80|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 64|Cena: 2.68|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 65|Cena: 2.57|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 66|Cena: 2.44|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 67|Cena: 2.35|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 68|Cena: 2.29|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 69|Cena: 2.20|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 70|Cena: 2.11|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 71|Cena: 2.06|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 72|Cena: 2.03|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 73|Cena: 2.03|Gotówka: 315.23|Akcje: 0|Wartość portfela: 315.23|Reward: 0.0000|Profit: 0.0000|
# Krok: 74|Cena: 2.01|Gotówka: 1.62|Akcje: 153|Wartość portfela: 308.65|Reward: -3.1051|Profit: -6.5777|
# Krok: 75|Cena: 2.01|Gotówka: 308.65|Akcje: 0|Wartość portfela: 308.65|Reward: -3.1051|Profit: 0.0000|
# Krok: 76|Cena: 2.00|Gotówka: 1.50|Akcje: 151|Wartość portfela: 303.47|Reward: -3.0412|Profit: -5.1817|
# Krok: 77|Cena: 2.03|Gotówka: 303.47|Akcje: 0|Wartość portfela: 303.47|Reward: -3.0412|Profit: 0.0000|
# Krok: 78|Cena: 2.07|Gotówka: 1.84|Akcje: 147|Wartość portfela: 306.54|Reward: -2.9865|Profit: 3.0659|
# Krok: 79|Cena: 2.10|Gotówka: 1.84|Akcje: 147|Wartość portfela: 310.18|Reward: 0.0000|Profit: 6.7104|
# Krok: 80|Cena: 2.17|Gotówka: 1.84|Akcje: 147|Wartość portfela: 320.52|Reward: 0.0000|Profit: 17.0447|
# Krok: 81|Cena: 2.21|Gotówka: 1.84|Akcje: 147|Wartość portfela: 326.97|Reward: 0.0000|Profit: 23.4942|
# Krok: 82|Cena: 2.29|Gotówka: 1.84|Akcje: 147|Wartość portfela: 339.20|Reward: 0.0000|Profit: 35.7294|
# Krok: 83|Cena: 2.38|Gotówka: 1.84|Akcje: 147|Wartość portfela: 352.08|Reward: 0.0000|Profit: 48.6039|
# Krok: 84|Cena: 2.46|Gotówka: 1.84|Akcje: 147|Wartość portfela: 364.13|Reward: 0.0000|Profit: 60.6615|
# Krok: 85|Cena: 2.61|Gotówka: 1.84|Akcje: 147|Wartość portfela: 385.00|Reward: 0.0000|Profit: 81.5244|
# Krok: 86|Cena: 2.71|Gotówka: 1.84|Akcje: 147|Wartość portfela: 399.50|Reward: 0.0000|Profit: 96.0292|
# Krok: 87|Cena: 2.84|Gotówka: 1.84|Akcje: 147|Wartość portfela: 419.57|Reward: 0.0000|Profit: 116.0952|
# Krok: 88|Cena: 2.99|Gotówka: 1.84|Akcje: 147|Wartość portfela: 440.85|Reward: 0.0000|Profit: 137.3795|
# Krok: 89|Cena: 3.13|Gotówka: 1.84|Akcje: 147|Wartość portfela: 461.84|Reward: 0.0000|Profit: 158.3662|
# Krok: 90|Cena: 3.28|Gotówka: 1.84|Akcje: 147|Wartość portfela: 484.67|Reward: 0.0000|Profit: 181.1929|
# Krok: 91|Cena: 3.43|Gotówka: 1.84|Akcje: 147|Wartość portfela: 505.61|Reward: 0.0000|Profit: 202.1384|
# Krok: 92|Cena: 3.58|Gotówka: 1.84|Akcje: 147|Wartość portfela: 528.76|Reward: 0.0000|Profit: 225.2906|
# Krok: 93|Cena: 3.76|Gotówka: 1.84|Akcje: 147|Wartość portfela: 554.70|Reward: 0.0000|Profit: 251.2283|
# Krok: 94|Cena: 3.90|Gotówka: 1.84|Akcje: 147|Wartość portfela: 575.62|Reward: 0.0000|Profit: 272.1510|
# Krok: 95|Cena: 4.09|Gotówka: 1.84|Akcje: 147|Wartość portfela: 602.60|Reward: 0.0000|Profit: 299.1261|
# Krok: 96|Cena: 4.27|Gotówka: 1.84|Akcje: 147|Wartość portfela: 629.75|Reward: 0.0000|Profit: 326.2763|
# Krok: 97|Cena: 4.46|Gotówka: 1.84|Akcje: 147|Wartość portfela: 657.90|Reward: 0.0000|Profit: 354.4269|
# Krok: 98|Cena: 4.68|Gotówka: 1.84|Akcje: 147|Wartość portfela: 689.50|Reward: 0.0000|Profit: 386.0294|
# Krok: 99|Cena: 4.84|Gotówka: 1.84|Akcje: 147|Wartość portfela: 713.35|Reward: 0.0000|Profit: 409.8796|
# Krok: 100|Cena: 5.04|Gotówka: 1.84|Akcje: 147|Wartość portfela: 742.67|Reward: 0.0000|Profit: 439.2002|
# Krok: 101|Cena: 5.26|Gotówka: 1.84|Akcje: 147|Wartość portfela: 775.35|Reward: 0.0000|Profit: 471.8744|
# Krok: 102|Cena: 5.42|Gotówka: 1.84|Akcje: 147|Wartość portfela: 798.09|Reward: 0.0000|Profit: 494.6124|
# Krok: 103|Cena: 5.62|Gotówka: 1.84|Akcje: 147|Wartość portfela: 828.66|Reward: 0.0000|Profit: 525.1862|
# Krok: 104|Cena: 5.77|Gotówka: 1.84|Akcje: 147|Wartość portfela: 850.75|Reward: 0.0000|Profit: 547.2755|
# Krok: 105|Cena: 5.97|Gotówka: 1.84|Akcje: 147|Wartość portfela: 879.43|Reward: 0.0000|Profit: 575.9562|
# Krok: 106|Cena: 6.13|Gotówka: 1.84|Akcje: 147|Wartość portfela: 903.21|Reward: 0.0000|Profit: 599.7389|
# Krok: 107|Cena: 6.32|Gotówka: 1.84|Akcje: 147|Wartość portfela: 930.31|Reward: 0.0000|Profit: 626.8361|
# Krok: 108|Cena: 6.51|Gotówka: 1.84|Akcje: 147|Wartość portfela: 958.31|Reward: 0.0000|Profit: 654.8329|
# Krok: 109|Cena: 6.62|Gotówka: 1.84|Akcje: 147|Wartość portfela: 974.42|Reward: 0.0000|Profit: 670.9451|
# Krok: 110|Cena: 6.81|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1003.47|Reward: 0.0000|Profit: 699.9991|
# Krok: 111|Cena: 6.96|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1024.54|Reward: 0.0000|Profit: 721.0668|
# Krok: 112|Cena: 7.08|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1042.60|Reward: 0.0000|Profit: 739.1288|
# Krok: 113|Cena: 7.19|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1059.38|Reward: 0.0000|Profit: 755.9121|
# Krok: 114|Cena: 7.35|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1081.84|Reward: 0.0000|Profit: 778.3674|
# Krok: 115|Cena: 7.45|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1096.70|Reward: 0.0000|Profit: 793.2229|
# Krok: 116|Cena: 7.57|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1114.13|Reward: 0.0000|Profit: 810.6545|
# Krok: 117|Cena: 7.66|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1127.20|Reward: 0.0000|Profit: 823.7317|
# Krok: 118|Cena: 7.77|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1144.00|Reward: 0.0000|Profit: 840.5256|
# Krok: 119|Cena: 7.80|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1149.14|Reward: 0.0000|Profit: 845.6654|
# Krok: 120|Cena: 7.85|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1155.75|Reward: 0.0000|Profit: 852.2747|
# Krok: 121|Cena: 7.92|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1166.52|Reward: 0.0000|Profit: 863.0520|
# Krok: 122|Cena: 7.96|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1172.18|Reward: 0.0000|Profit: 868.7107|
# Krok: 123|Cena: 8.01|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1179.35|Reward: 0.0000|Profit: 875.8747|
# Krok: 124|Cena: 8.01|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1179.88|Reward: 0.0000|Profit: 876.4095|
# Krok: 125|Cena: 8.01|Gotówka: 1.84|Akcje: 147|Wartość portfela: 1178.80|Reward: 0.0000|Profit: 875.3314|
# Krok: 126|Cena: 8.02|Gotówka: 1178.80|Akcje: 0|Wartość portfela: 1178.80|Reward: 876.4095|Profit: 0.0000|
# Krok: 127|Cena: 7.94|Gotówka: 4.42|Akcje: 145|Wartość portfela: 1156.36|Reward: -11.6276|Profit: -22.4395|
# Krok: 128|Cena: 7.92|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: -11.6276|Profit: 0.0000|
# Krok: 129|Cena: 7.87|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 130|Cena: 7.83|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 131|Cena: 7.74|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 132|Cena: 7.70|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 133|Cena: 7.59|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 134|Cena: 7.47|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 135|Cena: 7.37|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 136|Cena: 7.28|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 137|Cena: 7.16|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 138|Cena: 7.05|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 139|Cena: 6.92|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 140|Cena: 6.72|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 141|Cena: 6.53|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 142|Cena: 6.34|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 143|Cena: 6.22|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 144|Cena: 6.02|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 145|Cena: 5.85|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 146|Cena: 5.67|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 147|Cena: 5.49|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 148|Cena: 5.33|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 149|Cena: 5.12|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 150|Cena: 4.93|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 151|Cena: 4.72|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 152|Cena: 4.52|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 153|Cena: 4.36|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 154|Cena: 4.18|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 155|Cena: 4.04|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 156|Cena: 3.83|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 157|Cena: 3.68|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 158|Cena: 3.48|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 159|Cena: 3.31|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 160|Cena: 3.16|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 161|Cena: 3.02|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 162|Cena: 2.93|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 163|Cena: 2.74|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 164|Cena: 2.66|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 165|Cena: 2.51|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 166|Cena: 2.44|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 167|Cena: 2.34|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 168|Cena: 2.25|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 169|Cena: 2.18|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 170|Cena: 2.11|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 171|Cena: 2.08|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 172|Cena: 2.03|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 173|Cena: 1.99|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 174|Cena: 1.98|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 175|Cena: 2.00|Gotówka: 1156.36|Akcje: 0|Wartość portfela: 1156.36|Reward: 0.0000|Profit: 0.0000|
# Krok: 176|Cena: 2.04|Gotówka: 0.30|Akcje: 571|Wartość portfela: 1167.35|Reward: -11.4462|Profit: 10.9831|
# Krok: 177|Cena: 2.04|Gotówka: 0.30|Akcje: 571|Wartość portfela: 1164.28|Reward: 0.0000|Profit: 7.9106|
# Krok: 178|Cena: 2.07|Gotówka: 1164.28|Akcje: 0|Wartość portfela: 1164.28|Reward: 10.9831|Profit: 0.0000|
# Krok: 179|Cena: 2.12|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1183.10|Reward: -11.5170|Profit: 18.8231|
# Krok: 180|Cena: 2.20|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1226.67|Reward: 0.0000|Profit: 62.3927|
# Krok: 181|Cena: 2.25|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1253.01|Reward: 0.0000|Profit: 88.7355|
# Krok: 182|Cena: 2.32|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1290.53|Reward: 0.0000|Profit: 126.2518|
# Krok: 183|Cena: 2.44|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1357.88|Reward: 0.0000|Profit: 193.6052|
# Krok: 184|Cena: 2.52|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1406.50|Reward: 0.0000|Profit: 242.2227|
# Krok: 185|Cena: 2.66|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1480.49|Reward: 0.0000|Profit: 316.2106|
# Krok: 186|Cena: 2.75|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1532.32|Reward: 0.0000|Profit: 368.0456|
# Krok: 187|Cena: 2.85|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1588.52|Reward: 0.0000|Profit: 424.2468|
# Krok: 188|Cena: 2.98|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1663.50|Reward: 0.0000|Profit: 499.2249|
# Krok: 189|Cena: 3.19|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1778.10|Reward: 0.0000|Profit: 613.8283|
# Krok: 190|Cena: 3.34|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1863.96|Reward: 0.0000|Profit: 699.6802|
# Krok: 191|Cena: 3.47|Gotówka: 1.06|Akcje: 557|Wartość portfela: 1931.53|Reward: 0.0000|Profit: 767.2539|
# Krok: 192|Cena: 3.63|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2021.42|Reward: 0.0000|Profit: 857.1416|
# Krok: 193|Cena: 3.83|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2137.14|Reward: 0.0000|Profit: 972.8634|
# Krok: 194|Cena: 3.96|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2206.34|Reward: 0.0000|Profit: 1042.0613|
# Krok: 195|Cena: 4.14|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2308.76|Reward: 0.0000|Profit: 1144.4880|
# Krok: 196|Cena: 4.36|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2427.81|Reward: 0.0000|Profit: 1263.5369|
# Krok: 197|Cena: 4.52|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2519.61|Reward: 0.0000|Profit: 1355.3387|
# Krok: 198|Cena: 4.72|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2628.36|Reward: 0.0000|Profit: 1464.0814|
# Krok: 199|Cena: 4.90|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2731.62|Reward: 0.0000|Profit: 1567.3467|
# Krok: 200|Cena: 5.10|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2842.44|Reward: 0.0000|Profit: 1678.1658|
# Krok: 201|Cena: 5.31|Gotówka: 1.06|Akcje: 557|Wartość portfela: 2959.39|Reward: 0.0000|Profit: 1795.1137|
# Krok: 202|Cena: 5.47|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3049.12|Reward: 0.0000|Profit: 1884.8472|
# Krok: 203|Cena: 5.67|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3158.65|Reward: 0.0000|Profit: 1994.3759|
# Krok: 204|Cena: 5.80|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3230.55|Reward: 0.0000|Profit: 2066.2786|
# Krok: 205|Cena: 6.02|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3352.91|Reward: 0.0000|Profit: 2188.6362|
# Krok: 206|Cena: 6.18|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3441.87|Reward: 0.0000|Profit: 2277.5963|
# Krok: 207|Cena: 6.34|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3532.86|Reward: 0.0000|Profit: 2368.5848|
# Krok: 208|Cena: 6.51|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3628.81|Reward: 0.0000|Profit: 2464.5364|
# Krok: 209|Cena: 6.68|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3723.65|Reward: 0.0000|Profit: 2559.3720|
# Krok: 210|Cena: 6.86|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3822.61|Reward: 0.0000|Profit: 2658.3390|
# Krok: 211|Cena: 6.96|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3878.61|Reward: 0.0000|Profit: 2714.3306|
# Krok: 212|Cena: 7.13|Gotówka: 1.06|Akcje: 557|Wartość portfela: 3970.30|Reward: 0.0000|Profit: 2806.0266|
# Krok: 213|Cena: 7.24|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4036.45|Reward: 0.0000|Profit: 2872.1747|
# Krok: 214|Cena: 7.37|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4105.10|Reward: 0.0000|Profit: 2940.8202|
# Krok: 215|Cena: 7.51|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4181.57|Reward: 0.0000|Profit: 3017.2971|
# Krok: 216|Cena: 7.60|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4232.56|Reward: 0.0000|Profit: 3068.2862|
# Krok: 217|Cena: 7.70|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4291.92|Reward: 0.0000|Profit: 3127.6418|
# Krok: 218|Cena: 7.75|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4319.84|Reward: 0.0000|Profit: 3155.5600|
# Krok: 219|Cena: 7.81|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4352.25|Reward: 0.0000|Profit: 3187.9760|
# Krok: 220|Cena: 7.88|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4389.72|Reward: 0.0000|Profit: 3225.4399|
# Krok: 221|Cena: 7.93|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4420.74|Reward: 0.0000|Profit: 3256.4695|
# Krok: 222|Cena: 7.97|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4439.37|Reward: 0.0000|Profit: 3275.0964|
# Krok: 223|Cena: 7.97|Gotówka: 1.06|Akcje: 557|Wartość portfela: 4438.14|Reward: 0.0000|Profit: 3273.8609|
# Krok: 224|Cena: 8.00|Gotówka: 4438.14|Akcje: 0|Wartość portfela: 4438.14|Reward: 3275.0964|Profit: 0.0000|
# Krok: 225|Cena: 8.00|Gotówka: 1.84|Akcje: 549|Wartość portfela: 4395.32|Reward: -43.9237|Profit: -42.8197|
# Krok: 226|Cena: 8.04|Gotówka: 1.84|Akcje: 549|Wartość portfela: 4413.52|Reward: 0.0000|Profit: -24.6206|
# Krok: 227|Cena: 8.00|Gotówka: 1.84|Akcje: 549|Wartość portfela: 4393.04|Reward: 0.0000|Profit: -45.0925|
# Krok: 228|Cena: 7.91|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: -24.6206|Profit: 0.0000|
# Krok: 229|Cena: 7.87|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 230|Cena: 7.79|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 231|Cena: 7.74|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 232|Cena: 7.67|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 233|Cena: 7.60|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 234|Cena: 7.46|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 235|Cena: 7.35|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 236|Cena: 7.20|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 237|Cena: 7.11|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 238|Cena: 6.95|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 239|Cena: 6.81|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 240|Cena: 6.65|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 241|Cena: 6.51|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 242|Cena: 6.31|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 243|Cena: 6.14|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 244|Cena: 6.04|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 245|Cena: 5.79|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 246|Cena: 5.61|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 247|Cena: 5.48|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 248|Cena: 5.32|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 249|Cena: 5.05|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 250|Cena: 4.87|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 251|Cena: 4.70|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 252|Cena: 4.54|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 253|Cena: 4.30|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 254|Cena: 4.13|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 255|Cena: 3.97|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 256|Cena: 3.79|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 257|Cena: 3.61|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 258|Cena: 3.45|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 259|Cena: 3.26|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 260|Cena: 3.13|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 261|Cena: 2.99|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 262|Cena: 2.86|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 263|Cena: 2.72|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 264|Cena: 2.62|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 265|Cena: 2.52|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 266|Cena: 2.41|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 267|Cena: 2.32|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 268|Cena: 2.24|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 269|Cena: 2.17|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 270|Cena: 2.10|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 271|Cena: 2.07|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 272|Cena: 2.03|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 273|Cena: 2.05|Gotówka: 4393.04|Akcje: 0|Wartość portfela: 4393.04|Reward: 0.0000|Profit: 0.0000|
# Krok: 274|Cena: 2.03|Gotówka: 1.14|Akcje: 2119|Wartość portfela: 4307.05|Reward: -43.4842|Profit: -85.9948|
# Krok: 275|Cena: 2.01|Gotówka: 4307.05|Akcje: 0|Wartość portfela: 4307.05|Reward: -43.4842|Profit: 0.0000|
# Krok: 276|Cena: 2.00|Gotówka: 4307.05|Akcje: 0|Wartość portfela: 4307.05|Reward: 0.0000|Profit: 0.0000|
# Krok: 277|Cena: 2.02|Gotówka: 4307.05|Akcje: 0|Wartość portfela: 4307.05|Reward: 0.0000|Profit: 0.0000|
# Krok: 278|Cena: 2.10|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 4441.13|Reward: -42.6354|Profit: 134.0796|
# Krok: 279|Cena: 2.14|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 4505.89|Reward: 0.0000|Profit: 198.8390|
# Krok: 280|Cena: 2.20|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 4643.02|Reward: 0.0000|Profit: 335.9712|
# Krok: 281|Cena: 2.23|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 4700.61|Reward: 0.0000|Profit: 393.5587|
# Krok: 282|Cena: 2.36|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 4987.75|Reward: 0.0000|Profit: 680.7014|
# Krok: 283|Cena: 2.45|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 5164.39|Reward: 0.0000|Profit: 857.3438|
# Krok: 284|Cena: 2.52|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 5316.40|Reward: 0.0000|Profit: 1009.3516|
# Krok: 285|Cena: 2.65|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 5581.98|Reward: 0.0000|Profit: 1274.9337|
# Krok: 286|Cena: 2.78|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 5871.26|Reward: 0.0000|Profit: 1564.2106|
# Krok: 287|Cena: 2.91|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 6139.20|Reward: 0.0000|Profit: 1832.1507|
# Krok: 288|Cena: 3.04|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 6419.02|Reward: 0.0000|Profit: 2111.9688|
# Krok: 289|Cena: 3.19|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 6737.68|Reward: 0.0000|Profit: 2430.6325|
# Krok: 290|Cena: 3.34|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 7057.22|Reward: 0.0000|Profit: 2750.1746|
# Krok: 291|Cena: 3.51|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 7413.92|Reward: 0.0000|Profit: 3106.8694|
# Krok: 292|Cena: 3.71|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 7821.67|Reward: 0.0000|Profit: 3514.6193|
# Krok: 293|Cena: 3.80|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 8014.42|Reward: 0.0000|Profit: 3707.3716|
# Krok: 294|Cena: 4.02|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 8485.53|Reward: 0.0000|Profit: 4178.4826|
# Krok: 295|Cena: 4.21|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 8883.92|Reward: 0.0000|Profit: 4576.8718|
# Krok: 296|Cena: 4.40|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 9276.55|Reward: 0.0000|Profit: 4969.5006|
# Krok: 297|Cena: 4.57|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 9641.05|Reward: 0.0000|Profit: 5334.0053|
# Krok: 298|Cena: 4.73|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 9978.85|Reward: 0.0000|Profit: 5671.8034|
# Krok: 299|Cena: 4.96|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 10465.04|Reward: 0.0000|Profit: 6157.9902|
# Krok: 300|Cena: 5.18|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 10922.70|Reward: 0.0000|Profit: 6615.6501|
# Krok: 301|Cena: 5.30|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 11182.50|Reward: 0.0000|Profit: 6875.4484|
# Krok: 302|Cena: 5.53|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 11678.34|Reward: 0.0000|Profit: 7371.2904|
# Krok: 303|Cena: 5.70|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 12018.35|Reward: 0.0000|Profit: 7711.3052|
# Krok: 304|Cena: 5.88|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 12414.09|Reward: 0.0000|Profit: 8107.0377|
# Krok: 305|Cena: 6.04|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 12749.30|Reward: 0.0000|Profit: 8442.2495|
# Krok: 306|Cena: 6.23|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 13147.78|Reward: 0.0000|Profit: 8840.7280|
# Krok: 307|Cena: 6.43|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 13574.56|Reward: 0.0000|Profit: 9267.5080|
# Krok: 308|Cena: 6.58|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 13890.31|Reward: 0.0000|Profit: 9583.2629|
# Krok: 309|Cena: 6.76|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 14271.71|Reward: 0.0000|Profit: 9964.6593|
# Krok: 310|Cena: 6.90|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 14566.70|Reward: 0.0000|Profit: 10259.6553|
# Krok: 311|Cena: 7.03|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 14838.23|Reward: 0.0000|Profit: 10531.1796|
# Krok: 312|Cena: 7.19|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 15179.04|Reward: 0.0000|Profit: 10871.9942|
# Krok: 313|Cena: 7.29|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 15391.66|Reward: 0.0000|Profit: 11084.6107|
# Krok: 314|Cena: 7.42|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 15656.63|Reward: 0.0000|Profit: 11349.5846|
# Krok: 315|Cena: 7.51|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 15837.62|Reward: 0.0000|Profit: 11530.5738|
# Krok: 316|Cena: 7.61|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16060.37|Reward: 0.0000|Profit: 11753.3243|
# Krok: 317|Cena: 7.68|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16213.72|Reward: 0.0000|Profit: 11906.6704|
# Krok: 318|Cena: 7.79|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16447.92|Reward: 0.0000|Profit: 12140.8701|
# Krok: 319|Cena: 7.82|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16496.22|Reward: 0.0000|Profit: 12189.1692|
# Krok: 320|Cena: 7.91|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16694.96|Reward: 0.0000|Profit: 12387.9142|
# Krok: 321|Cena: 7.94|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16745.67|Reward: 0.0000|Profit: 12438.6204|
# Krok: 322|Cena: 7.99|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16870.31|Reward: 0.0000|Profit: 12563.2567|
# Krok: 323|Cena: 8.01|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16894.86|Reward: 0.0000|Profit: 12587.8120|
# Krok: 324|Cena: 8.04|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16957.26|Reward: 0.0000|Profit: 12650.2151|
# Krok: 325|Cena: 8.01|Gotówka: 0.87|Akcje: 2110|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 12596.3758|
# Krok: 326|Cena: 7.95|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 12650.2151|Profit: 0.0000|
# Krok: 327|Cena: 7.95|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 328|Cena: 7.89|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 329|Cena: 7.85|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 330|Cena: 7.83|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 331|Cena: 7.74|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 332|Cena: 7.63|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 333|Cena: 7.53|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 334|Cena: 7.45|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 335|Cena: 7.31|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 336|Cena: 7.19|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 337|Cena: 7.08|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 338|Cena: 6.96|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 339|Cena: 6.80|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 340|Cena: 6.59|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 341|Cena: 6.48|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 342|Cena: 6.30|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 343|Cena: 6.14|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 344|Cena: 5.98|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 345|Cena: 5.73|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 346|Cena: 5.57|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 347|Cena: 5.41|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 348|Cena: 5.18|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 349|Cena: 5.05|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 350|Cena: 4.84|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 351|Cena: 4.66|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 352|Cena: 4.45|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 353|Cena: 4.29|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 354|Cena: 4.11|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 355|Cena: 3.92|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 356|Cena: 3.75|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 357|Cena: 3.58|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 358|Cena: 3.39|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 359|Cena: 3.25|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 360|Cena: 3.10|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 361|Cena: 2.97|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 362|Cena: 2.85|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 363|Cena: 2.68|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 364|Cena: 2.58|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 365|Cena: 2.51|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 366|Cena: 2.36|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 367|Cena: 2.28|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 368|Cena: 2.22|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 369|Cena: 2.17|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 370|Cena: 2.10|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 371|Cena: 2.08|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 372|Cena: 2.04|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 373|Cena: 2.02|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 374|Cena: 2.01|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 375|Cena: 2.05|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 376|Cena: 2.02|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 377|Cena: 2.01|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 378|Cena: 2.12|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: 0.0000|Profit: 0.0000|
# Krok: 379|Cena: 2.13|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 380|Cena: 2.21|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 381|Cena: 2.31|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 382|Cena: 2.34|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 383|Cena: 2.44|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 384|Cena: 2.54|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 385|Cena: 2.67|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 386|Cena: 2.82|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 387|Cena: 2.95|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 388|Cena: 3.09|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 389|Cena: 3.20|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 390|Cena: 3.34|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 391|Cena: 3.55|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 392|Cena: 3.71|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 393|Cena: 3.90|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 394|Cena: 4.08|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 395|Cena: 4.25|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 396|Cena: 4.45|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 397|Cena: 4.63|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 398|Cena: 4.82|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 399|Cena: 4.99|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|
# Krok: 400|Cena: 4.99|Gotówka: 16903.42|Akcje: 0|Wartość portfela: 16903.42|Reward: -1000.0000|Profit: 0.0000|

# %%
results_plot_continuous(env_predict=env_predict, prices=prices)

# %%
plot_shares_changes_fixed_size(lista, prices)
